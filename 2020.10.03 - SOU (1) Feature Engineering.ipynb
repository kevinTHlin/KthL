# %%
import pandas as pd
import numpy as np
import statistics 

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

df = pd.read_excel("C1 - t1.xlsx")

a1 = df.loc[:, ['访问时长(seconds)']]
a1 = a1.values
a2 = df.loc[:, ['活动要求学习时间(seconds)']]
a2 = a2.values

a = a1 -a2
df.loc[:, '高过门槛时长'] = a

df
# Out:
#       USER ID   活动类型               活动名称  活动要求学习时间(seconds)  \
# 0        1625   quiz               课程前测                  0
# 1       24539   quiz               课程前测                  0
# 2       24581   quiz               课程前测                  0
# 3       24581  video    学一学：人工智能应用示例（一）                120
# 4        1625  video  学一学：人工智能现状——第三次热潮                300
# ...       ...    ...                ...                ...
# 1992    24757   quiz         第三讲 学习体验问卷                  0
# 1993    24757   quiz         第七讲 学习体验问卷                  0
# 1994    24757   quiz         第十讲 学习体验问卷                  0
# 1995    24757   quiz        第十三讲 学习体验问卷                  0
# 1996    24757   quiz        第十四讲 学习体验问卷                  0
#
#                             活动章节  章节预计学习时间(seconds)            访问时间(datetime)  \
# 0                             导言                  0  2020-09-11T05:48:12.749Z
# 1                             导言                  0  2020-09-11T05:51:53.341Z
# ...

# %%
user = df['USER ID'].unique()
user = list(user)

user.remove(24632) 
user.remove(24702) 

USER_ID = {}
for i in user:
     USER_ID[i] = df.loc[df['USER ID'] == i]

        
        
c1 = np.array([196, 537, 170, 344, 399, 845, 381, 257, 354, 1027, 716, 676, 1007, 381, 139])
c2 = np.array([5, 5, 9, 20, 42])
c3 = np.array([53, 6, 3, 3, 3, 3, 3, 3, 3, 
               3, 3, 3, 3, 3, 3, 3, 3])
c4 = ['学一学：人工智能应用示例（一）',
    '学一学：人工智能现状——第三次热潮',
    '学一学：人工智能现状：AI版“双手互搏”有多牛？',
    '学一学：人工智能应用示例（二）', 
    '学一学：人工智能的突破与不确定性',
    '学一学：视觉错觉（一）视力之谜',
    '学一学：视觉错觉（二）颜色错觉',
    '学一学：视觉错觉（三）先验错觉',
    '学一学：声音与视听错觉', 
    '学一学：空间错觉  二维',
    '学一学：空间错觉  三维',
    '学一学：语言错觉',
    '学一学：其他错觉',
    '学一学：思考与小结',
    '补充资料：波士顿动力机器人']
c5 = ['延伸阅读：颠倒的视觉', 
    '延伸阅读：看得见的斑点狗',
    '延伸阅读：火星人脸的阴影', 
    '延伸阅读：听觉错觉与语音、歌唱的智能分析', 
    '想一想：课程回顾']
c6 = ['课程前测', 
    '解释型AI的决策应用调查表', 
    '第一讲 学习体验问卷',
    '第二讲 学习体验问卷',
    '第三讲 学习体验问卷',
    '第四讲 学习体验问卷',
    '第五讲 学习体验问卷',
    '第六讲 学习体验问卷',
    '第七讲 学习体验问卷',
    '第八讲 学习体验问卷',
    '第九讲 学习体验问卷',
    '第十讲 学习体验问卷',
    '第十一讲 学习体验问卷',
    '第十二讲 学习体验问卷',
    '第十三讲 学习体验问卷',
    '第十四讲 学习体验问卷',
    '课程整体回顾问卷']

# %%
USER_ID[1625].reset_index(inplace=True)
USER_ID[1625].set_index('活动名称', inplace=True)
print(USER_ID[1625].shape) 
# USER_ID[1625]

Time_1625_V = USER_ID[1625].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_1625_V = np.nan_to_num(Time_1625_V)

Time_1625_T = USER_ID[1625].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_1625_T = np.nan_to_num(Time_1625_T)

Time_1625_H = USER_ID[1625].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_1625_H = np.nan_to_num(Time_1625_H)

#(1) Grit
Grit_1625_V = Time_1625_V / c1  #视频观看时长/视频总时长
Grit_1625_T = Time_1625_T / c2   #文本阅读时长/文本页数
Grit_1625_H = Time_1625_H /c3   #作业花费时长/作业问题数

Grit1_1625 = statistics.mean(Grit_1625_V)    #(视频观看时长/视频总时长)的平均
Grit2_1625 = statistics.median(Grit_1625_V)    #(视频观看时长/视频总时长)的中位数
Grit3_1625 = 1/statistics.stdev(Grit_1625_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_1625 = 1/(max(Grit_1625_V)-min(Grit_1625_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_1625 = statistics.mean(Grit_1625_T)    #(文本阅读时长/文本页数)的平均
Grit6_1625 = statistics.median(Grit_1625_T)    #(文本阅读时长/文本页数)的中位数
Grit7_1625 = 1/statistics.stdev(Grit_1625_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_1625 = 1/(max(Grit_1625_T)-min(Grit_1625_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_1625 = statistics.mean(Grit_1625_H)    #(作业花费时长/作业问题数)的平均
Grit10_1625 = statistics.median(Grit_1625_H)    #(作业花费时长/作业问题数)的中位数
Grit11_1625 = 1/statistics.stdev(Grit_1625_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_1625 = 1/(max(Grit_1625_H)-min(Grit_1625_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_1625 = Time_1625_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_1625 = Time_1625_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_1625 = Time_1625_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_1625 = USER_ID[1625].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_1625 = np.nan_to_num(Self_control4_1625)
Self_control4_1625 = Self_control4_1625.max()

Self_control5_1625 = USER_ID[1625].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_1625 = np.nan_to_num(Self_control5_1625)
Self_control5_1625 = Self_control5_1625.min()

Self_control6_1625 = USER_ID[1625].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_1625 = np.nan_to_num(Self_control6_1625)
Self_control6_1625 = Self_control6_1625.sum() 
Self_control6_1625 = Self_control6_1625 / 70

Self_control7_1625 = USER_ID[1625].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_1625 = np.nan_to_num(Self_control7_1625)
Self_control7_1625 = Self_control7_1625[20:40].mean()

#(3) Engagement
Engagement_1625_V = Time_1625_V    #视频观看时长
Engagement_1625_T = Time_1625_T    #文本阅读时长
Engagement_1625_H = Time_1625_H    #作业花费时长

Engagement1_1625 = USER_ID[1625].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_1625 = np.nan_to_num(Engagement1_1625).sum()

Engagement2_1625 = statistics.mean(Engagement_1625_V)    #平均每次花费在视频学习的时间
Engagement3_1625 = statistics.mean(Engagement_1625_T)    #平均每次花费在文本课件的时间
Engagement4_1625 = statistics.mean(Engagement_1625_H)    #平均每次花费在作业答题的时间
Engagement5_1625 = 70    #学习次数(登入次数)
Engagement6_1625 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_1625 = Time_1625_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_1625 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_1625 = USER_ID[1625].loc[:, '访问时长(seconds)'].values
Self_perception1_1625 = np.nan_to_num(Self_perception1_1625)

Self_perception1_1625 = 1/((Self_perception1_1625[:20].sum() 
                         - Self_perception1_1625[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_1625 = 1/((statistics.mean(Grit_1625_V[:7]) 
                         - statistics.mean(Grit_1625_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_1625 = 1/((statistics.mean(Grit_1625_T[:2]) 
                         - statistics.mean(Grit_1625_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_1625 = 1/((statistics.mean(Grit_1625_H[:9]) 
                         - statistics.mean(Grit_1625_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_1625 = USER_ID[1625].loc[:, ['高过门槛时长']].values
Motivation1_1625 = np.nan_to_num(Motivation1_1625).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_1625 = USER_ID[1625].loc[c4, ['高过门槛时长']].values
Motivation2_1625 = np.nan_to_num(Motivation2_1625).sum()
#文挡高过门槛时长总和
Motivation3_1625 = USER_ID[1625].loc[c5, ['高过门槛时长']].values   
Motivation3_1625 = np.nan_to_num(Motivation3_1625).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_1625 = np.array(USER_ID[1625].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_1625 = np.nan_to_num(Motivation4_1625)
Motivation4_1625 = statistics.mean(Motivation4_1625 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_1625 = np.array(USER_ID[1625].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_1625 = np.nan_to_num(Motivation5_1625)
Motivation5_1625 = statistics.mean(Motivation5_1625 / c2)

#选修花费总时长
Motivation6_1625 = USER_ID[1625].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_1625 = np.nan_to_num(Motivation6_1625).sum()

#(选修花费/页数)的平均
Motivation7_1625 = Motivation6_1625 / (11+8)
Motivation8_1625 = Motivation7_1625/Motivation5_1625    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_1625 = 1    #完成进度*
# Out:
# (40, 9)

# %%
USER_ID[24539].reset_index(inplace=True)
USER_ID[24539].set_index('活动名称', inplace=True)
print(USER_ID[24539].shape) 
# USER_ID[24539]

Time_24539_V = USER_ID[24539].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24539_V = np.nan_to_num(Time_24539_V)

Time_24539_T = USER_ID[24539].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24539_T = np.nan_to_num(Time_24539_T)

Time_24539_H = USER_ID[24539].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24539_H = np.nan_to_num(Time_24539_H)

#(1) Grit
Grit_24539_V = Time_24539_V / c1  #视频观看时长/视频总时长
Grit_24539_T = Time_24539_T / c2   #文本阅读时长/文本页数
Grit_24539_H = Time_24539_H /c3   #作业花费时长/作业问题数

Grit1_24539 = statistics.mean(Grit_24539_V)    #(视频观看时长/视频总时长)的平均
Grit2_24539 = statistics.median(Grit_24539_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24539 = 1/statistics.stdev(Grit_24539_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24539 = 1/(max(Grit_24539_V)-min(Grit_24539_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24539 = statistics.mean(Grit_24539_T)    #(文本阅读时长/文本页数)的平均
Grit6_24539 = statistics.median(Grit_24539_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24539 = 1/statistics.stdev(Grit_24539_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24539 = 1/(max(Grit_24539_T)-min(Grit_24539_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24539 = statistics.mean(Grit_24539_H)    #(作业花费时长/作业问题数)的平均
Grit10_24539 = statistics.median(Grit_24539_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24539 = 1/statistics.stdev(Grit_24539_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24539 = 1/(max(Grit_24539_H)-min(Grit_24539_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24539 = Time_24539_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24539 = Time_24539_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24539 = Time_24539_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24539 = USER_ID[24539].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24539 = np.nan_to_num(Self_control4_24539)
Self_control4_24539 = Self_control4_24539.max()

Self_control5_24539 = USER_ID[24539].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24539 = np.nan_to_num(Self_control5_24539)
Self_control5_24539 = Self_control5_24539.min()

Self_control6_24539 = USER_ID[24539].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24539 = np.nan_to_num(Self_control6_24539)
Self_control6_24539 = Self_control6_24539.sum() 
Self_control6_24539 = Self_control6_24539 / 36

Self_control7_24539 = USER_ID[24539].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24539 = np.nan_to_num(Self_control7_24539)
Self_control7_24539 = Self_control7_24539[20:40].mean()

#(3) Engagement
Engagement_24539_V = Time_24539_V    #视频观看时长
Engagement_24539_T = Time_24539_T    #文本阅读时长
Engagement_24539_H = Time_24539_H    #作业花费时长

Engagement1_24539 = USER_ID[24539].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24539 = np.nan_to_num(Engagement1_24539).sum()

Engagement2_24539 = statistics.mean(Engagement_24539_V)    #平均每次花费在视频学习的时间
Engagement3_24539 = statistics.mean(Engagement_24539_T)    #平均每次花费在文本课件的时间
Engagement4_24539 = statistics.mean(Engagement_24539_H)    #平均每次花费在作业答题的时间
Engagement5_24539 = 36    #学习次数(登入次数)
Engagement6_24539 = 0    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24539 = Time_24539_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24539 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24539 = USER_ID[24539].loc[:, '访问时长(seconds)'].values
Self_perception1_24539 = np.nan_to_num(Self_perception1_24539)

Self_perception1_24539 = 1/((Self_perception1_24539[:20].sum() 
                         - Self_perception1_24539[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24539 = 1/((statistics.mean(Grit_24539_V[:7]) 
                         - statistics.mean(Grit_24539_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24539 = 1/((statistics.mean(Grit_24539_T[:2]) 
                         - statistics.mean(Grit_24539_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24539 = 1/((statistics.mean(Grit_24539_H[:9]) 
                         - statistics.mean(Grit_24539_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24539 = USER_ID[24539].loc[:, ['高过门槛时长']].values
Motivation1_24539 = np.nan_to_num(Motivation1_24539).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24539 = USER_ID[24539].loc[c4, ['高过门槛时长']].values
Motivation2_24539 = np.nan_to_num(Motivation2_24539).sum()
#文挡高过门槛时长总和
Motivation3_24539 = USER_ID[24539].loc[c5, ['高过门槛时长']].values   
Motivation3_24539 = np.nan_to_num(Motivation3_24539).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24539 = np.array(USER_ID[24539].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24539 = np.nan_to_num(Motivation4_24539)
Motivation4_24539 = statistics.mean(Motivation4_24539 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24539 = np.array(USER_ID[24539].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24539 = np.nan_to_num(Motivation5_24539)
Motivation5_24539 = statistics.mean(Motivation5_24539 / c2)

#选修花费总时长
Motivation6_24539 = 0

#(选修花费/页数)的平均
Motivation7_24539 = Motivation6_24539 / (11+8)
Motivation8_24539 = Motivation7_24539/Motivation5_24539    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24539 = 0.38    #完成进度*
# Out:
# (17, 9)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-4a8202db6f3f> in <module>
#       4 # USER_ID[24539]
#       5
# ----> 6 Time_24539_V = USER_ID[24539].loc[c4, '访问时长(seconds)'].values    #视频观看时长
#       7 Time_24539_V = np.nan_to_num(Time_24539_V)
#       8
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
# ...

# %%
USER_ID[24581].reset_index(inplace=True)
USER_ID[24581].set_index('活动名称', inplace=True)
print(USER_ID[24581].shape) 
# USER_ID[24581]

Time_24581_V = USER_ID[24581].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24581_V = np.nan_to_num(Time_24581_V)

Time_24581_T = USER_ID[24581].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24581_T = np.nan_to_num(Time_24581_T)

Time_24581_H = USER_ID[24581].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24581_H = np.nan_to_num(Time_24581_H)

#(1) Grit
Grit_24581_V = Time_24581_V / c1  #视频观看时长/视频总时长
Grit_24581_T = Time_24581_T / c2   #文本阅读时长/文本页数
Grit_24581_H = Time_24581_H /c3   #作业花费时长/作业问题数

Grit1_24581 = statistics.mean(Grit_24581_V)    #(视频观看时长/视频总时长)的平均
Grit2_24581 = statistics.median(Grit_24581_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24581 = 1/statistics.stdev(Grit_24581_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24581 = 1/(max(Grit_24581_V)-min(Grit_24581_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24581 = statistics.mean(Grit_24581_T)    #(文本阅读时长/文本页数)的平均
Grit6_24581 = statistics.median(Grit_24581_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24581 = 1/statistics.stdev(Grit_24581_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24581 = 1/(max(Grit_24581_T)-min(Grit_24581_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24581 = statistics.mean(Grit_24581_H)    #(作业花费时长/作业问题数)的平均
Grit10_24581 = statistics.median(Grit_24581_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24581 = 1/statistics.stdev(Grit_24581_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24581 = 1/(max(Grit_24581_H)-min(Grit_24581_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24581 = Time_24581_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24581 = Time_24581_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24581 = Time_24581_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24581 = USER_ID[24581].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24581 = np.nan_to_num(Self_control4_24581)
Self_control4_24581 = Self_control4_24581.max()

Self_control5_24581 = USER_ID[24581].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24581 = np.nan_to_num(Self_control5_24581)
Self_control5_24581 = Self_control5_24581.min()

Self_control6_24581 = USER_ID[24581].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24581 = np.nan_to_num(Self_control6_24581)
Self_control6_24581 = Self_control6_24581.sum() 
Self_control6_24581 = Self_control6_24581 / 62

Self_control7_24581 = USER_ID[24581].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24581 = np.nan_to_num(Self_control7_24581)
Self_control7_24581 = Self_control7_24581[20:40].mean()

#(3) Engagement
Engagement_24581_V = Time_24581_V    #视频观看时长
Engagement_24581_T = Time_24581_T    #文本阅读时长
Engagement_24581_H = Time_24581_H    #作业花费时长

Engagement1_24581 = USER_ID[24581].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24581 = np.nan_to_num(Engagement1_24581).sum()

Engagement2_24581 = statistics.mean(Engagement_24581_V)    #平均每次花费在视频学习的时间
Engagement3_24581 = statistics.mean(Engagement_24581_T)    #平均每次花费在文本课件的时间
Engagement4_24581 = statistics.mean(Engagement_24581_H)    #平均每次花费在作业答题的时间
Engagement5_24581 = 62    #学习次数(登入次数)
Engagement6_24581 = 30    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24581 = Time_24581_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24581 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24581 = USER_ID[24581].loc[:, '访问时长(seconds)'].values
Self_perception1_24581 = np.nan_to_num(Self_perception1_24581)

Self_perception1_24581 = 1/((Self_perception1_24581[:20].sum() 
                         - Self_perception1_24581[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24581 = 1/((statistics.mean(Grit_24581_V[:7]) 
                         - statistics.mean(Grit_24581_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24581 = 1/((statistics.mean(Grit_24581_T[:2]) 
                         - statistics.mean(Grit_24581_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24581 = 1/((statistics.mean(Grit_24581_H[:9]) 
                         - statistics.mean(Grit_24581_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24581 = USER_ID[24581].loc[:, ['高过门槛时长']].values
Motivation1_24581 = np.nan_to_num(Motivation1_24581).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24581 = USER_ID[24581].loc[c4, ['高过门槛时长']].values
Motivation2_24581 = np.nan_to_num(Motivation2_24581).sum()
#文挡高过门槛时长总和
Motivation3_24581 = USER_ID[24581].loc[c5, ['高过门槛时长']].values   
Motivation3_24581 = np.nan_to_num(Motivation3_24581).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24581 = np.array(USER_ID[24581].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24581 = np.nan_to_num(Motivation4_24581)
Motivation4_24581 = statistics.mean(Motivation4_24581 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24581 = np.array(USER_ID[24581].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24581 = np.nan_to_num(Motivation5_24581)
Motivation5_24581 = statistics.mean(Motivation5_24581 / c2)

#选修花费总时长
Motivation6_24581 = USER_ID[24581].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24581 = np.nan_to_num(Motivation6_24581).sum()

#(选修花费/页数)的平均
Motivation7_24581 = Motivation6_24581 / (11+8)
Motivation8_24581 = Motivation7_24581/Motivation5_24581    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24581 = 0.97    #完成进度*

# %%
USER_ID[24586].reset_index(inplace=True)
USER_ID[24586].set_index('活动名称', inplace=True)
print(USER_ID[24586].shape) 
# USER_ID[24586]

Time_24586_V = USER_ID[24586].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24586_V = np.nan_to_num(Time_24586_V)

Time_24586_T = USER_ID[24586].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24586_T = np.nan_to_num(Time_24586_T)

Time_24586_H = USER_ID[24586].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24586_H = np.nan_to_num(Time_24586_H)

#(1) Grit
Grit_24586_V = Time_24586_V / c1  #视频观看时长/视频总时长
Grit_24586_T = Time_24586_T / c2   #文本阅读时长/文本页数
Grit_24586_H = Time_24586_H /c3   #作业花费时长/作业问题数

Grit1_24586 = statistics.mean(Grit_24586_V)    #(视频观看时长/视频总时长)的平均
Grit2_24586 = statistics.median(Grit_24586_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24586 = 1/statistics.stdev(Grit_24586_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24586 = 1/(max(Grit_24586_V)-min(Grit_24586_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24586 = statistics.mean(Grit_24586_T)    #(文本阅读时长/文本页数)的平均
Grit6_24586 = statistics.median(Grit_24586_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24586 = 1/statistics.stdev(Grit_24586_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24586 = 1/(max(Grit_24586_T)-min(Grit_24586_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24586 = statistics.mean(Grit_24586_H)    #(作业花费时长/作业问题数)的平均
Grit10_24586 = statistics.median(Grit_24586_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24586 = 1/statistics.stdev(Grit_24586_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24586 = 1/(max(Grit_24586_H)-min(Grit_24586_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24586 = Time_24586_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24586 = Time_24586_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24586 = Time_24586_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24586 = USER_ID[24586].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24586 = np.nan_to_num(Self_control4_24586)
Self_control4_24586 = Self_control4_24586.max()

Self_control5_24586 = USER_ID[24586].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24586 = np.nan_to_num(Self_control5_24586)
Self_control5_24586 = Self_control5_24586.min()

Self_control6_24586 = USER_ID[24586].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24586 = np.nan_to_num(Self_control6_24586)
Self_control6_24586 = Self_control6_24586.sum() 
Self_control6_24586 = Self_control6_24586 / 65

Self_control7_24586 = USER_ID[24586].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24586 = np.nan_to_num(Self_control7_24586)
Self_control7_24586 = Self_control7_24586[20:40].mean()

#(3) Engagement
Engagement_24586_V = Time_24586_V    #视频观看时长
Engagement_24586_T = Time_24586_T    #文本阅读时长
Engagement_24586_H = Time_24586_H    #作业花费时长

Engagement1_24586 = USER_ID[24586].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24586 = np.nan_to_num(Engagement1_24586).sum()

Engagement2_24586 = statistics.mean(Engagement_24586_V)    #平均每次花费在视频学习的时间
Engagement3_24586 = statistics.mean(Engagement_24586_T)    #平均每次花费在文本课件的时间
Engagement4_24586 = statistics.mean(Engagement_24586_H)    #平均每次花费在作业答题的时间
Engagement5_24586 = 65    #学习次数(登入次数)
Engagement6_24586 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24586 = Time_24586_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24586 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24586 = USER_ID[24586].loc[:, '访问时长(seconds)'].values
Self_perception1_24586 = np.nan_to_num(Self_perception1_24586)

Self_perception1_24586 = 1/((Self_perception1_24586[:20].sum() 
                         - Self_perception1_24586[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24586 = 1/((statistics.mean(Grit_24586_V[:7]) 
                         - statistics.mean(Grit_24586_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24586 = 1/((statistics.mean(Grit_24586_T[:2]) 
                         - statistics.mean(Grit_24586_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24586 = 1/((statistics.mean(Grit_24586_H[:9]) 
                         - statistics.mean(Grit_24586_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24586 = USER_ID[24586].loc[:, ['高过门槛时长']].values
Motivation1_24586 = np.nan_to_num(Motivation1_24586).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24586 = USER_ID[24586].loc[c4, ['高过门槛时长']].values
Motivation2_24586 = np.nan_to_num(Motivation2_24586).sum()
#文挡高过门槛时长总和
Motivation3_24586 = USER_ID[24586].loc[c5, ['高过门槛时长']].values   
Motivation3_24586 = np.nan_to_num(Motivation3_24586).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24586 = np.array(USER_ID[24586].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24586 = np.nan_to_num(Motivation4_24586)
Motivation4_24586 = statistics.mean(Motivation4_24586 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24586 = np.array(USER_ID[24586].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24586 = np.nan_to_num(Motivation5_24586)
Motivation5_24586 = statistics.mean(Motivation5_24586 / c2)

#选修花费总时长
Motivation6_24586 = USER_ID[24586].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24586 = np.nan_to_num(Motivation6_24586).sum()

#(选修花费/页数)的平均
Motivation7_24586 = Motivation6_24586 / (11+8)
Motivation8_24586 = Motivation7_24586/Motivation5_24586    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24586 = 1    #完成进度*

# %%
USER_ID[24585].reset_index(inplace=True)
USER_ID[24585].set_index('活动名称', inplace=True)
print(USER_ID[24585].shape) 
# USER_ID[24585]

Time_24585_V = USER_ID[24585].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24585_V = np.nan_to_num(Time_24585_V)

Time_24585_T = USER_ID[24585].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24585_T = np.nan_to_num(Time_24585_T)

Time_24585_H = USER_ID[24585].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24585_H = np.nan_to_num(Time_24585_H)

#(1) Grit
Grit_24585_V = Time_24585_V / c1  #视频观看时长/视频总时长
Grit_24585_T = Time_24585_T / c2   #文本阅读时长/文本页数
Grit_24585_H = Time_24585_H /c3   #作业花费时长/作业问题数

Grit1_24585 = statistics.mean(Grit_24585_V)    #(视频观看时长/视频总时长)的平均
Grit2_24585 = statistics.median(Grit_24585_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24585 = 1/statistics.stdev(Grit_24585_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24585 = 1/(max(Grit_24585_V)-min(Grit_24585_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24585 = statistics.mean(Grit_24585_T)    #(文本阅读时长/文本页数)的平均
Grit6_24585 = statistics.median(Grit_24585_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24585 = 1/statistics.stdev(Grit_24585_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24585 = 1/(max(Grit_24585_T)-min(Grit_24585_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24585 = statistics.mean(Grit_24585_H)    #(作业花费时长/作业问题数)的平均
Grit10_24585 = statistics.median(Grit_24585_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24585 = 1/statistics.stdev(Grit_24585_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24585 = 1/(max(Grit_24585_H)-min(Grit_24585_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24585 = Time_24585_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24585 = Time_24585_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24585 = Time_24585_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24585 = USER_ID[24585].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24585 = np.nan_to_num(Self_control4_24585)
Self_control4_24585 = Self_control4_24585.max()

Self_control5_24585 = USER_ID[24585].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24585 = np.nan_to_num(Self_control5_24585)
Self_control5_24585 = Self_control5_24585.min()

Self_control6_24585 = USER_ID[24585].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24585 = np.nan_to_num(Self_control6_24585)
Self_control6_24585 = Self_control6_24585.sum() 
Self_control6_24585 = Self_control6_24585 / 79

Self_control7_24585 = USER_ID[24585].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24585 = np.nan_to_num(Self_control7_24585)
Self_control7_24585 = Self_control7_24585[20:40].mean()

#(3) Engagement
Engagement_24585_V = Time_24585_V    #视频观看时长
Engagement_24585_T = Time_24585_T    #文本阅读时长
Engagement_24585_H = Time_24585_H    #作业花费时长

Engagement1_24585 = USER_ID[24585].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24585 = np.nan_to_num(Engagement1_24585).sum()

Engagement2_24585 = statistics.mean(Engagement_24585_V)    #平均每次花费在视频学习的时间
Engagement3_24585 = statistics.mean(Engagement_24585_T)    #平均每次花费在文本课件的时间
Engagement4_24585 = statistics.mean(Engagement_24585_H)    #平均每次花费在作业答题的时间
Engagement5_24585 = 79    #学习次数(登入次数)
Engagement6_24585 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24585 = Time_24585_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24585 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24585 = USER_ID[24585].loc[:, '访问时长(seconds)'].values
Self_perception1_24585 = np.nan_to_num(Self_perception1_24585)

Self_perception1_24585 = 1/((Self_perception1_24585[:20].sum() 
                         - Self_perception1_24585[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24585 = 1/((statistics.mean(Grit_24585_V[:7]) 
                         - statistics.mean(Grit_24585_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24585 = 1/((statistics.mean(Grit_24585_T[:2]) 
                         - statistics.mean(Grit_24585_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24585 = 1/((statistics.mean(Grit_24585_H[:9]) 
                         - statistics.mean(Grit_24585_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24585 = USER_ID[24585].loc[:, ['高过门槛时长']].values
Motivation1_24585 = np.nan_to_num(Motivation1_24585).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24585 = USER_ID[24585].loc[c4, ['高过门槛时长']].values
Motivation2_24585 = np.nan_to_num(Motivation2_24585).sum()
#文挡高过门槛时长总和
Motivation3_24585 = USER_ID[24585].loc[c5, ['高过门槛时长']].values   
Motivation3_24585 = np.nan_to_num(Motivation3_24585).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24585 = np.array(USER_ID[24585].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24585 = np.nan_to_num(Motivation4_24585)
Motivation4_24585 = statistics.mean(Motivation4_24585 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24585 = np.array(USER_ID[24585].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24585 = np.nan_to_num(Motivation5_24585)
Motivation5_24585 = statistics.mean(Motivation5_24585 / c2)

#选修花费总时长
Motivation6_24585 = USER_ID[24585].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24585 = np.nan_to_num(Motivation6_24585).sum()

#(选修花费/页数)的平均
Motivation7_24585 = Motivation6_24585 / (11+8)
Motivation8_24585 = Motivation7_24585/Motivation5_24585    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24585 = 1    #完成进度*

# %%
USER_ID[8976].reset_index(inplace=True)
USER_ID[8976].set_index('活动名称', inplace=True)
print(USER_ID[8976].shape) 
# USER_ID[8976]

Time_8976_V = USER_ID[8976].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_8976_V = np.nan_to_num(Time_8976_V)

Time_8976_T = USER_ID[8976].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_8976_T = np.nan_to_num(Time_8976_T)

Time_8976_H = USER_ID[8976].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_8976_H = np.nan_to_num(Time_8976_H)

#(1) Grit
Grit_8976_V = Time_8976_V / c1  #视频观看时长/视频总时长
Grit_8976_T = Time_8976_T / c2   #文本阅读时长/文本页数
Grit_8976_H = Time_8976_H /c3   #作业花费时长/作业问题数

Grit1_8976 = statistics.mean(Grit_8976_V)    #(视频观看时长/视频总时长)的平均
Grit2_8976 = statistics.median(Grit_8976_V)    #(视频观看时长/视频总时长)的中位数
Grit3_8976 = 1/statistics.stdev(Grit_8976_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_8976 = 1/(max(Grit_8976_V)-min(Grit_8976_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_8976 = statistics.mean(Grit_8976_T)    #(文本阅读时长/文本页数)的平均
Grit6_8976 = statistics.median(Grit_8976_T)    #(文本阅读时长/文本页数)的中位数
Grit7_8976 = 1/statistics.stdev(Grit_8976_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_8976 = 1/(max(Grit_8976_T)-min(Grit_8976_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_8976 = statistics.mean(Grit_8976_H)    #(作业花费时长/作业问题数)的平均
Grit10_8976 = statistics.median(Grit_8976_H)    #(作业花费时长/作业问题数)的中位数
Grit11_8976 = 1/statistics.stdev(Grit_8976_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_8976 = 1/(max(Grit_8976_H)-min(Grit_8976_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_8976 = Time_8976_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_8976 = Time_8976_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_8976 = Time_8976_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_8976 = USER_ID[8976].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_8976 = np.nan_to_num(Self_control4_8976)
Self_control4_8976 = Self_control4_8976.max()

Self_control5_8976 = USER_ID[8976].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_8976 = np.nan_to_num(Self_control5_8976)
Self_control5_8976 = Self_control5_8976.min()

Self_control6_8976 = USER_ID[8976].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_8976 = np.nan_to_num(Self_control6_8976)
Self_control6_8976 = Self_control6_8976.sum() 
Self_control6_8976 = Self_control6_8976 / 64

Self_control7_8976 = USER_ID[8976].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_8976 = np.nan_to_num(Self_control7_8976)
Self_control7_8976 = Self_control7_8976[20:40].mean()

#(3) Engagement
Engagement_8976_V = Time_8976_V    #视频观看时长
Engagement_8976_T = Time_8976_T    #文本阅读时长
Engagement_8976_H = Time_8976_H    #作业花费时长

Engagement1_8976 = USER_ID[8976].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_8976 = np.nan_to_num(Engagement1_8976).sum()

Engagement2_8976 = statistics.mean(Engagement_8976_V)    #平均每次花费在视频学习的时间
Engagement3_8976 = statistics.mean(Engagement_8976_T)    #平均每次花费在文本课件的时间
Engagement4_8976 = statistics.mean(Engagement_8976_H)    #平均每次花费在作业答题的时间
Engagement5_8976 = 64    #学习次数(登入次数)
Engagement6_8976 = 15    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_8976 = Time_8976_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_8976 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_8976 = USER_ID[8976].loc[:, '访问时长(seconds)'].values
Self_perception1_8976 = np.nan_to_num(Self_perception1_8976)

Self_perception1_8976 = 1/((Self_perception1_8976[:20].sum() 
                         - Self_perception1_8976[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_8976 = 1/((statistics.mean(Grit_8976_V[:7]) 
                         - statistics.mean(Grit_8976_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_8976 = 1/((statistics.mean(Grit_8976_T[:2]) 
                         - statistics.mean(Grit_8976_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_8976 = 1/((statistics.mean(Grit_8976_H[:9]) 
                         - statistics.mean(Grit_8976_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_8976 = USER_ID[8976].loc[:, ['高过门槛时长']].values
Motivation1_8976 = np.nan_to_num(Motivation1_8976).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_8976 = USER_ID[8976].loc[c4, ['高过门槛时长']].values
Motivation2_8976 = np.nan_to_num(Motivation2_8976).sum()
#文挡高过门槛时长总和
Motivation3_8976 = USER_ID[8976].loc[c5, ['高过门槛时长']].values   
Motivation3_8976 = np.nan_to_num(Motivation3_8976).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_8976 = np.array(USER_ID[8976].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_8976 = np.nan_to_num(Motivation4_8976)
Motivation4_8976 = statistics.mean(Motivation4_8976 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_8976 = np.array(USER_ID[8976].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_8976 = np.nan_to_num(Motivation5_8976)
Motivation5_8976 = statistics.mean(Motivation5_8976 / c2)

#选修花费总时长
Motivation6_8976 = USER_ID[8976].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_8976 = np.nan_to_num(Motivation6_8976).sum()

#(选修花费/页数)的平均
Motivation7_8976 = Motivation6_8976 / (11+8)
Motivation8_8976 = Motivation7_8976/Motivation5_8976    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_8976 = 1    #完成进度*

# %%
USER_ID[24603].reset_index(inplace=True)
USER_ID[24603].set_index('活动名称', inplace=True)
print(USER_ID[24603].shape) 
# USER_ID[24603]

Time_24603_V = USER_ID[24603].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24603_V = np.nan_to_num(Time_24603_V)

Time_24603_T = USER_ID[24603].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24603_T = np.nan_to_num(Time_24603_T)

Time_24603_H = USER_ID[24603].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24603_H = np.nan_to_num(Time_24603_H)

#(1) Grit
Grit_24603_V = Time_24603_V / c1  #视频观看时长/视频总时长
Grit_24603_T = Time_24603_T / c2   #文本阅读时长/文本页数
Grit_24603_H = Time_24603_H /c3   #作业花费时长/作业问题数

Grit1_24603 = statistics.mean(Grit_24603_V)    #(视频观看时长/视频总时长)的平均
Grit2_24603 = statistics.median(Grit_24603_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24603 = 1/statistics.stdev(Grit_24603_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24603 = 1/(max(Grit_24603_V)-min(Grit_24603_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24603 = statistics.mean(Grit_24603_T)    #(文本阅读时长/文本页数)的平均
Grit6_24603 = statistics.median(Grit_24603_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24603 = 1/statistics.stdev(Grit_24603_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24603 = 1/(max(Grit_24603_T)-min(Grit_24603_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24603 = statistics.mean(Grit_24603_H)    #(作业花费时长/作业问题数)的平均
Grit10_24603 = statistics.median(Grit_24603_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24603 = 1/statistics.stdev(Grit_24603_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24603 = 1/(max(Grit_24603_H)-min(Grit_24603_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24603 = Time_24603_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24603 = Time_24603_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24603 = Time_24603_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24603 = USER_ID[24603].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24603 = np.nan_to_num(Self_control4_24603)
Self_control4_24603 = Self_control4_24603.max()

Self_control5_24603 = USER_ID[24603].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24603 = np.nan_to_num(Self_control5_24603)
Self_control5_24603 = Self_control5_24603.min()

Self_control6_24603 = USER_ID[24603].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24603 = np.nan_to_num(Self_control6_24603)
Self_control6_24603 = Self_control6_24603.sum() 
Self_control6_24603 = Self_control6_24603 / 69

Self_control7_24603 = USER_ID[24603].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24603 = np.nan_to_num(Self_control7_24603)
Self_control7_24603 = Self_control7_24603[20:40].mean()

#(3) Engagement
Engagement_24603_V = Time_24603_V    #视频观看时长
Engagement_24603_T = Time_24603_T    #文本阅读时长
Engagement_24603_H = Time_24603_H    #作业花费时长

Engagement1_24603 = USER_ID[24603].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24603 = np.nan_to_num(Engagement1_24603).sum()

Engagement2_24603 = statistics.mean(Engagement_24603_V)    #平均每次花费在视频学习的时间
Engagement3_24603 = statistics.mean(Engagement_24603_T)    #平均每次花费在文本课件的时间
Engagement4_24603 = statistics.mean(Engagement_24603_H)    #平均每次花费在作业答题的时间
Engagement5_24603 = 69    #学习次数(登入次数)
Engagement6_24603 = 15    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24603 = Time_24603_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24603 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24603 = USER_ID[24603].loc[:, '访问时长(seconds)'].values
Self_perception1_24603 = np.nan_to_num(Self_perception1_24603)

Self_perception1_24603 = 1/((Self_perception1_24603[:20].sum() 
                         - Self_perception1_24603[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24603 = 1/((statistics.mean(Grit_24603_V[:7]) 
                         - statistics.mean(Grit_24603_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24603 = 1/((statistics.mean(Grit_24603_T[:2]) 
                         - statistics.mean(Grit_24603_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24603 = 1/((statistics.mean(Grit_24603_H[:9]) 
                         - statistics.mean(Grit_24603_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24603 = USER_ID[24603].loc[:, ['高过门槛时长']].values
Motivation1_24603 = np.nan_to_num(Motivation1_24603).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24603 = USER_ID[24603].loc[c4, ['高过门槛时长']].values
Motivation2_24603 = np.nan_to_num(Motivation2_24603).sum()
#文挡高过门槛时长总和
Motivation3_24603 = USER_ID[24603].loc[c5, ['高过门槛时长']].values   
Motivation3_24603 = np.nan_to_num(Motivation3_24603).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24603 = np.array(USER_ID[24603].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24603 = np.nan_to_num(Motivation4_24603)
Motivation4_24603 = statistics.mean(Motivation4_24603 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24603 = np.array(USER_ID[24603].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24603 = np.nan_to_num(Motivation5_24603)
Motivation5_24603 = statistics.mean(Motivation5_24603 / c2)

#选修花费总时长
Motivation6_24603 = USER_ID[24603].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24603 = np.nan_to_num(Motivation6_24603).sum()

#(选修花费/页数)的平均
Motivation7_24603 = Motivation6_24603 / (11+8)
Motivation8_24603 = Motivation7_24603/Motivation5_24603    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24603 = 1    #完成进度*

# %%
USER_ID[24606].reset_index(inplace=True)
USER_ID[24606].set_index('活动名称', inplace=True)
print(USER_ID[24606].shape) 
# USER_ID[24606]

Time_24606_V = USER_ID[24606].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24606_V = np.nan_to_num(Time_24606_V)

Time_24606_T = USER_ID[24606].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24606_T = np.nan_to_num(Time_24606_T)

Time_24606_H = USER_ID[24606].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24606_H = np.nan_to_num(Time_24606_H)

#(1) Grit
Grit_24606_V = Time_24606_V / c1  #视频观看时长/视频总时长
Grit_24606_T = Time_24606_T / c2   #文本阅读时长/文本页数
Grit_24606_H = Time_24606_H /c3   #作业花费时长/作业问题数

Grit1_24606 = statistics.mean(Grit_24606_V)    #(视频观看时长/视频总时长)的平均
Grit2_24606 = statistics.median(Grit_24606_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24606 = 1/statistics.stdev(Grit_24606_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24606 = 1/(max(Grit_24606_V)-min(Grit_24606_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24606 = statistics.mean(Grit_24606_T)    #(文本阅读时长/文本页数)的平均
Grit6_24606 = statistics.median(Grit_24606_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24606 = 1/statistics.stdev(Grit_24606_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24606 = 1/(max(Grit_24606_T)-min(Grit_24606_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24606 = statistics.mean(Grit_24606_H)    #(作业花费时长/作业问题数)的平均
Grit10_24606 = statistics.median(Grit_24606_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24606 = 1/statistics.stdev(Grit_24606_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24606 = 1/(max(Grit_24606_H)-min(Grit_24606_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24606 = Time_24606_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24606 = Time_24606_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24606 = Time_24606_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24606 = USER_ID[24606].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24606 = np.nan_to_num(Self_control4_24606)
Self_control4_24606 = Self_control4_24606.max()

Self_control5_24606 = USER_ID[24606].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24606 = np.nan_to_num(Self_control5_24606)
Self_control5_24606 = Self_control5_24606.min()

Self_control6_24606 = USER_ID[24606].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24606 = np.nan_to_num(Self_control6_24606)
Self_control6_24606 = Self_control6_24606.sum() 
Self_control6_24606 = Self_control6_24606 / 60

Self_control7_24606 = USER_ID[24606].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24606 = np.nan_to_num(Self_control7_24606)
Self_control7_24606 = Self_control7_24606[20:40].mean()

#(3) Engagement
Engagement_24606_V = Time_24606_V    #视频观看时长
Engagement_24606_T = Time_24606_T    #文本阅读时长
Engagement_24606_H = Time_24606_H    #作业花费时长

Engagement1_24606 = USER_ID[24606].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24606 = np.nan_to_num(Engagement1_24606).sum()

Engagement2_24606 = statistics.mean(Engagement_24606_V)    #平均每次花费在视频学习的时间
Engagement3_24606 = statistics.mean(Engagement_24606_T)    #平均每次花费在文本课件的时间
Engagement4_24606 = statistics.mean(Engagement_24606_H)    #平均每次花费在作业答题的时间
Engagement5_24606 = 60    #学习次数(登入次数)
Engagement6_24606 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24606 = Time_24606_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24606 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24606 = USER_ID[24606].loc[:, '访问时长(seconds)'].values
Self_perception1_24606 = np.nan_to_num(Self_perception1_24606)

Self_perception1_24606 = 1/((Self_perception1_24606[:20].sum() 
                         - Self_perception1_24606[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24606 = 1/((statistics.mean(Grit_24606_V[:7]) 
                         - statistics.mean(Grit_24606_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24606 = 1/((statistics.mean(Grit_24606_T[:2]) 
                         - statistics.mean(Grit_24606_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24606 = 1/((statistics.mean(Grit_24606_H[:9]) 
                         - statistics.mean(Grit_24606_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24606 = USER_ID[24606].loc[:, ['高过门槛时长']].values
Motivation1_24606 = np.nan_to_num(Motivation1_24606).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24606 = USER_ID[24606].loc[c4, ['高过门槛时长']].values
Motivation2_24606 = np.nan_to_num(Motivation2_24606).sum()
#文挡高过门槛时长总和
Motivation3_24606 = USER_ID[24606].loc[c5, ['高过门槛时长']].values   
Motivation3_24606 = np.nan_to_num(Motivation3_24606).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24606 = np.array(USER_ID[24606].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24606 = np.nan_to_num(Motivation4_24606)
Motivation4_24606 = statistics.mean(Motivation4_24606 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24606 = np.array(USER_ID[24606].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24606 = np.nan_to_num(Motivation5_24606)
Motivation5_24606 = statistics.mean(Motivation5_24606 / c2)

#选修花费总时长
Motivation6_24606 = USER_ID[24606].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24606 = np.nan_to_num(Motivation6_24606).sum()

#(选修花费/页数)的平均
Motivation7_24606 = Motivation6_24606 / (11+8)
Motivation8_24606 = Motivation7_24606/Motivation5_24606    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24606 = 1    #完成进度*

# %%
USER_ID[24589].reset_index(inplace=True)
USER_ID[24589].set_index('活动名称', inplace=True)
print(USER_ID[24589].shape) 

# USER_ID[24589]

Time_24589_V = USER_ID[24589].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24589_T = USER_ID[24589].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24589_H = USER_ID[24589].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24589_V = Time_24589_V / c1  #视频观看时长/视频总时长
Grit_24589_T = Time_24589_T / c2   #文本阅读时长/文本页数
Grit_24589_H = Time_24589_H /c3   #作业花费时长/作业问题数

Grit1_24589 = statistics.mean(Grit_24589_V)    #(视频观看时长/视频总时长)的平均
Grit2_24589 = statistics.median(Grit_24589_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24589 = 1/statistics.stdev(Grit_24589_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24589 = 1/(max(Grit_24589_V)-min(Grit_24589_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24589 = statistics.mean(Grit_24589_T)    #(文本阅读时长/文本页数)的平均
Grit6_24589 = statistics.median(Grit_24589_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24589 = 1/statistics.stdev(Grit_24589_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24589 = 1/(max(Grit_24589_T)-min(Grit_24589_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24589 = statistics.mean(Grit_24589_H)    #(作业花费时长/作业问题数)的平均
Grit10_24589 = statistics.median(Grit_24589_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24589 = 1/statistics.stdev(Grit_24589_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24589 = 1/(max(Grit_24589_H)-min(Grit_24589_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24589 = Time_24589_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24589 = Time_24589_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24589 = Time_24589_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24589 = USER_ID[24589].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24589 = Self_control4_24589.max()

Self_control5_24589 = USER_ID[24589].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24589 = Self_control5_24589.min()

Self_control6_24589 = USER_ID[24589].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24589 = Self_control6_24589.sum() 
Self_control6_24589 = Self_control6_24589 / 57

Self_control7_24589 = USER_ID[24589].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24589 = Self_control7_24589[20:40].mean()

#(3) Engagement
Engagement_24589_V = Time_24589_V    #视频观看时长
Engagement_24589_T = Time_24589_T    #文本阅读时长
Engagement_24589_H = Time_24589_H    #作业花费时长

Engagement1_24589 = USER_ID[24589].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24589 = statistics.mean(Engagement_24589_V)    #平均每次花费在视频学习的时间
Engagement3_24589 = statistics.mean(Engagement_24589_T)    #平均每次花费在文本课件的时间
Engagement4_24589 = statistics.mean(Engagement_24589_H)    #平均每次花费在作业答题的时间
Engagement5_24589 = 57    #学习次数(登入次数)
Engagement6_24589 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24589 = Time_24589_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24589 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24589 = USER_ID[24589].loc[:, '访问时长(seconds)'].values
Self_perception1_24589 = 1/((Self_perception1_24589[:20].sum() 
                         - Self_perception1_24589[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24589 = 1/((statistics.mean(Grit_24589_V[:7]) 
                         - statistics.mean(Grit_24589_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24589 = 1/((statistics.mean(Grit_24589_T[:2]) 
                         - statistics.mean(Grit_24589_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24589 = 1/((statistics.mean(Grit_24589_H[:9]) 
                         - statistics.mean(Grit_24589_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24589 = USER_ID[24589].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24589 = USER_ID[24589].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24589 = USER_ID[24589].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24589 = np.array(USER_ID[24589].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24589 = statistics.mean(Motivation4_24589 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24589 = np.array(USER_ID[24589].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24589 = statistics.mean(Motivation5_24589 / c2)

#选修花费总时长
Motivation6_24589 = USER_ID[24589].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24589 = Motivation6_24589 / (11+8)
Motivation8_24589 = Motivation7_24589/Motivation5_24589    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24589 = 0.97    #完成进度*

# %%
USER_ID[24614].reset_index(inplace=True)
USER_ID[24614].set_index('活动名称', inplace=True)
print(USER_ID[24614].shape) 

# USER_ID[24614]

Time_24614_V = USER_ID[24614].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24614_T = USER_ID[24614].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24614_H = USER_ID[24614].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24614_V = Time_24614_V / c1  #视频观看时长/视频总时长
Grit_24614_T = Time_24614_T / c2   #文本阅读时长/文本页数
Grit_24614_H = Time_24614_H /c3   #作业花费时长/作业问题数

Grit1_24614 = statistics.mean(Grit_24614_V)    #(视频观看时长/视频总时长)的平均
Grit2_24614 = statistics.median(Grit_24614_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24614 = 1/statistics.stdev(Grit_24614_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24614 = 1/(max(Grit_24614_V)-min(Grit_24614_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24614 = statistics.mean(Grit_24614_T)    #(文本阅读时长/文本页数)的平均
Grit6_24614 = statistics.median(Grit_24614_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24614 = 1/statistics.stdev(Grit_24614_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24614 = 1/(max(Grit_24614_T)-min(Grit_24614_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24614 = statistics.mean(Grit_24614_H)    #(作业花费时长/作业问题数)的平均
Grit10_24614 = statistics.median(Grit_24614_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24614 = 1/statistics.stdev(Grit_24614_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24614 = 1/(max(Grit_24614_H)-min(Grit_24614_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24614 = Time_24614_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24614 = Time_24614_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24614 = Time_24614_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24614 = USER_ID[24614].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24614 = Self_control4_24614.max()

Self_control5_24614 = USER_ID[24614].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24614 = Self_control5_24614.min()

Self_control6_24614 = USER_ID[24614].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24614 = Self_control6_24614.sum() 
Self_control6_24614 = Self_control6_24614 / 116

Self_control7_24614 = USER_ID[24614].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24614 = Self_control7_24614[20:40].mean()

#(3) Engagement
Engagement_24614_V = Time_24614_V    #视频观看时长
Engagement_24614_T = Time_24614_T    #文本阅读时长
Engagement_24614_H = Time_24614_H    #作业花费时长

Engagement1_24614 = USER_ID[24614].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24614 = statistics.mean(Engagement_24614_V)    #平均每次花费在视频学习的时间
Engagement3_24614 = statistics.mean(Engagement_24614_T)    #平均每次花费在文本课件的时间
Engagement4_24614 = statistics.mean(Engagement_24614_H)    #平均每次花费在作业答题的时间
Engagement5_24614 = 116    #学习次数(登入次数)
Engagement6_24614 = 30    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24614 = Time_24614_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24614 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24614 = USER_ID[24614].loc[:, '访问时长(seconds)'].values
Self_perception1_24614 = 1/((Self_perception1_24614[:20].sum() 
                         - Self_perception1_24614[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24614 = 1/((statistics.mean(Grit_24614_V[:7]) 
                         - statistics.mean(Grit_24614_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24614 = 1/((statistics.mean(Grit_24614_T[:2]) 
                         - statistics.mean(Grit_24614_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24614 = 1/((statistics.mean(Grit_24614_H[:9]) 
                         - statistics.mean(Grit_24614_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24614 = USER_ID[24614].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24614 = USER_ID[24614].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24614 = USER_ID[24614].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24614 = np.array(USER_ID[24614].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24614 = statistics.mean(Motivation4_24614 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24614 = np.array(USER_ID[24614].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24614 = statistics.mean(Motivation5_24614 / c2)

#选修花费总时长
Motivation6_24614 = USER_ID[24614].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24614 = Motivation6_24614 / (11+8)
Motivation8_24614 = Motivation7_24614/Motivation5_24614    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24614 = 1    #完成进度*

# %%
USER_ID[24588].reset_index(inplace=True)
USER_ID[24588].set_index('活动名称', inplace=True)
print(USER_ID[24588].shape) 

# USER_ID[24588]

Time_24588_V = USER_ID[24588].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24588_T = USER_ID[24588].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24588_H = USER_ID[24588].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24588_V = Time_24588_V / c1  #视频观看时长/视频总时长
Grit_24588_T = Time_24588_T / c2   #文本阅读时长/文本页数
Grit_24588_H = Time_24588_H /c3   #作业花费时长/作业问题数

Grit1_24588 = statistics.mean(Grit_24588_V)    #(视频观看时长/视频总时长)的平均
Grit2_24588 = statistics.median(Grit_24588_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24588 = 1/statistics.stdev(Grit_24588_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24588 = 1/(max(Grit_24588_V)-min(Grit_24588_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24588 = statistics.mean(Grit_24588_T)    #(文本阅读时长/文本页数)的平均
Grit6_24588 = statistics.median(Grit_24588_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24588 = 1/statistics.stdev(Grit_24588_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24588 = 1/(max(Grit_24588_T)-min(Grit_24588_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24588 = statistics.mean(Grit_24588_H)    #(作业花费时长/作业问题数)的平均
Grit10_24588 = statistics.median(Grit_24588_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24588 = 1/statistics.stdev(Grit_24588_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24588 = 1/(max(Grit_24588_H)-min(Grit_24588_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24588 = Time_24588_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24588 = Time_24588_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24588 = Time_24588_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24588 = USER_ID[24588].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24588 = Self_control4_24588.max()

Self_control5_24588 = USER_ID[24588].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24588 = Self_control5_24588.min()

Self_control6_24588 = USER_ID[24588].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24588 = Self_control6_24588.sum() 
Self_control6_24588 = Self_control6_24588 / 71

Self_control7_24588 = USER_ID[24588].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24588 = Self_control7_24588[20:40].mean()

#(3) Engagement
Engagement_24588_V = Time_24588_V    #视频观看时长
Engagement_24588_T = Time_24588_T    #文本阅读时长
Engagement_24588_H = Time_24588_H    #作业花费时长

Engagement1_24588 = USER_ID[24588].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24588 = statistics.mean(Engagement_24588_V)    #平均每次花费在视频学习的时间
Engagement3_24588 = statistics.mean(Engagement_24588_T)    #平均每次花费在文本课件的时间
Engagement4_24588 = statistics.mean(Engagement_24588_H)    #平均每次花费在作业答题的时间
Engagement5_24588 = 71    #学习次数(登入次数)
Engagement6_24588 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24588 = Time_24588_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24588 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24588 = USER_ID[24588].loc[:, '访问时长(seconds)'].values
Self_perception1_24588 = 1/((Self_perception1_24588[:20].sum() 
                         - Self_perception1_24588[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24588 = 1/((statistics.mean(Grit_24588_V[:7]) 
                         - statistics.mean(Grit_24588_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24588 = 1/((statistics.mean(Grit_24588_T[:2]) 
                         - statistics.mean(Grit_24588_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24588 = 1/((statistics.mean(Grit_24588_H[:9]) 
                         - statistics.mean(Grit_24588_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24588 = USER_ID[24588].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24588 = USER_ID[24588].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24588 = USER_ID[24588].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24588 = np.array(USER_ID[24588].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24588 = statistics.mean(Motivation4_24588 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24588 = np.array(USER_ID[24588].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24588 = statistics.mean(Motivation5_24588 / c2)

#选修花费总时长
Motivation6_24588 = USER_ID[24588].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24588 = Motivation6_24588 / (11+8)
Motivation8_24588 = Motivation7_24588/Motivation5_24588    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24588 = 1    #完成进度*

# %%
USER_ID[24615].reset_index(inplace=True)
USER_ID[24615].set_index('活动名称', inplace=True)
print(USER_ID[24615].shape) 

# USER_ID[24615]

Time_24615_V = USER_ID[24615].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24615_T = USER_ID[24615].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24615_H = USER_ID[24615].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24615_V = Time_24615_V / c1  #视频观看时长/视频总时长
Grit_24615_T = Time_24615_T / c2   #文本阅读时长/文本页数
Grit_24615_H = Time_24615_H /c3   #作业花费时长/作业问题数

Grit1_24615 = statistics.mean(Grit_24615_V)    #(视频观看时长/视频总时长)的平均
Grit2_24615 = statistics.median(Grit_24615_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24615 = 1/statistics.stdev(Grit_24615_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24615 = 1/(max(Grit_24615_V)-min(Grit_24615_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24615 = statistics.mean(Grit_24615_T)    #(文本阅读时长/文本页数)的平均
Grit6_24615 = statistics.median(Grit_24615_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24615 = 1/statistics.stdev(Grit_24615_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24615 = 1/(max(Grit_24615_T)-min(Grit_24615_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24615 = statistics.mean(Grit_24615_H)    #(作业花费时长/作业问题数)的平均
Grit10_24615 = statistics.median(Grit_24615_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24615 = 1/statistics.stdev(Grit_24615_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24615 = 1/(max(Grit_24615_H)-min(Grit_24615_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24615 = Time_24615_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24615 = Time_24615_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24615 = Time_24615_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24615 = USER_ID[24615].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24615 = Self_control4_24615.max()

Self_control5_24615 = USER_ID[24615].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24615 = Self_control5_24615.min()

Self_control6_24615 = USER_ID[24615].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24615 = Self_control6_24615.sum() 
Self_control6_24615 = Self_control6_24615 / 67

Self_control7_24615 = USER_ID[24615].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24615 = Self_control7_24615[20:40].mean()

#(3) Engagement
Engagement_24615_V = Time_24615_V    #视频观看时长
Engagement_24615_T = Time_24615_T    #文本阅读时长
Engagement_24615_H = Time_24615_H    #作业花费时长

Engagement1_24615 = USER_ID[24615].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24615 = statistics.mean(Engagement_24615_V)    #平均每次花费在视频学习的时间
Engagement3_24615 = statistics.mean(Engagement_24615_T)    #平均每次花费在文本课件的时间
Engagement4_24615 = statistics.mean(Engagement_24615_H)    #平均每次花费在作业答题的时间
Engagement5_24615 = 67    #学习次数(登入次数)
Engagement6_24615 = 21    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24615 = Time_24615_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24615 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24615 = USER_ID[24615].loc[:, '访问时长(seconds)'].values
Self_perception1_24615 = 1/((Self_perception1_24615[:20].sum() 
                         - Self_perception1_24615[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24615 = 1/((statistics.mean(Grit_24615_V[:7]) 
                         - statistics.mean(Grit_24615_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24615 = 1/((statistics.mean(Grit_24615_T[:2]) 
                         - statistics.mean(Grit_24615_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24615 = 1/((statistics.mean(Grit_24615_H[:9]) 
                         - statistics.mean(Grit_24615_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24615 = USER_ID[24615].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24615 = USER_ID[24615].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24615 = USER_ID[24615].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24615 = np.array(USER_ID[24615].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24615 = statistics.mean(Motivation4_24615 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24615 = np.array(USER_ID[24615].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24615 = statistics.mean(Motivation5_24615 / c2)

#选修花费总时长
Motivation6_24615 = USER_ID[24615].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24615 = Motivation6_24615 / (11+8)
Motivation8_24615 = Motivation7_24615/Motivation5_24615    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24615 = 1    #完成进度*

# %%
USER_ID[24617].reset_index(inplace=True)
USER_ID[24617].set_index('活动名称', inplace=True)
print(USER_ID[24617].shape) 

# USER_ID[24617]

Time_24617_V = USER_ID[24617].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24617_T = USER_ID[24617].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24617_H = USER_ID[24617].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24617_V = Time_24617_V / c1  #视频观看时长/视频总时长
Grit_24617_T = Time_24617_T / c2   #文本阅读时长/文本页数
Grit_24617_H = Time_24617_H /c3   #作业花费时长/作业问题数

Grit1_24617 = statistics.mean(Grit_24617_V)    #(视频观看时长/视频总时长)的平均
Grit2_24617 = statistics.median(Grit_24617_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24617 = 1/statistics.stdev(Grit_24617_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24617 = 1/(max(Grit_24617_V)-min(Grit_24617_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24617 = statistics.mean(Grit_24617_T)    #(文本阅读时长/文本页数)的平均
Grit6_24617 = statistics.median(Grit_24617_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24617 = 1/statistics.stdev(Grit_24617_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24617 = 1/(max(Grit_24617_T)-min(Grit_24617_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24617 = statistics.mean(Grit_24617_H)    #(作业花费时长/作业问题数)的平均
Grit10_24617 = statistics.median(Grit_24617_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24617 = 1/statistics.stdev(Grit_24617_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24617 = 1/(max(Grit_24617_H)-min(Grit_24617_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24617 = Time_24617_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24617 = Time_24617_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24617 = Time_24617_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24617 = USER_ID[24617].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24617 = Self_control4_24617.max()

Self_control5_24617 = USER_ID[24617].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24617 = Self_control5_24617.min()

Self_control6_24617 = USER_ID[24617].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24617 = Self_control6_24617.sum() 
Self_control6_24617 = Self_control6_24617 / 67

Self_control7_24617 = USER_ID[24617].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24617 = Self_control7_24617[20:40].mean()

#(3) Engagement
Engagement_24617_V = Time_24617_V    #视频观看时长
Engagement_24617_T = Time_24617_T    #文本阅读时长
Engagement_24617_H = Time_24617_H    #作业花费时长

Engagement1_24617 = USER_ID[24617].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24617 = statistics.mean(Engagement_24617_V)    #平均每次花费在视频学习的时间
Engagement3_24617 = statistics.mean(Engagement_24617_T)    #平均每次花费在文本课件的时间
Engagement4_24617 = statistics.mean(Engagement_24617_H)    #平均每次花费在作业答题的时间
Engagement5_24617 = 67    #学习次数(登入次数)
Engagement6_24617 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24617 = Time_24617_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24617 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24617 = USER_ID[24617].loc[:, '访问时长(seconds)'].values
Self_perception1_24617 = 1/((Self_perception1_24617[:20].sum() 
                         - Self_perception1_24617[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24617 = 1/((statistics.mean(Grit_24617_V[:7]) 
                         - statistics.mean(Grit_24617_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24617 = 1/((statistics.mean(Grit_24617_T[:2]) 
                         - statistics.mean(Grit_24617_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24617 = 1/((statistics.mean(Grit_24617_H[:9]) 
                         - statistics.mean(Grit_24617_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24617 = USER_ID[24617].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24617 = USER_ID[24617].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24617 = USER_ID[24617].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24617 = np.array(USER_ID[24617].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24617 = statistics.mean(Motivation4_24617 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24617 = np.array(USER_ID[24617].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24617 = statistics.mean(Motivation5_24617 / c2)

#选修花费总时长
Motivation6_24617 = USER_ID[24617].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24617 = Motivation6_24617 / (11+8)
Motivation8_24617 = Motivation7_24617/Motivation5_24617    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24617 = 1    #完成进度*

# %%
USER_ID[24587].reset_index(inplace=True)
USER_ID[24587].set_index('活动名称', inplace=True)
print(USER_ID[24587].shape) 

# USER_ID[24587]

Time_24587_V = USER_ID[24587].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24587_T = USER_ID[24587].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24587_H = USER_ID[24587].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24587_V = Time_24587_V / c1  #视频观看时长/视频总时长
Grit_24587_T = Time_24587_T / c2   #文本阅读时长/文本页数
Grit_24587_H = Time_24587_H /c3   #作业花费时长/作业问题数

Grit1_24587 = statistics.mean(Grit_24587_V)    #(视频观看时长/视频总时长)的平均
Grit2_24587 = statistics.median(Grit_24587_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24587 = 1/statistics.stdev(Grit_24587_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24587 = 1/(max(Grit_24587_V)-min(Grit_24587_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24587 = statistics.mean(Grit_24587_T)    #(文本阅读时长/文本页数)的平均
Grit6_24587 = statistics.median(Grit_24587_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24587 = 1/statistics.stdev(Grit_24587_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24587 = 1/(max(Grit_24587_T)-min(Grit_24587_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24587 = statistics.mean(Grit_24587_H)    #(作业花费时长/作业问题数)的平均
Grit10_24587 = statistics.median(Grit_24587_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24587 = 1/statistics.stdev(Grit_24587_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24587 = 1/(max(Grit_24587_H)-min(Grit_24587_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24587 = Time_24587_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24587 = Time_24587_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24587 = Time_24587_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24587 = USER_ID[24587].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24587 = Self_control4_24587.max()

Self_control5_24587 = USER_ID[24587].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24587 = Self_control5_24587.min()

Self_control6_24587 = USER_ID[24587].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24587 = Self_control6_24587.sum() 
Self_control6_24587 = Self_control6_24587 / 69

Self_control7_24587 = USER_ID[24587].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24587 = Self_control7_24587[20:40].mean()

#(3) Engagement
Engagement_24587_V = Time_24587_V    #视频观看时长
Engagement_24587_T = Time_24587_T    #文本阅读时长
Engagement_24587_H = Time_24587_H    #作业花费时长

Engagement1_24587 = USER_ID[24587].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24587 = statistics.mean(Engagement_24587_V)    #平均每次花费在视频学习的时间
Engagement3_24587 = statistics.mean(Engagement_24587_T)    #平均每次花费在文本课件的时间
Engagement4_24587 = statistics.mean(Engagement_24587_H)    #平均每次花费在作业答题的时间
Engagement5_24587 = 69    #学习次数(登入次数)
Engagement6_24587 = 6    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24587 = Time_24587_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24587 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24587 = USER_ID[24587].loc[:, '访问时长(seconds)'].values
Self_perception1_24587 = 1/((Self_perception1_24587[:20].sum() 
                         - Self_perception1_24587[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24587 = 1/((statistics.mean(Grit_24587_V[:7]) 
                         - statistics.mean(Grit_24587_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24587 = 1/((statistics.mean(Grit_24587_T[:2]) 
                         - statistics.mean(Grit_24587_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24587 = 1/((statistics.mean(Grit_24587_H[:9]) 
                         - statistics.mean(Grit_24587_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24587 = USER_ID[24587].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24587 = USER_ID[24587].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24587 = USER_ID[24587].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24587 = np.array(USER_ID[24587].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24587 = statistics.mean(Motivation4_24587 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24587 = np.array(USER_ID[24587].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24587 = statistics.mean(Motivation5_24587 / c2)

#选修花费总时长
Motivation6_24587 = USER_ID[24587].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24587 = Motivation6_24587 / (11+8)
Motivation8_24587 = Motivation7_24587/Motivation5_24587    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24587 = 1    #完成进度*

# %%
USER_ID[24628].reset_index(inplace=True)
USER_ID[24628].set_index('活动名称', inplace=True)
print(USER_ID[24628].shape) 

# USER_ID[24628]

Time_24628_V = USER_ID[24628].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24628_T = USER_ID[24628].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24628_H = USER_ID[24628].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24628_V = Time_24628_V / c1  #视频观看时长/视频总时长
Grit_24628_T = Time_24628_T / c2   #文本阅读时长/文本页数
Grit_24628_H = Time_24628_H /c3   #作业花费时长/作业问题数

Grit1_24628 = statistics.mean(Grit_24628_V)    #(视频观看时长/视频总时长)的平均
Grit2_24628 = statistics.median(Grit_24628_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24628 = 1/statistics.stdev(Grit_24628_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24628 = 1/(max(Grit_24628_V)-min(Grit_24628_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24628 = statistics.mean(Grit_24628_T)    #(文本阅读时长/文本页数)的平均
Grit6_24628 = statistics.median(Grit_24628_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24628 = 1/statistics.stdev(Grit_24628_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24628 = 1/(max(Grit_24628_T)-min(Grit_24628_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24628 = statistics.mean(Grit_24628_H)    #(作业花费时长/作业问题数)的平均
Grit10_24628 = statistics.median(Grit_24628_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24628 = 1/statistics.stdev(Grit_24628_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24628 = 1/(max(Grit_24628_H)-min(Grit_24628_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24628 = Time_24628_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24628 = Time_24628_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24628 = Time_24628_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24628 = USER_ID[24628].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24628 = Self_control4_24628.max()

Self_control5_24628 = USER_ID[24628].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24628 = Self_control5_24628.min()

Self_control6_24628 = USER_ID[24628].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24628 = Self_control6_24628.sum() 
Self_control6_24628 = Self_control6_24628 / 62

Self_control7_24628 = USER_ID[24628].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24628 = Self_control7_24628[20:40].mean()

#(3) Engagement
Engagement_24628_V = Time_24628_V    #视频观看时长
Engagement_24628_T = Time_24628_T    #文本阅读时长
Engagement_24628_H = Time_24628_H    #作业花费时长

Engagement1_24628 = USER_ID[24628].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24628 = statistics.mean(Engagement_24628_V)    #平均每次花费在视频学习的时间
Engagement3_24628 = statistics.mean(Engagement_24628_T)    #平均每次花费在文本课件的时间
Engagement4_24628 = statistics.mean(Engagement_24628_H)    #平均每次花费在作业答题的时间
Engagement5_24628 = 62    #学习次数(登入次数)
Engagement6_24628 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24628 = Time_24628_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24628 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24628 = USER_ID[24628].loc[:, '访问时长(seconds)'].values
Self_perception1_24628 = 1/((Self_perception1_24628[:20].sum() 
                         - Self_perception1_24628[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24628 = 1/((statistics.mean(Grit_24628_V[:7]) 
                         - statistics.mean(Grit_24628_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24628 = 1/((statistics.mean(Grit_24628_T[:2]) 
                         - statistics.mean(Grit_24628_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24628 = 1/((statistics.mean(Grit_24628_H[:9]) 
                         - statistics.mean(Grit_24628_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24628 = USER_ID[24628].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24628 = USER_ID[24628].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24628 = USER_ID[24628].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24628 = np.array(USER_ID[24628].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24628 = statistics.mean(Motivation4_24628 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24628 = np.array(USER_ID[24628].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24628 = statistics.mean(Motivation5_24628 / c2)

#选修花费总时长
Motivation6_24628 = USER_ID[24628].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24628 = Motivation6_24628 / (11+8)
Motivation8_24628 = Motivation7_24628/Motivation5_24628    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24628 = 1    #完成进度*

# %%
USER_ID[24638].reset_index(inplace=True)
USER_ID[24638].set_index('活动名称', inplace=True)
print(USER_ID[24638].shape) 

# USER_ID[24638]

Time_24638_V = USER_ID[24638].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24638_T = USER_ID[24638].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24638_H = USER_ID[24638].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24638_V = Time_24638_V / c1  #视频观看时长/视频总时长
Grit_24638_T = Time_24638_T / c2   #文本阅读时长/文本页数
Grit_24638_H = Time_24638_H /c3   #作业花费时长/作业问题数

Grit1_24638 = statistics.mean(Grit_24638_V)    #(视频观看时长/视频总时长)的平均
Grit2_24638 = statistics.median(Grit_24638_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24638 = 1/statistics.stdev(Grit_24638_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24638 = 1/(max(Grit_24638_V)-min(Grit_24638_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24638 = statistics.mean(Grit_24638_T)    #(文本阅读时长/文本页数)的平均
Grit6_24638 = statistics.median(Grit_24638_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24638 = 1/statistics.stdev(Grit_24638_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24638 = 1/(max(Grit_24638_T)-min(Grit_24638_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24638 = statistics.mean(Grit_24638_H)    #(作业花费时长/作业问题数)的平均
Grit10_24638 = statistics.median(Grit_24638_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24638 = 1/statistics.stdev(Grit_24638_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24638 = 1/(max(Grit_24638_H)-min(Grit_24638_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24638 = Time_24638_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24638 = Time_24638_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24638 = Time_24638_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24638 = USER_ID[24638].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24638 = Self_control4_24638.max()

Self_control5_24638 = USER_ID[24638].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24638 = Self_control5_24638.min()

Self_control6_24638 = USER_ID[24638].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24638 = Self_control6_24638.sum() 
Self_control6_24638 = Self_control6_24638 / 61

Self_control7_24638 = USER_ID[24638].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24638 = Self_control7_24638[20:40].mean()

#(3) Engagement
Engagement_24638_V = Time_24638_V    #视频观看时长
Engagement_24638_T = Time_24638_T    #文本阅读时长
Engagement_24638_H = Time_24638_H    #作业花费时长

Engagement1_24638 = USER_ID[24638].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24638 = statistics.mean(Engagement_24638_V)    #平均每次花费在视频学习的时间
Engagement3_24638 = statistics.mean(Engagement_24638_T)    #平均每次花费在文本课件的时间
Engagement4_24638 = statistics.mean(Engagement_24638_H)    #平均每次花费在作业答题的时间
Engagement5_24638 = 61    #学习次数(登入次数)
Engagement6_24638 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24638 = Time_24638_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24638 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24638 = USER_ID[24638].loc[:, '访问时长(seconds)'].values
Self_perception1_24638 = 1/((Self_perception1_24638[:20].sum() 
                         - Self_perception1_24638[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24638 = 1/((statistics.mean(Grit_24638_V[:7]) 
                         - statistics.mean(Grit_24638_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24638 = 1/((statistics.mean(Grit_24638_T[:2]) 
                         - statistics.mean(Grit_24638_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24638 = 1/((statistics.mean(Grit_24638_H[:9]) 
                         - statistics.mean(Grit_24638_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24638 = USER_ID[24638].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24638 = USER_ID[24638].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24638 = USER_ID[24638].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24638 = np.array(USER_ID[24638].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24638 = statistics.mean(Motivation4_24638 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24638 = np.array(USER_ID[24638].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24638 = statistics.mean(Motivation5_24638 / c2)

#选修花费总时长
Motivation6_24638 = USER_ID[24638].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24638 = Motivation6_24638 / (11+8)
Motivation8_24638 = Motivation7_24638/Motivation5_24638    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24638 = 1    #完成进度*

# %%
USER_ID[1623].reset_index(inplace=True)
USER_ID[1623].set_index('活动名称', inplace=True)
print(USER_ID[1623].shape) 

# USER_ID[1623]

Time_1623_V = USER_ID[1623].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_1623_T = USER_ID[1623].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_1623_H = USER_ID[1623].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_1623_V = Time_1623_V / c1  #视频观看时长/视频总时长
Grit_1623_T = Time_1623_T / c2   #文本阅读时长/文本页数
Grit_1623_H = Time_1623_H /c3   #作业花费时长/作业问题数

Grit1_1623 = statistics.mean(Grit_1623_V)    #(视频观看时长/视频总时长)的平均
Grit2_1623 = statistics.median(Grit_1623_V)    #(视频观看时长/视频总时长)的中位数
Grit3_1623 = 1/statistics.stdev(Grit_1623_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_1623 = 1/(max(Grit_1623_V)-min(Grit_1623_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_1623 = statistics.mean(Grit_1623_T)    #(文本阅读时长/文本页数)的平均
Grit6_1623 = statistics.median(Grit_1623_T)    #(文本阅读时长/文本页数)的中位数
Grit7_1623 = 1/statistics.stdev(Grit_1623_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_1623 = 1/(max(Grit_1623_T)-min(Grit_1623_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_1623 = statistics.mean(Grit_1623_H)    #(作业花费时长/作业问题数)的平均
Grit10_1623 = statistics.median(Grit_1623_H)    #(作业花费时长/作业问题数)的中位数
Grit11_1623 = 1/statistics.stdev(Grit_1623_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_1623 = 1/(max(Grit_1623_H)-min(Grit_1623_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_1623 = Time_1623_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_1623 = Time_1623_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_1623 = Time_1623_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_1623 = USER_ID[1623].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_1623 = Self_control4_1623.max()

Self_control5_1623 = USER_ID[1623].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_1623 = Self_control5_1623.min()

Self_control6_1623 = USER_ID[1623].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_1623 = Self_control6_1623.sum() 
Self_control6_1623 = Self_control6_1623 / 60

Self_control7_1623 = USER_ID[1623].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_1623 = Self_control7_1623[20:40].mean()

#(3) Engagement
Engagement_1623_V = Time_1623_V    #视频观看时长
Engagement_1623_T = Time_1623_T    #文本阅读时长
Engagement_1623_H = Time_1623_H    #作业花费时长

Engagement1_1623 = USER_ID[1623].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_1623 = statistics.mean(Engagement_1623_V)    #平均每次花费在视频学习的时间
Engagement3_1623 = statistics.mean(Engagement_1623_T)    #平均每次花费在文本课件的时间
Engagement4_1623 = statistics.mean(Engagement_1623_H)    #平均每次花费在作业答题的时间
Engagement5_1623 = 60    #学习次数(登入次数)
Engagement6_1623 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_1623 = Time_1623_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_1623 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_1623 = USER_ID[1623].loc[:, '访问时长(seconds)'].values
Self_perception1_1623 = 1/((Self_perception1_1623[:20].sum() 
                         - Self_perception1_1623[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_1623 = 1/((statistics.mean(Grit_1623_V[:7]) 
                         - statistics.mean(Grit_1623_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_1623 = 1/((statistics.mean(Grit_1623_T[:2]) 
                         - statistics.mean(Grit_1623_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_1623 = 1/((statistics.mean(Grit_1623_H[:9]) 
                         - statistics.mean(Grit_1623_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_1623 = USER_ID[1623].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_1623 = USER_ID[1623].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_1623 = USER_ID[1623].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_1623 = np.array(USER_ID[1623].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_1623 = statistics.mean(Motivation4_1623 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_1623 = np.array(USER_ID[1623].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_1623 = statistics.mean(Motivation5_1623 / c2)

#选修花费总时长
Motivation6_1623 = USER_ID[1623].loc[['延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_1623 = Motivation6_1623 / (11+8)
Motivation8_1623 = Motivation7_1623/Motivation5_1623    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_1623 = 0.97    #完成进度*

# %%
USER_ID[24647].reset_index(inplace=True)
USER_ID[24647].set_index('活动名称', inplace=True)
print(USER_ID[24647].shape) 

# USER_ID[24647]

Time_24647_V = USER_ID[24647].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24647_T = USER_ID[24647].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24647_H = USER_ID[24647].loc[c6, '访问时长(seconds)'].values    #作业花费时长
#(1) Grit
Grit_24647_V = Time_24647_V / c1  #视频观看时长/视频总时长
Grit_24647_T = Time_24647_T / c2   #文本阅读时长/文本页数
Grit_24647_H = Time_24647_H /c3   #作业花费时长/作业问题数

Grit1_24647 = statistics.mean(Grit_24647_V)    #(视频观看时长/视频总时长)的平均
Grit2_24647 = statistics.median(Grit_24647_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24647 = 1/statistics.stdev(Grit_24647_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24647 = 1/(max(Grit_24647_V)-min(Grit_24647_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24647 = statistics.mean(Grit_24647_T)    #(文本阅读时长/文本页数)的平均
Grit6_24647 = statistics.median(Grit_24647_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24647 = 1/statistics.stdev(Grit_24647_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24647 = 1/(max(Grit_24647_T)-min(Grit_24647_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24647 = statistics.mean(Grit_24647_H)    #(作业花费时长/作业问题数)的平均
Grit10_24647 = statistics.median(Grit_24647_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24647 = 1/statistics.stdev(Grit_24647_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24647 = 1/(max(Grit_24647_H)-min(Grit_24647_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24647 = Time_24647_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24647 = Time_24647_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24647 = Time_24647_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24647 = USER_ID[24647].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24647 = Self_control4_24647.max()

Self_control5_24647 = USER_ID[24647].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24647 = Self_control5_24647.min()

Self_control6_24647 = USER_ID[24647].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24647 = Self_control6_24647.sum() 
Self_control6_24647 = Self_control6_24647 / 62

Self_control7_24647 = USER_ID[24647].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24647 = Self_control7_24647[20:40].mean()

#(3) Engagement
Engagement_24647_V = Time_24647_V    #视频观看时长
Engagement_24647_T = Time_24647_T    #文本阅读时长
Engagement_24647_H = Time_24647_H    #作业花费时长

Engagement1_24647 = USER_ID[24647].loc[:, '访问时长(seconds)'].sum()    #学习总时长
Engagement2_24647 = statistics.mean(Engagement_24647_V)    #平均每次花费在视频学习的时间
Engagement3_24647 = statistics.mean(Engagement_24647_T)    #平均每次花费在文本课件的时间
Engagement4_24647 = statistics.mean(Engagement_24647_H)    #平均每次花费在作业答题的时间
Engagement5_24647 = 62    #学习次数(登入次数)
Engagement6_24647 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24647 = Time_24647_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24647 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24647 = USER_ID[24647].loc[:, '访问时长(seconds)'].values
Self_perception1_24647 = 1/((Self_perception1_24647[:20].sum() 
                         - Self_perception1_24647[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24647 = 1/((statistics.mean(Grit_24647_V[:7]) 
                         - statistics.mean(Grit_24647_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24647 = 1/((statistics.mean(Grit_24647_T[:2]) 
                         - statistics.mean(Grit_24647_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24647 = 1/((statistics.mean(Grit_24647_H[:9]) 
                         - statistics.mean(Grit_24647_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24647 = USER_ID[24647].loc[:, ['高过门槛时长']].values.sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24647 = USER_ID[24647].loc[c4, ['高过门槛时长']].values.sum()
#文挡高过门槛时长总和
Motivation3_24647 = USER_ID[24647].loc[c5, ['高过门槛时长']].values.sum()                                     
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24647 = np.array(USER_ID[24647].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24647 = statistics.mean(Motivation4_24647 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24647 = np.array(USER_ID[24647].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24647 = statistics.mean(Motivation5_24647 / c2)

#选修花费总时长
Motivation6_24647 = USER_ID[24647].loc[['延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values.sum()
#(选修花费/页数)的平均
Motivation7_24647 = Motivation6_24647 / (11+8)
Motivation8_24647 = Motivation7_24647/Motivation5_24647    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24647 = 0.97    #完成进度*

# %%
USER_ID[24618].reset_index(inplace=True)
USER_ID[24618].set_index('活动名称', inplace=True)
print(USER_ID[24618].shape) 

# USER_ID[24618]

Time_24618_V = USER_ID[24618].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24618_V = np.nan_to_num(Time_24618_V)

Time_24618_T = USER_ID[24618].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24618_T = np.nan_to_num(Time_24618_T)

Time_24618_H = USER_ID[24618].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24618_H = np.nan_to_num(Time_24618_H)

#(1) Grit
Grit_24618_V = Time_24618_V / c1  #视频观看时长/视频总时长
Grit_24618_T = Time_24618_T / c2   #文本阅读时长/文本页数
Grit_24618_H = Time_24618_H /c3   #作业花费时长/作业问题数

Grit1_24618 = statistics.mean(Grit_24618_V)    #(视频观看时长/视频总时长)的平均
Grit2_24618 = statistics.median(Grit_24618_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24618 = 1/statistics.stdev(Grit_24618_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24618 = 1/(max(Grit_24618_V)-min(Grit_24618_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24618 = statistics.mean(Grit_24618_T)    #(文本阅读时长/文本页数)的平均
Grit6_24618 = statistics.median(Grit_24618_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24618 = 1/statistics.stdev(Grit_24618_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24618 = 1/(max(Grit_24618_T)-min(Grit_24618_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24618 = statistics.mean(Grit_24618_H)    #(作业花费时长/作业问题数)的平均
Grit10_24618 = statistics.median(Grit_24618_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24618 = 1/statistics.stdev(Grit_24618_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24618 = 1/(max(Grit_24618_H)-min(Grit_24618_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24618 = Time_24618_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24618 = Time_24618_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24618 = Time_24618_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24618 = USER_ID[24618].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24618 = np.nan_to_num(Self_control4_24618)
Self_control4_24618 = Self_control4_24618.max()

Self_control5_24618 = USER_ID[24618].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24618 = np.nan_to_num(Self_control5_24618)
Self_control5_24618 = Self_control5_24618.min()

Self_control6_24618 = USER_ID[24618].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24618 = np.nan_to_num(Self_control6_24618)
Self_control6_24618 = Self_control6_24618.sum() 
Self_control6_24618 = Self_control6_24618 / 58

Self_control7_24618 = USER_ID[24618].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24618 = np.nan_to_num(Self_control7_24618)
Self_control7_24618 = Self_control7_24618[20:40].mean()

#(3) Engagement
Engagement_24618_V = Time_24618_V    #视频观看时长
Engagement_24618_T = Time_24618_T    #文本阅读时长
Engagement_24618_H = Time_24618_H    #作业花费时长

Engagement1_24618 = USER_ID[24618].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24618 = np.nan_to_num(Engagement1_24618).sum()

Engagement2_24618 = statistics.mean(Engagement_24618_V)    #平均每次花费在视频学习的时间
Engagement3_24618 = statistics.mean(Engagement_24618_T)    #平均每次花费在文本课件的时间
Engagement4_24618 = statistics.mean(Engagement_24618_H)    #平均每次花费在作业答题的时间
Engagement5_24618 = 58    #学习次数(登入次数)
Engagement6_24618 = 15    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24618 = Time_24618_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24618 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24618 = USER_ID[24618].loc[:, '访问时长(seconds)'].values
Self_perception1_24618 = np.nan_to_num(Self_perception1_24618)

Self_perception1_24618 = 1/((Self_perception1_24618[:20].sum() 
                         - Self_perception1_24618[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24618 = 1/((statistics.mean(Grit_24618_V[:7]) 
                         - statistics.mean(Grit_24618_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24618 = 1/((statistics.mean(Grit_24618_T[:2]) 
                         - statistics.mean(Grit_24618_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24618 = 1/((statistics.mean(Grit_24618_H[:9]) 
                         - statistics.mean(Grit_24618_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24618 = USER_ID[24618].loc[:, ['高过门槛时长']].values
Motivation1_24618 = np.nan_to_num(Motivation1_24618).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24618 = USER_ID[24618].loc[c4, ['高过门槛时长']].values
Motivation2_24618 = np.nan_to_num(Motivation2_24618).sum()
#文挡高过门槛时长总和
Motivation3_24618 = USER_ID[24618].loc[c5, ['高过门槛时长']].values   
Motivation3_24618 = np.nan_to_num(Motivation3_24618).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24618 = np.array(USER_ID[24618].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24618 = np.nan_to_num(Motivation4_24618)
Motivation4_24618 = statistics.mean(Motivation4_24618 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24618 = np.array(USER_ID[24618].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24618 = np.nan_to_num(Motivation5_24618)
Motivation5_24618 = statistics.mean(Motivation5_24618 / c2)

#选修花费总时长
Motivation6_24618 = USER_ID[24618].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24618 = np.nan_to_num(Motivation6_24618).sum()

#(选修花费/页数)的平均
Motivation7_24618 = Motivation6_24618 / (11+8)
Motivation8_24618 = Motivation7_24618/Motivation5_24618    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24618 = 1    #完成进度*

# %%
USER_ID[4388].reset_index(inplace=True)
USER_ID[4388].set_index('活动名称', inplace=True)
print(USER_ID[4388].shape) 

# USER_ID[4388]

Time_4388_V = USER_ID[4388].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_4388_V = np.nan_to_num(Time_4388_V)

Time_4388_T = USER_ID[4388].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_4388_T = np.nan_to_num(Time_4388_T)

Time_4388_H = USER_ID[4388].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_4388_H = np.nan_to_num(Time_4388_H)

#(1) Grit
Grit_4388_V = Time_4388_V / c1  #视频观看时长/视频总时长
Grit_4388_T = Time_4388_T / c2   #文本阅读时长/文本页数
Grit_4388_H = Time_4388_H /c3   #作业花费时长/作业问题数

Grit1_4388 = statistics.mean(Grit_4388_V)    #(视频观看时长/视频总时长)的平均
Grit2_4388 = statistics.median(Grit_4388_V)    #(视频观看时长/视频总时长)的中位数
Grit3_4388 = 1/statistics.stdev(Grit_4388_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_4388 = 1/(max(Grit_4388_V)-min(Grit_4388_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_4388 = statistics.mean(Grit_4388_T)    #(文本阅读时长/文本页数)的平均
Grit6_4388 = statistics.median(Grit_4388_T)    #(文本阅读时长/文本页数)的中位数
Grit7_4388 = 1/statistics.stdev(Grit_4388_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_4388 = 1/(max(Grit_4388_T)-min(Grit_4388_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_4388 = statistics.mean(Grit_4388_H)    #(作业花费时长/作业问题数)的平均
Grit10_4388 = statistics.median(Grit_4388_H)    #(作业花费时长/作业问题数)的中位数
Grit11_4388 = 1/statistics.stdev(Grit_4388_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_4388 = 1/(max(Grit_4388_H)-min(Grit_4388_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_4388 = Time_4388_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_4388 = Time_4388_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_4388 = Time_4388_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_4388 = USER_ID[4388].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_4388 = np.nan_to_num(Self_control4_4388)
Self_control4_4388 = Self_control4_4388.max()

Self_control5_4388 = USER_ID[4388].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_4388 = np.nan_to_num(Self_control5_4388)
Self_control5_4388 = Self_control5_4388.min()

Self_control6_4388 = USER_ID[4388].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_4388 = np.nan_to_num(Self_control6_4388)
Self_control6_4388 = Self_control6_4388.sum() 
Self_control6_4388 = Self_control6_4388 / 66

Self_control7_4388 = USER_ID[4388].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_4388 = np.nan_to_num(Self_control7_4388)
Self_control7_4388 = Self_control7_4388[20:40].mean()

#(3) Engagement
Engagement_4388_V = Time_4388_V    #视频观看时长
Engagement_4388_T = Time_4388_T    #文本阅读时长
Engagement_4388_H = Time_4388_H    #作业花费时长

Engagement1_4388 = USER_ID[4388].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_4388 = np.nan_to_num(Engagement1_4388).sum()

Engagement2_4388 = statistics.mean(Engagement_4388_V)    #平均每次花费在视频学习的时间
Engagement3_4388 = statistics.mean(Engagement_4388_T)    #平均每次花费在文本课件的时间
Engagement4_4388 = statistics.mean(Engagement_4388_H)    #平均每次花费在作业答题的时间
Engagement5_4388 = 66    #学习次数(登入次数)
Engagement6_4388 = 30    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_4388 = Time_4388_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_4388 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_4388 = USER_ID[4388].loc[:, '访问时长(seconds)'].values
Self_perception1_4388 = np.nan_to_num(Self_perception1_4388)

Self_perception1_4388 = 1/((Self_perception1_4388[:20].sum() 
                         - Self_perception1_4388[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_4388 = 1/((statistics.mean(Grit_4388_V[:7]) 
                         - statistics.mean(Grit_4388_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_4388 = 1/((statistics.mean(Grit_4388_T[:2]) 
                         - statistics.mean(Grit_4388_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_4388 = 1/((statistics.mean(Grit_4388_H[:9]) 
                         - statistics.mean(Grit_4388_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_4388 = USER_ID[4388].loc[:, ['高过门槛时长']].values
Motivation1_4388 = np.nan_to_num(Motivation1_4388).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_4388 = USER_ID[4388].loc[c4, ['高过门槛时长']].values
Motivation2_4388 = np.nan_to_num(Motivation2_4388).sum()
#文挡高过门槛时长总和
Motivation3_4388 = USER_ID[4388].loc[c5, ['高过门槛时长']].values   
Motivation3_4388 = np.nan_to_num(Motivation3_4388).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_4388 = np.array(USER_ID[4388].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_4388 = np.nan_to_num(Motivation4_4388)
Motivation4_4388 = statistics.mean(Motivation4_4388 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_4388 = np.array(USER_ID[4388].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_4388 = np.nan_to_num(Motivation5_4388)
Motivation5_4388 = statistics.mean(Motivation5_4388 / c2)

#选修花费总时长
Motivation6_4388 = USER_ID[4388].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_4388 = np.nan_to_num(Motivation6_4388).sum()

#(选修花费/页数)的平均
Motivation7_4388 = Motivation6_4388 / (11+8)
Motivation8_4388 = Motivation7_4388/Motivation5_4388    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_4388 = 0.97    #完成进度*

# %%
USER_ID[24671].reset_index(inplace=True)
USER_ID[24671].set_index('活动名称', inplace=True)
print(USER_ID[24671].shape) 

# USER_ID[24671]

Time_24671_V = USER_ID[24671].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24671_V = np.nan_to_num(Time_24671_V)

Time_24671_T = USER_ID[24671].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24671_T = np.nan_to_num(Time_24671_T)

Time_24671_H = USER_ID[24671].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24671_H = np.nan_to_num(Time_24671_H)

#(1) Grit
Grit_24671_V = Time_24671_V / c1  #视频观看时长/视频总时长
Grit_24671_T = Time_24671_T / c2   #文本阅读时长/文本页数
Grit_24671_H = Time_24671_H /c3   #作业花费时长/作业问题数

Grit1_24671 = statistics.mean(Grit_24671_V)    #(视频观看时长/视频总时长)的平均
Grit2_24671 = statistics.median(Grit_24671_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24671 = 1/statistics.stdev(Grit_24671_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24671 = 1/(max(Grit_24671_V)-min(Grit_24671_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24671 = statistics.mean(Grit_24671_T)    #(文本阅读时长/文本页数)的平均
Grit6_24671 = statistics.median(Grit_24671_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24671 = 1/statistics.stdev(Grit_24671_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24671 = 1/(max(Grit_24671_T)-min(Grit_24671_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24671 = statistics.mean(Grit_24671_H)    #(作业花费时长/作业问题数)的平均
Grit10_24671 = statistics.median(Grit_24671_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24671 = 1/statistics.stdev(Grit_24671_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24671 = 1/(max(Grit_24671_H)-min(Grit_24671_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24671 = Time_24671_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24671 = Time_24671_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24671 = Time_24671_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24671 = USER_ID[24671].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24671 = np.nan_to_num(Self_control4_24671)
Self_control4_24671 = Self_control4_24671.max()

Self_control5_24671 = USER_ID[24671].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24671 = np.nan_to_num(Self_control5_24671)
Self_control5_24671 = Self_control5_24671.min()

Self_control6_24671 = USER_ID[24671].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24671 = np.nan_to_num(Self_control6_24671)
Self_control6_24671 = Self_control6_24671.sum() 
Self_control6_24671 = Self_control6_24671 / 56

Self_control7_24671 = USER_ID[24671].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24671 = np.nan_to_num(Self_control7_24671)
Self_control7_24671 = Self_control7_24671[20:40].mean()

#(3) Engagement
Engagement_24671_V = Time_24671_V    #视频观看时长
Engagement_24671_T = Time_24671_T    #文本阅读时长
Engagement_24671_H = Time_24671_H    #作业花费时长

Engagement1_24671 = USER_ID[24671].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24671 = np.nan_to_num(Engagement1_24671).sum()

Engagement2_24671 = statistics.mean(Engagement_24671_V)    #平均每次花费在视频学习的时间
Engagement3_24671 = statistics.mean(Engagement_24671_T)    #平均每次花费在文本课件的时间
Engagement4_24671 = statistics.mean(Engagement_24671_H)    #平均每次花费在作业答题的时间
Engagement5_24671 = 56    #学习次数(登入次数)
Engagement6_24671 = 30    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24671 = Time_24671_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24671 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24671 = USER_ID[24671].loc[:, '访问时长(seconds)'].values
Self_perception1_24671 = np.nan_to_num(Self_perception1_24671)

Self_perception1_24671 = 1/((Self_perception1_24671[:20].sum() 
                         - Self_perception1_24671[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24671 = 1/((statistics.mean(Grit_24671_V[:7]) 
                         - statistics.mean(Grit_24671_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24671 = 1/((statistics.mean(Grit_24671_T[:2]) 
                         - statistics.mean(Grit_24671_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24671 = 1/((statistics.mean(Grit_24671_H[:9]) 
                         - statistics.mean(Grit_24671_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24671 = USER_ID[24671].loc[:, ['高过门槛时长']].values
Motivation1_24671 = np.nan_to_num(Motivation1_24671).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24671 = USER_ID[24671].loc[c4, ['高过门槛时长']].values
Motivation2_24671 = np.nan_to_num(Motivation2_24671).sum()
#文挡高过门槛时长总和
Motivation3_24671 = USER_ID[24671].loc[c5, ['高过门槛时长']].values   
Motivation3_24671 = np.nan_to_num(Motivation3_24671).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24671 = np.array(USER_ID[24671].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24671 = np.nan_to_num(Motivation4_24671)
Motivation4_24671 = statistics.mean(Motivation4_24671 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24671 = np.array(USER_ID[24671].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24671 = np.nan_to_num(Motivation5_24671)
Motivation5_24671 = statistics.mean(Motivation5_24671 / c2)

#选修花费总时长
Motivation6_24671 = USER_ID[24671].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24671 = np.nan_to_num(Motivation6_24671).sum()

#(选修花费/页数)的平均
Motivation7_24671 = Motivation6_24671 / (11+8)
Motivation8_24671 = Motivation7_24671/Motivation5_24671    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24671 = 1    #完成进度*

# %%
USER_ID[24681].reset_index(inplace=True)
USER_ID[24681].set_index('活动名称', inplace=True)
print(USER_ID[24681].shape) 

# USER_ID[24681]

Time_24681_V = USER_ID[24681].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24681_V = np.nan_to_num(Time_24681_V)

Time_24681_T = USER_ID[24681].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24681_T = np.nan_to_num(Time_24681_T)

Time_24681_H = USER_ID[24681].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24681_H = np.nan_to_num(Time_24681_H)

#(1) Grit
Grit_24681_V = Time_24681_V / c1  #视频观看时长/视频总时长
Grit_24681_T = Time_24681_T / c2   #文本阅读时长/文本页数
Grit_24681_H = Time_24681_H /c3   #作业花费时长/作业问题数

Grit1_24681 = statistics.mean(Grit_24681_V)    #(视频观看时长/视频总时长)的平均
Grit2_24681 = statistics.median(Grit_24681_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24681 = 1/statistics.stdev(Grit_24681_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24681 = 1/(max(Grit_24681_V)-min(Grit_24681_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24681 = statistics.mean(Grit_24681_T)    #(文本阅读时长/文本页数)的平均
Grit6_24681 = statistics.median(Grit_24681_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24681 = 1/statistics.stdev(Grit_24681_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24681 = 1/(max(Grit_24681_T)-min(Grit_24681_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24681 = statistics.mean(Grit_24681_H)    #(作业花费时长/作业问题数)的平均
Grit10_24681 = statistics.median(Grit_24681_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24681 = 1/statistics.stdev(Grit_24681_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24681 = 1/(max(Grit_24681_H)-min(Grit_24681_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24681 = Time_24681_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24681 = Time_24681_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24681 = Time_24681_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24681 = USER_ID[24681].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24681 = np.nan_to_num(Self_control4_24681)
Self_control4_24681 = Self_control4_24681.max()

Self_control5_24681 = USER_ID[24681].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24681 = np.nan_to_num(Self_control5_24681)
Self_control5_24681 = Self_control5_24681.min()

Self_control6_24681 = USER_ID[24681].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24681 = np.nan_to_num(Self_control6_24681)
Self_control6_24681 = Self_control6_24681.sum() 
Self_control6_24681 = Self_control6_24681 / 61

Self_control7_24681 = USER_ID[24681].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24681 = np.nan_to_num(Self_control7_24681)
Self_control7_24681 = Self_control7_24681[20:40].mean()

#(3) Engagement
Engagement_24681_V = Time_24681_V    #视频观看时长
Engagement_24681_T = Time_24681_T    #文本阅读时长
Engagement_24681_H = Time_24681_H    #作业花费时长

Engagement1_24681 = USER_ID[24681].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24681 = np.nan_to_num(Engagement1_24681).sum()

Engagement2_24681 = statistics.mean(Engagement_24681_V)    #平均每次花费在视频学习的时间
Engagement3_24681 = statistics.mean(Engagement_24681_T)    #平均每次花费在文本课件的时间
Engagement4_24681 = statistics.mean(Engagement_24681_H)    #平均每次花费在作业答题的时间
Engagement5_24681 = 61    #学习次数(登入次数)
Engagement6_24681 = 9    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24681 = Time_24681_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24681 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24681 = USER_ID[24681].loc[:, '访问时长(seconds)'].values
Self_perception1_24681 = np.nan_to_num(Self_perception1_24681)

Self_perception1_24681 = 1/((Self_perception1_24681[:20].sum() 
                         - Self_perception1_24681[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24681 = 1/((statistics.mean(Grit_24681_V[:7]) 
                         - statistics.mean(Grit_24681_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24681 = 1/((statistics.mean(Grit_24681_T[:2]) 
                         - statistics.mean(Grit_24681_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24681 = 1/((statistics.mean(Grit_24681_H[:9]) 
                         - statistics.mean(Grit_24681_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24681 = USER_ID[24681].loc[:, ['高过门槛时长']].values
Motivation1_24681 = np.nan_to_num(Motivation1_24681).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24681 = USER_ID[24681].loc[c4, ['高过门槛时长']].values
Motivation2_24681 = np.nan_to_num(Motivation2_24681).sum()
#文挡高过门槛时长总和
Motivation3_24681 = USER_ID[24681].loc[c5, ['高过门槛时长']].values   
Motivation3_24681 = np.nan_to_num(Motivation3_24681).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24681 = np.array(USER_ID[24681].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24681 = np.nan_to_num(Motivation4_24681)
Motivation4_24681 = statistics.mean(Motivation4_24681 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24681 = np.array(USER_ID[24681].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24681 = np.nan_to_num(Motivation5_24681)
Motivation5_24681 = statistics.mean(Motivation5_24681 / c2)

#选修花费总时长
Motivation6_24681 = USER_ID[24681].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24681 = np.nan_to_num(Motivation6_24681).sum()

#(选修花费/页数)的平均
Motivation7_24681 = Motivation6_24681 / (11+8)
Motivation8_24681 = Motivation7_24681/Motivation5_24681    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24681 = 1    #完成进度*

# %%
USER_ID[24691].reset_index(inplace=True)
USER_ID[24691].set_index('活动名称', inplace=True)
print(USER_ID[24691].shape) 

# USER_ID[24691]

Time_24691_V = USER_ID[24691].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24691_V = np.nan_to_num(Time_24691_V)

Time_24691_T = USER_ID[24691].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24691_T = np.nan_to_num(Time_24691_T)

Time_24691_H = USER_ID[24691].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24691_H = np.nan_to_num(Time_24691_H)

#(1) Grit
Grit_24691_V = Time_24691_V / c1  #视频观看时长/视频总时长
Grit_24691_T = Time_24691_T / c2   #文本阅读时长/文本页数
Grit_24691_H = Time_24691_H /c3   #作业花费时长/作业问题数

Grit1_24691 = statistics.mean(Grit_24691_V)    #(视频观看时长/视频总时长)的平均
Grit2_24691 = statistics.median(Grit_24691_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24691 = 1/statistics.stdev(Grit_24691_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24691 = 1/(max(Grit_24691_V)-min(Grit_24691_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24691 = statistics.mean(Grit_24691_T)    #(文本阅读时长/文本页数)的平均
Grit6_24691 = statistics.median(Grit_24691_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24691 = 1/statistics.stdev(Grit_24691_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24691 = 1/(max(Grit_24691_T)-min(Grit_24691_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24691 = statistics.mean(Grit_24691_H)    #(作业花费时长/作业问题数)的平均
Grit10_24691 = statistics.median(Grit_24691_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24691 = 1/statistics.stdev(Grit_24691_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24691 = 1/(max(Grit_24691_H)-min(Grit_24691_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24691 = Time_24691_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24691 = Time_24691_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24691 = Time_24691_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24691 = USER_ID[24691].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24691 = np.nan_to_num(Self_control4_24691)
Self_control4_24691 = Self_control4_24691.max()

Self_control5_24691 = USER_ID[24691].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24691 = np.nan_to_num(Self_control5_24691)
Self_control5_24691 = Self_control5_24691.min()

Self_control6_24691 = USER_ID[24691].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24691 = np.nan_to_num(Self_control6_24691)
Self_control6_24691 = Self_control6_24691.sum() 
Self_control6_24691 = Self_control6_24691 / 65

Self_control7_24691 = USER_ID[24691].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24691 = np.nan_to_num(Self_control7_24691)
Self_control7_24691 = Self_control7_24691[20:40].mean()

#(3) Engagement
Engagement_24691_V = Time_24691_V    #视频观看时长
Engagement_24691_T = Time_24691_T    #文本阅读时长
Engagement_24691_H = Time_24691_H    #作业花费时长

Engagement1_24691 = USER_ID[24691].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24691 = np.nan_to_num(Engagement1_24691).sum()

Engagement2_24691 = statistics.mean(Engagement_24691_V)    #平均每次花费在视频学习的时间
Engagement3_24691 = statistics.mean(Engagement_24691_T)    #平均每次花费在文本课件的时间
Engagement4_24691 = statistics.mean(Engagement_24691_H)    #平均每次花费在作业答题的时间
Engagement5_24691 = 65    #学习次数(登入次数)
Engagement6_24691 = 0    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24691 = Time_24691_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24691 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24691 = USER_ID[24691].loc[:, '访问时长(seconds)'].values
Self_perception1_24691 = np.nan_to_num(Self_perception1_24691)

Self_perception1_24691 = 1/((Self_perception1_24691[:20].sum() 
                         - Self_perception1_24691[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24691 = 1/((statistics.mean(Grit_24691_V[:7]) 
                         - statistics.mean(Grit_24691_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24691 = 1/((statistics.mean(Grit_24691_T[:2]) 
                         - statistics.mean(Grit_24691_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24691 = 1/((statistics.mean(Grit_24691_H[:9]) 
                         - statistics.mean(Grit_24691_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24691 = USER_ID[24691].loc[:, ['高过门槛时长']].values
Motivation1_24691 = np.nan_to_num(Motivation1_24691).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24691 = USER_ID[24691].loc[c4, ['高过门槛时长']].values
Motivation2_24691 = np.nan_to_num(Motivation2_24691).sum()
#文挡高过门槛时长总和
Motivation3_24691 = USER_ID[24691].loc[c5, ['高过门槛时长']].values   
Motivation3_24691 = np.nan_to_num(Motivation3_24691).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24691 = np.array(USER_ID[24691].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24691 = np.nan_to_num(Motivation4_24691)
Motivation4_24691 = statistics.mean(Motivation4_24691 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24691 = np.array(USER_ID[24691].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24691 = np.nan_to_num(Motivation5_24691)
Motivation5_24691 = statistics.mean(Motivation5_24691 / c2)

#选修花费总时长
Motivation6_24691 = USER_ID[24691].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24691 = np.nan_to_num(Motivation6_24691).sum()

#(选修花费/页数)的平均
Motivation7_24691 = Motivation6_24691 / (11+8)
Motivation8_24691 = Motivation7_24691/Motivation5_24691    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24691 = 0.97    #完成进度*

# %%
USER_ID[3458].reset_index(inplace=True)
USER_ID[3458].set_index('活动名称', inplace=True)
print(USER_ID[3458].shape) 

# USER_ID[3458]

Time_3458_V = USER_ID[3458].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_3458_V = np.nan_to_num(Time_3458_V)

Time_3458_T = USER_ID[3458].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_3458_T = np.nan_to_num(Time_3458_T)

Time_3458_H = USER_ID[3458].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_3458_H = np.nan_to_num(Time_3458_H)

#(1) Grit
Grit_3458_V = Time_3458_V / c1  #视频观看时长/视频总时长
Grit_3458_T = Time_3458_T / c2   #文本阅读时长/文本页数
Grit_3458_H = Time_3458_H /c3   #作业花费时长/作业问题数

Grit1_3458 = statistics.mean(Grit_3458_V)    #(视频观看时长/视频总时长)的平均
Grit2_3458 = statistics.median(Grit_3458_V)    #(视频观看时长/视频总时长)的中位数
Grit3_3458 = 1/statistics.stdev(Grit_3458_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_3458 = 1/(max(Grit_3458_V)-min(Grit_3458_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_3458 = statistics.mean(Grit_3458_T)    #(文本阅读时长/文本页数)的平均
Grit6_3458 = statistics.median(Grit_3458_T)    #(文本阅读时长/文本页数)的中位数
Grit7_3458 = 1/statistics.stdev(Grit_3458_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_3458 = 1/(max(Grit_3458_T)-min(Grit_3458_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_3458 = statistics.mean(Grit_3458_H)    #(作业花费时长/作业问题数)的平均
Grit10_3458 = statistics.median(Grit_3458_H)    #(作业花费时长/作业问题数)的中位数
Grit11_3458 = 1/statistics.stdev(Grit_3458_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_3458 = 1/(max(Grit_3458_H)-min(Grit_3458_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_3458 = Time_3458_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_3458 = Time_3458_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_3458 = Time_3458_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_3458 = USER_ID[3458].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_3458 = np.nan_to_num(Self_control4_3458)
Self_control4_3458 = Self_control4_3458.max()

Self_control5_3458 = USER_ID[3458].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_3458 = np.nan_to_num(Self_control5_3458)
Self_control5_3458 = Self_control5_3458.min()

Self_control6_3458 = USER_ID[3458].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_3458 = np.nan_to_num(Self_control6_3458)
Self_control6_3458 = Self_control6_3458.sum() 
Self_control6_3458 = Self_control6_3458 / 77

Self_control7_3458 = USER_ID[3458].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_3458 = np.nan_to_num(Self_control7_3458)
Self_control7_3458 = Self_control7_3458[20:40].mean()

#(3) Engagement
Engagement_3458_V = Time_3458_V    #视频观看时长
Engagement_3458_T = Time_3458_T    #文本阅读时长
Engagement_3458_H = Time_3458_H    #作业花费时长

Engagement1_3458 = USER_ID[3458].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_3458 = np.nan_to_num(Engagement1_3458).sum()

Engagement2_3458 = statistics.mean(Engagement_3458_V)    #平均每次花费在视频学习的时间
Engagement3_3458 = statistics.mean(Engagement_3458_T)    #平均每次花费在文本课件的时间
Engagement4_3458 = statistics.mean(Engagement_3458_H)    #平均每次花费在作业答题的时间
Engagement5_3458 = 77    #学习次数(登入次数)
Engagement6_3458 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_3458 = Time_3458_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_3458 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_3458 = USER_ID[3458].loc[:, '访问时长(seconds)'].values
Self_perception1_3458 = np.nan_to_num(Self_perception1_3458)

Self_perception1_3458 = 1/((Self_perception1_3458[:20].sum() 
                         - Self_perception1_3458[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_3458 = 1/((statistics.mean(Grit_3458_V[:7]) 
                         - statistics.mean(Grit_3458_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_3458 = 1/((statistics.mean(Grit_3458_T[:2]) 
                         - statistics.mean(Grit_3458_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_3458 = 1/((statistics.mean(Grit_3458_H[:9]) 
                         - statistics.mean(Grit_3458_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_3458 = USER_ID[3458].loc[:, ['高过门槛时长']].values
Motivation1_3458 = np.nan_to_num(Motivation1_3458).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_3458 = USER_ID[3458].loc[c4, ['高过门槛时长']].values
Motivation2_3458 = np.nan_to_num(Motivation2_3458).sum()
#文挡高过门槛时长总和
Motivation3_3458 = USER_ID[3458].loc[c5, ['高过门槛时长']].values   
Motivation3_3458 = np.nan_to_num(Motivation3_3458).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_3458 = np.array(USER_ID[3458].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_3458 = np.nan_to_num(Motivation4_3458)
Motivation4_3458 = statistics.mean(Motivation4_3458 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_3458 = np.array(USER_ID[3458].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_3458 = np.nan_to_num(Motivation5_3458)
Motivation5_3458 = statistics.mean(Motivation5_3458 / c2)

#选修花费总时长
Motivation6_3458 = USER_ID[3458].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_3458 = np.nan_to_num(Motivation6_3458).sum()

#(选修花费/页数)的平均
Motivation7_3458 = Motivation6_3458 / (11+8)
Motivation8_3458 = Motivation7_3458/Motivation5_3458    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_3458 = 1    #完成进度*

# %%
USER_ID[1613].reset_index(inplace=True)
USER_ID[1613].set_index('活动名称', inplace=True)
print(USER_ID[1613].shape) 

# USER_ID[1613]

Time_1613_V = USER_ID[1613].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_1613_V = np.nan_to_num(Time_1613_V)

Time_1613_T = USER_ID[1613].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_1613_T = np.nan_to_num(Time_1613_T)

Time_1613_H = USER_ID[1613].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_1613_H = np.nan_to_num(Time_1613_H)

#(1) Grit
Grit_1613_V = Time_1613_V / c1  #视频观看时长/视频总时长
Grit_1613_T = Time_1613_T / c2   #文本阅读时长/文本页数
Grit_1613_H = Time_1613_H /c3   #作业花费时长/作业问题数

Grit1_1613 = statistics.mean(Grit_1613_V)    #(视频观看时长/视频总时长)的平均
Grit2_1613 = statistics.median(Grit_1613_V)    #(视频观看时长/视频总时长)的中位数
Grit3_1613 = 1/statistics.stdev(Grit_1613_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_1613 = 1/(max(Grit_1613_V)-min(Grit_1613_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_1613 = statistics.mean(Grit_1613_T)    #(文本阅读时长/文本页数)的平均
Grit6_1613 = statistics.median(Grit_1613_T)    #(文本阅读时长/文本页数)的中位数
Grit7_1613 = 1/statistics.stdev(Grit_1613_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_1613 = 1/(max(Grit_1613_T)-min(Grit_1613_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_1613 = statistics.mean(Grit_1613_H)    #(作业花费时长/作业问题数)的平均
Grit10_1613 = statistics.median(Grit_1613_H)    #(作业花费时长/作业问题数)的中位数
Grit11_1613 = 1/statistics.stdev(Grit_1613_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_1613 = 1/(max(Grit_1613_H)-min(Grit_1613_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_1613 = Time_1613_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_1613 = Time_1613_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_1613 = Time_1613_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_1613 = USER_ID[1613].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_1613 = np.nan_to_num(Self_control4_1613)
Self_control4_1613 = Self_control4_1613.max()

Self_control5_1613 = USER_ID[1613].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_1613 = np.nan_to_num(Self_control5_1613)
Self_control5_1613 = Self_control5_1613.min()

Self_control6_1613 = USER_ID[1613].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_1613 = np.nan_to_num(Self_control6_1613)
Self_control6_1613 = Self_control6_1613.sum() 
Self_control6_1613 = Self_control6_1613 / 61

Self_control7_1613 = USER_ID[1613].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_1613 = np.nan_to_num(Self_control7_1613)
Self_control7_1613 = Self_control7_1613[20:40].mean()

#(3) Engagement
Engagement_1613_V = Time_1613_V    #视频观看时长
Engagement_1613_T = Time_1613_T    #文本阅读时长
Engagement_1613_H = Time_1613_H    #作业花费时长

Engagement1_1613 = USER_ID[1613].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_1613 = np.nan_to_num(Engagement1_1613).sum()

Engagement2_1613 = statistics.mean(Engagement_1613_V)    #平均每次花费在视频学习的时间
Engagement3_1613 = statistics.mean(Engagement_1613_T)    #平均每次花费在文本课件的时间
Engagement4_1613 = statistics.mean(Engagement_1613_H)    #平均每次花费在作业答题的时间
Engagement5_1613 = 61    #学习次数(登入次数)
Engagement6_1613 = 24    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_1613 = Time_1613_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_1613 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_1613 = USER_ID[1613].loc[:, '访问时长(seconds)'].values
Self_perception1_1613 = np.nan_to_num(Self_perception1_1613)

Self_perception1_1613 = 1/((Self_perception1_1613[:20].sum() 
                         - Self_perception1_1613[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_1613 = 1/((statistics.mean(Grit_1613_V[:7]) 
                         - statistics.mean(Grit_1613_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_1613 = 1/((statistics.mean(Grit_1613_T[:2]) 
                         - statistics.mean(Grit_1613_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_1613 = 1/((statistics.mean(Grit_1613_H[:9]) 
                         - statistics.mean(Grit_1613_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_1613 = USER_ID[1613].loc[:, ['高过门槛时长']].values
Motivation1_1613 = np.nan_to_num(Motivation1_1613).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_1613 = USER_ID[1613].loc[c4, ['高过门槛时长']].values
Motivation2_1613 = np.nan_to_num(Motivation2_1613).sum()
#文挡高过门槛时长总和
Motivation3_1613 = USER_ID[1613].loc[c5, ['高过门槛时长']].values   
Motivation3_1613 = np.nan_to_num(Motivation3_1613).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_1613 = np.array(USER_ID[1613].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_1613 = np.nan_to_num(Motivation4_1613)
Motivation4_1613 = statistics.mean(Motivation4_1613 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_1613 = np.array(USER_ID[1613].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_1613 = np.nan_to_num(Motivation5_1613)
Motivation5_1613 = statistics.mean(Motivation5_1613 / c2)

#选修花费总时长
Motivation6_1613 = USER_ID[1613].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_1613 = np.nan_to_num(Motivation6_1613).sum()

#(选修花费/页数)的平均
Motivation7_1613 = Motivation6_1613 / (11+8)
Motivation8_1613 = Motivation7_1613/Motivation5_1613    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_1613 = 1    #完成进度*

# %%
USER_ID[8889].reset_index(inplace=True)
USER_ID[8889].set_index('活动名称', inplace=True)
print(USER_ID[8889].shape) 

# USER_ID[8889]

Time_8889_V = USER_ID[8889].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_8889_V = np.nan_to_num(Time_8889_V)

Time_8889_T = USER_ID[8889].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_8889_T = np.nan_to_num(Time_8889_T)

Time_8889_H = USER_ID[8889].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_8889_H = np.nan_to_num(Time_8889_H)

#(1) Grit
Grit_8889_V = Time_8889_V / c1  #视频观看时长/视频总时长
Grit_8889_T = Time_8889_T / c2   #文本阅读时长/文本页数
Grit_8889_H = Time_8889_H /c3   #作业花费时长/作业问题数

Grit1_8889 = statistics.mean(Grit_8889_V)    #(视频观看时长/视频总时长)的平均
Grit2_8889 = statistics.median(Grit_8889_V)    #(视频观看时长/视频总时长)的中位数
Grit3_8889 = 1/statistics.stdev(Grit_8889_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_8889 = 1/(max(Grit_8889_V)-min(Grit_8889_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_8889 = statistics.mean(Grit_8889_T)    #(文本阅读时长/文本页数)的平均
Grit6_8889 = statistics.median(Grit_8889_T)    #(文本阅读时长/文本页数)的中位数
Grit7_8889 = 1/statistics.stdev(Grit_8889_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_8889 = 1/(max(Grit_8889_T)-min(Grit_8889_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_8889 = statistics.mean(Grit_8889_H)    #(作业花费时长/作业问题数)的平均
Grit10_8889 = statistics.median(Grit_8889_H)    #(作业花费时长/作业问题数)的中位数
Grit11_8889 = 1/statistics.stdev(Grit_8889_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_8889 = 1/(max(Grit_8889_H)-min(Grit_8889_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_8889 = Time_8889_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_8889 = Time_8889_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_8889 = Time_8889_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_8889 = USER_ID[8889].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_8889 = np.nan_to_num(Self_control4_8889)
Self_control4_8889 = Self_control4_8889.max()

Self_control5_8889 = USER_ID[8889].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_8889 = np.nan_to_num(Self_control5_8889)
Self_control5_8889 = Self_control5_8889.min()

Self_control6_8889 = USER_ID[8889].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_8889 = np.nan_to_num(Self_control6_8889)
Self_control6_8889 = Self_control6_8889.sum() 
Self_control6_8889 = Self_control6_8889 / 64

Self_control7_8889 = USER_ID[8889].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_8889 = np.nan_to_num(Self_control7_8889)
Self_control7_8889 = Self_control7_8889[20:40].mean()

#(3) Engagement
Engagement_8889_V = Time_8889_V    #视频观看时长
Engagement_8889_T = Time_8889_T    #文本阅读时长
Engagement_8889_H = Time_8889_H    #作业花费时长

Engagement1_8889 = USER_ID[8889].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_8889 = np.nan_to_num(Engagement1_8889).sum()

Engagement2_8889 = statistics.mean(Engagement_8889_V)    #平均每次花费在视频学习的时间
Engagement3_8889 = statistics.mean(Engagement_8889_T)    #平均每次花费在文本课件的时间
Engagement4_8889 = statistics.mean(Engagement_8889_H)    #平均每次花费在作业答题的时间
Engagement5_8889 = 64    #学习次数(登入次数)
Engagement6_8889 = 6    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_8889 = Time_8889_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_8889 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_8889 = USER_ID[8889].loc[:, '访问时长(seconds)'].values
Self_perception1_8889 = np.nan_to_num(Self_perception1_8889)

Self_perception1_8889 = 1/((Self_perception1_8889[:20].sum() 
                         - Self_perception1_8889[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_8889 = 1/((statistics.mean(Grit_8889_V[:7]) 
                         - statistics.mean(Grit_8889_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_8889 = 1/((statistics.mean(Grit_8889_T[:2]) 
                         - statistics.mean(Grit_8889_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_8889 = 1/((statistics.mean(Grit_8889_H[:9]) 
                         - statistics.mean(Grit_8889_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_8889 = USER_ID[8889].loc[:, ['高过门槛时长']].values
Motivation1_8889 = np.nan_to_num(Motivation1_8889).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_8889 = USER_ID[8889].loc[c4, ['高过门槛时长']].values
Motivation2_8889 = np.nan_to_num(Motivation2_8889).sum()
#文挡高过门槛时长总和
Motivation3_8889 = USER_ID[8889].loc[c5, ['高过门槛时长']].values   
Motivation3_8889 = np.nan_to_num(Motivation3_8889).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_8889 = np.array(USER_ID[8889].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_8889 = np.nan_to_num(Motivation4_8889)
Motivation4_8889 = statistics.mean(Motivation4_8889 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_8889 = np.array(USER_ID[8889].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_8889 = np.nan_to_num(Motivation5_8889)
Motivation5_8889 = statistics.mean(Motivation5_8889 / c2)

#选修花费总时长
Motivation6_8889 = USER_ID[8889].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_8889 = np.nan_to_num(Motivation6_8889).sum()

#(选修花费/页数)的平均
Motivation7_8889 = Motivation6_8889 / (11+8)
Motivation8_8889 = Motivation7_8889/Motivation5_8889    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_8889 = 1    #完成进度*

# %%
USER_ID[24701].reset_index(inplace=True)
USER_ID[24701].set_index('活动名称', inplace=True)
print(USER_ID[24701].shape) 

# USER_ID[24701]

Time_24701_V = USER_ID[24701].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24701_V = np.nan_to_num(Time_24701_V)

Time_24701_T = USER_ID[24701].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24701_T = np.nan_to_num(Time_24701_T)

Time_24701_H = USER_ID[24701].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24701_H = np.nan_to_num(Time_24701_H)

#(1) Grit
Grit_24701_V = Time_24701_V / c1  #视频观看时长/视频总时长
Grit_24701_T = Time_24701_T / c2   #文本阅读时长/文本页数
Grit_24701_H = Time_24701_H /c3   #作业花费时长/作业问题数

Grit1_24701 = statistics.mean(Grit_24701_V)    #(视频观看时长/视频总时长)的平均
Grit2_24701 = statistics.median(Grit_24701_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24701 = 1/statistics.stdev(Grit_24701_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24701 = 1/(max(Grit_24701_V)-min(Grit_24701_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24701 = statistics.mean(Grit_24701_T)    #(文本阅读时长/文本页数)的平均
Grit6_24701 = statistics.median(Grit_24701_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24701 = 1/statistics.stdev(Grit_24701_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24701 = 1/(max(Grit_24701_T)-min(Grit_24701_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24701 = statistics.mean(Grit_24701_H)    #(作业花费时长/作业问题数)的平均
Grit10_24701 = statistics.median(Grit_24701_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24701 = 1/statistics.stdev(Grit_24701_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24701 = 1/(max(Grit_24701_H)-min(Grit_24701_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24701 = Time_24701_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24701 = Time_24701_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24701 = Time_24701_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24701 = USER_ID[24701].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24701 = np.nan_to_num(Self_control4_24701)
Self_control4_24701 = Self_control4_24701.max()

Self_control5_24701 = USER_ID[24701].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24701 = np.nan_to_num(Self_control5_24701)
Self_control5_24701 = Self_control5_24701.min()

Self_control6_24701 = USER_ID[24701].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24701 = np.nan_to_num(Self_control6_24701)
Self_control6_24701 = Self_control6_24701.sum() 
Self_control6_24701 = Self_control6_24701 / 45

Self_control7_24701 = USER_ID[24701].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24701 = np.nan_to_num(Self_control7_24701)
Self_control7_24701 = Self_control7_24701[20:40].mean()

#(3) Engagement
Engagement_24701_V = Time_24701_V    #视频观看时长
Engagement_24701_T = Time_24701_T    #文本阅读时长
Engagement_24701_H = Time_24701_H    #作业花费时长

Engagement1_24701 = USER_ID[24701].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24701 = np.nan_to_num(Engagement1_24701).sum()

Engagement2_24701 = statistics.mean(Engagement_24701_V)    #平均每次花费在视频学习的时间
Engagement3_24701 = statistics.mean(Engagement_24701_T)    #平均每次花费在文本课件的时间
Engagement4_24701 = statistics.mean(Engagement_24701_H)    #平均每次花费在作业答题的时间
Engagement5_24701 = 45    #学习次数(登入次数)
Engagement6_24701 = 0    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24701 = Time_24701_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24701 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24701 = USER_ID[24701].loc[:, '访问时长(seconds)'].values
Self_perception1_24701 = np.nan_to_num(Self_perception1_24701)

Self_perception1_24701 = 1/((Self_perception1_24701[:20].sum() 
                         - Self_perception1_24701[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24701 = 1/((statistics.mean(Grit_24701_V[:7]) 
                         - statistics.mean(Grit_24701_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24701 = 1/((statistics.mean(Grit_24701_T[:2]) 
                         - statistics.mean(Grit_24701_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24701 = 1/((statistics.mean(Grit_24701_H[:9]) 
                         - statistics.mean(Grit_24701_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24701 = USER_ID[24701].loc[:, ['高过门槛时长']].values
Motivation1_24701 = np.nan_to_num(Motivation1_24701).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24701 = USER_ID[24701].loc[c4, ['高过门槛时长']].values
Motivation2_24701 = np.nan_to_num(Motivation2_24701).sum()
#文挡高过门槛时长总和
Motivation3_24701 = USER_ID[24701].loc[c5, ['高过门槛时长']].values   
Motivation3_24701 = np.nan_to_num(Motivation3_24701).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24701 = np.array(USER_ID[24701].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24701 = np.nan_to_num(Motivation4_24701)
Motivation4_24701 = statistics.mean(Motivation4_24701 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24701 = np.array(USER_ID[24701].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24701 = np.nan_to_num(Motivation5_24701)
Motivation5_24701 = statistics.mean(Motivation5_24701 / c2)

#选修花费总时长
Motivation6_24701 = USER_ID[24701].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24701 = np.nan_to_num(Motivation6_24701).sum()

#(选修花费/页数)的平均
Motivation7_24701 = Motivation6_24701 / (11+8)
Motivation8_24701 = Motivation7_24701/Motivation5_24701    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24701 = 0.72    #完成进度*

# %%
USER_ID[24720].reset_index(inplace=True)
USER_ID[24720].set_index('活动名称', inplace=True)
print(USER_ID[24720].shape) 

# USER_ID[24720]

Time_24720_V = USER_ID[24720].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24720_V = np.nan_to_num(Time_24720_V)

Time_24720_T = USER_ID[24720].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24720_T = np.nan_to_num(Time_24720_T)

Time_24720_H = USER_ID[24720].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24720_H = np.nan_to_num(Time_24720_H)

#(1) Grit
Grit_24720_V = Time_24720_V / c1  #视频观看时长/视频总时长
Grit_24720_T = Time_24720_T / c2   #文本阅读时长/文本页数
Grit_24720_H = Time_24720_H /c3   #作业花费时长/作业问题数

Grit1_24720 = statistics.mean(Grit_24720_V)    #(视频观看时长/视频总时长)的平均
Grit2_24720 = statistics.median(Grit_24720_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24720 = 1/statistics.stdev(Grit_24720_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24720 = 1/(max(Grit_24720_V)-min(Grit_24720_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24720 = statistics.mean(Grit_24720_T)    #(文本阅读时长/文本页数)的平均
Grit6_24720 = statistics.median(Grit_24720_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24720 = 1/statistics.stdev(Grit_24720_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24720 = 1/(max(Grit_24720_T)-min(Grit_24720_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24720 = statistics.mean(Grit_24720_H)    #(作业花费时长/作业问题数)的平均
Grit10_24720 = statistics.median(Grit_24720_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24720 = 1/statistics.stdev(Grit_24720_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24720 = 1/(max(Grit_24720_H)-min(Grit_24720_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24720 = Time_24720_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24720 = Time_24720_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24720 = Time_24720_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24720 = USER_ID[24720].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24720 = np.nan_to_num(Self_control4_24720)
Self_control4_24720 = Self_control4_24720.max()

Self_control5_24720 = USER_ID[24720].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24720 = np.nan_to_num(Self_control5_24720)
Self_control5_24720 = Self_control5_24720.min()

Self_control6_24720 = USER_ID[24720].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24720 = np.nan_to_num(Self_control6_24720)
Self_control6_24720 = Self_control6_24720.sum() 
Self_control6_24720 = Self_control6_24720 / 62

Self_control7_24720 = USER_ID[24720].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24720 = np.nan_to_num(Self_control7_24720)
Self_control7_24720 = Self_control7_24720[20:40].mean()

#(3) Engagement
Engagement_24720_V = Time_24720_V    #视频观看时长
Engagement_24720_T = Time_24720_T    #文本阅读时长
Engagement_24720_H = Time_24720_H    #作业花费时长

Engagement1_24720 = USER_ID[24720].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24720 = np.nan_to_num(Engagement1_24720).sum()

Engagement2_24720 = statistics.mean(Engagement_24720_V)    #平均每次花费在视频学习的时间
Engagement3_24720 = statistics.mean(Engagement_24720_T)    #平均每次花费在文本课件的时间
Engagement4_24720 = statistics.mean(Engagement_24720_H)    #平均每次花费在作业答题的时间
Engagement5_24720 = 62    #学习次数(登入次数)
Engagement6_24720 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24720 = Time_24720_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24720 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24720 = USER_ID[24720].loc[:, '访问时长(seconds)'].values
Self_perception1_24720 = np.nan_to_num(Self_perception1_24720)

Self_perception1_24720 = 1/((Self_perception1_24720[:20].sum() 
                         - Self_perception1_24720[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24720 = 1/((statistics.mean(Grit_24720_V[:7]) 
                         - statistics.mean(Grit_24720_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24720 = 1/((statistics.mean(Grit_24720_T[:2]) 
                         - statistics.mean(Grit_24720_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24720 = 1/((statistics.mean(Grit_24720_H[:9]) 
                         - statistics.mean(Grit_24720_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24720 = USER_ID[24720].loc[:, ['高过门槛时长']].values
Motivation1_24720 = np.nan_to_num(Motivation1_24720).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24720 = USER_ID[24720].loc[c4, ['高过门槛时长']].values
Motivation2_24720 = np.nan_to_num(Motivation2_24720).sum()
#文挡高过门槛时长总和
Motivation3_24720 = USER_ID[24720].loc[c5, ['高过门槛时长']].values   
Motivation3_24720 = np.nan_to_num(Motivation3_24720).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24720 = np.array(USER_ID[24720].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24720 = np.nan_to_num(Motivation4_24720)
Motivation4_24720 = statistics.mean(Motivation4_24720 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24720 = np.array(USER_ID[24720].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24720 = np.nan_to_num(Motivation5_24720)
Motivation5_24720 = statistics.mean(Motivation5_24720 / c2)

#选修花费总时长
Motivation6_24720 = USER_ID[24720].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24720 = np.nan_to_num(Motivation6_24720).sum()

#(选修花费/页数)的平均
Motivation7_24720 = Motivation6_24720 / (11+8)
Motivation8_24720 = Motivation7_24720/Motivation5_24720    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24720 = 0.97    #完成进度*

# %%
USER_ID[24719]

# %%
USER_ID[24719].reset_index(inplace=True)
USER_ID[24719].set_index('活动名称', inplace=True)
print(USER_ID[24719].shape)
# USER_ID[24719]

Time_24719_V = USER_ID[24719].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24719_V = np.nan_to_num(Time_24719_V)

Time_24719_T = USER_ID[24719].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24719_T = np.nan_to_num(Time_24719_T)

Time_24719_H = USER_ID[24719].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24719_H = np.nan_to_num(Time_24719_H)

#(1) Grit
Grit_24719_V = Time_24719_V / c1  #视频观看时长/视频总时长
Grit_24719_T = Time_24719_T / c2   #文本阅读时长/文本页数
Grit_24719_H = Time_24719_H /c3   #作业花费时长/作业问题数

Grit1_24719 = statistics.mean(Grit_24719_V)    #(视频观看时长/视频总时长)的平均
Grit2_24719 = statistics.median(Grit_24719_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24719 = 1/statistics.stdev(Grit_24719_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24719 = 1/(max(Grit_24719_V)-min(Grit_24719_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24719 = statistics.mean(Grit_24719_T)    #(文本阅读时长/文本页数)的平均
Grit6_24719 = statistics.median(Grit_24719_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24719 = 1/statistics.stdev(Grit_24719_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24719 = 1/(max(Grit_24719_T)-min(Grit_24719_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24719 = statistics.mean(Grit_24719_H)    #(作业花费时长/作业问题数)的平均
Grit10_24719 = statistics.median(Grit_24719_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24719 = 1/statistics.stdev(Grit_24719_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24719 = 1/(max(Grit_24719_H)-min(Grit_24719_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24719 = Time_24719_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24719 = Time_24719_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24719 = Time_24719_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24719 = USER_ID[24719].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24719 = np.nan_to_num(Self_control4_24719)
Self_control4_24719 = Self_control4_24719.max()

Self_control5_24719 = USER_ID[24719].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24719 = np.nan_to_num(Self_control5_24719)
Self_control5_24719 = Self_control5_24719.min()

Self_control6_24719 = USER_ID[24719].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24719 = np.nan_to_num(Self_control6_24719)
Self_control6_24719 = Self_control6_24719.sum() 
Self_control6_24719 = Self_control6_24719 / 61

Self_control7_24719 = USER_ID[24719].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24719 = np.nan_to_num(Self_control7_24719)
Self_control7_24719 = Self_control7_24719[20:40].mean()

#(3) Engagement
Engagement_24719_V = Time_24719_V    #视频观看时长
Engagement_24719_T = Time_24719_T    #文本阅读时长
Engagement_24719_H = Time_24719_H    #作业花费时长

Engagement1_24719 = USER_ID[24719].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24719 = np.nan_to_num(Engagement1_24719).sum()

Engagement2_24719 = statistics.mean(Engagement_24719_V)    #平均每次花费在视频学习的时间
Engagement3_24719 = statistics.mean(Engagement_24719_T)    #平均每次花费在文本课件的时间
Engagement4_24719 = statistics.mean(Engagement_24719_H)    #平均每次花费在作业答题的时间
Engagement5_24719 = 61    #学习次数(登入次数)
Engagement6_24719 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24719 = Time_24719_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24719 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24719 = USER_ID[24719].loc[:, '访问时长(seconds)'].values
Self_perception1_24719 = np.nan_to_num(Self_perception1_24719)

Self_perception1_24719 = 1/((Self_perception1_24719[:20].sum() 
                         - Self_perception1_24719[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24719 = 1/((statistics.mean(Grit_24719_V[:7]) 
                         - statistics.mean(Grit_24719_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24719 = 1/((statistics.mean(Grit_24719_T[:2]) 
                         - statistics.mean(Grit_24719_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24719 = 1/((statistics.mean(Grit_24719_H[:9]) 
                         - statistics.mean(Grit_24719_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24719 = USER_ID[24719].loc[:, ['高过门槛时长']].values
Motivation1_24719 = np.nan_to_num(Motivation1_24719).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24719 = USER_ID[24719].loc[c4, ['高过门槛时长']].values
Motivation2_24719 = np.nan_to_num(Motivation2_24719).sum()
#文挡高过门槛时长总和
Motivation3_24719 = USER_ID[24719].loc[c5, ['高过门槛时长']].values   
Motivation3_24719 = np.nan_to_num(Motivation3_24719).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24719 = np.array(USER_ID[24719].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24719 = np.nan_to_num(Motivation4_24719)
Motivation4_24719 = statistics.mean(Motivation4_24719 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24719 = np.array(USER_ID[24719].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24719 = np.nan_to_num(Motivation5_24719)
Motivation5_24719 = statistics.mean(Motivation5_24719 / c2)

#选修花费总时长
Motivation6_24719 = USER_ID[24719].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24719 = np.nan_to_num(Motivation6_24719).sum()

#(选修花费/页数)的平均
Motivation7_24719 = Motivation6_24719 / (11+8)
Motivation8_24719 = Motivation7_24719/Motivation5_24719    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24719 = 0.97    #完成进度*

# %%
USER_ID[24717]

# %%
USER_ID[24717].reset_index(inplace=True)
USER_ID[24717].set_index('活动名称', inplace=True)
print(USER_ID[24717].shape)
# USER_ID[24717]

Time_24717_V = USER_ID[24717].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24717_V = np.nan_to_num(Time_24717_V)

Time_24717_T = USER_ID[24717].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24717_T = np.nan_to_num(Time_24717_T)

Time_24717_H = USER_ID[24717].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24717_H = np.nan_to_num(Time_24717_H)

#(1) Grit
Grit_24717_V = Time_24717_V / c1  #视频观看时长/视频总时长
Grit_24717_T = Time_24717_T / c2   #文本阅读时长/文本页数
Grit_24717_H = Time_24717_H /c3   #作业花费时长/作业问题数

Grit1_24717 = statistics.mean(Grit_24717_V)    #(视频观看时长/视频总时长)的平均
Grit2_24717 = statistics.median(Grit_24717_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24717 = 1/statistics.stdev(Grit_24717_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24717 = 1/(max(Grit_24717_V)-min(Grit_24717_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24717 = statistics.mean(Grit_24717_T)    #(文本阅读时长/文本页数)的平均
Grit6_24717 = statistics.median(Grit_24717_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24717 = 1/statistics.stdev(Grit_24717_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24717 = 1/(max(Grit_24717_T)-min(Grit_24717_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24717 = statistics.mean(Grit_24717_H)    #(作业花费时长/作业问题数)的平均
Grit10_24717 = statistics.median(Grit_24717_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24717 = 1/statistics.stdev(Grit_24717_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24717 = 1/(max(Grit_24717_H)-min(Grit_24717_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24717 = Time_24717_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24717 = Time_24717_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24717 = Time_24717_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24717 = USER_ID[24717].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24717 = np.nan_to_num(Self_control4_24717)
Self_control4_24717 = Self_control4_24717.max()

Self_control5_24717 = USER_ID[24717].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24717 = np.nan_to_num(Self_control5_24717)
Self_control5_24717 = Self_control5_24717.min()

Self_control6_24717 = USER_ID[24717].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24717 = np.nan_to_num(Self_control6_24717)
Self_control6_24717 = Self_control6_24717.sum() 
Self_control6_24717 = Self_control6_24717 / 64

Self_control7_24717 = USER_ID[24717].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24717 = np.nan_to_num(Self_control7_24717)
Self_control7_24717 = Self_control7_24717[20:40].mean()

#(3) Engagement
Engagement_24717_V = Time_24717_V    #视频观看时长
Engagement_24717_T = Time_24717_T    #文本阅读时长
Engagement_24717_H = Time_24717_H    #作业花费时长

Engagement1_24717 = USER_ID[24717].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24717 = np.nan_to_num(Engagement1_24717).sum()

Engagement2_24717 = statistics.mean(Engagement_24717_V)    #平均每次花费在视频学习的时间
Engagement3_24717 = statistics.mean(Engagement_24717_T)    #平均每次花费在文本课件的时间
Engagement4_24717 = statistics.mean(Engagement_24717_H)    #平均每次花费在作业答题的时间
Engagement5_24717 = 64    #学习次数(登入次数)
Engagement6_24717 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24717 = Time_24717_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24717 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24717 = USER_ID[24717].loc[:, '访问时长(seconds)'].values
Self_perception1_24717 = np.nan_to_num(Self_perception1_24717)

Self_perception1_24717 = 1/((Self_perception1_24717[:20].sum() 
                         - Self_perception1_24717[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24717 = 1/((statistics.mean(Grit_24717_V[:7]) 
                         - statistics.mean(Grit_24717_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24717 = 1/((statistics.mean(Grit_24717_T[:2]) 
                         - statistics.mean(Grit_24717_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24717 = 1/((statistics.mean(Grit_24717_H[:9]) 
                         - statistics.mean(Grit_24717_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24717 = USER_ID[24717].loc[:, ['高过门槛时长']].values
Motivation1_24717 = np.nan_to_num(Motivation1_24717).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24717 = USER_ID[24717].loc[c4, ['高过门槛时长']].values
Motivation2_24717 = np.nan_to_num(Motivation2_24717).sum()
#文挡高过门槛时长总和
Motivation3_24717 = USER_ID[24717].loc[c5, ['高过门槛时长']].values   
Motivation3_24717 = np.nan_to_num(Motivation3_24717).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24717 = np.array(USER_ID[24717].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24717 = np.nan_to_num(Motivation4_24717)
Motivation4_24717 = statistics.mean(Motivation4_24717 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24717 = np.array(USER_ID[24717].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24717 = np.nan_to_num(Motivation5_24717)
Motivation5_24717 = statistics.mean(Motivation5_24717 / c2)

#选修花费总时长
Motivation6_24717 = USER_ID[24717].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24717 = np.nan_to_num(Motivation6_24717).sum()

#(选修花费/页数)的平均
Motivation7_24717 = Motivation6_24717 / (11+8)
Motivation8_24717 = Motivation7_24717/Motivation5_24717    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24717 = 0.97    #完成进度*

# %%
USER_ID[24721]

# %%
USER_ID[24721].reset_index(inplace=True)
USER_ID[24721].set_index('活动名称', inplace=True)
print(USER_ID[24721].shape)
# USER_ID[24721]

Time_24721_V = USER_ID[24721].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24721_V = np.nan_to_num(Time_24721_V)

Time_24721_T = USER_ID[24721].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24721_T = np.nan_to_num(Time_24721_T)

Time_24721_H = USER_ID[24721].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24721_H = np.nan_to_num(Time_24721_H)

#(1) Grit
Grit_24721_V = Time_24721_V / c1  #视频观看时长/视频总时长
Grit_24721_T = Time_24721_T / c2   #文本阅读时长/文本页数
Grit_24721_H = Time_24721_H /c3   #作业花费时长/作业问题数

Grit1_24721 = statistics.mean(Grit_24721_V)    #(视频观看时长/视频总时长)的平均
Grit2_24721 = statistics.median(Grit_24721_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24721 = 1/statistics.stdev(Grit_24721_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24721 = 1/(max(Grit_24721_V)-min(Grit_24721_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24721 = statistics.mean(Grit_24721_T)    #(文本阅读时长/文本页数)的平均
Grit6_24721 = statistics.median(Grit_24721_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24721 = 1/statistics.stdev(Grit_24721_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24721 = 1/(max(Grit_24721_T)-min(Grit_24721_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24721 = statistics.mean(Grit_24721_H)    #(作业花费时长/作业问题数)的平均
Grit10_24721 = statistics.median(Grit_24721_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24721 = 1/statistics.stdev(Grit_24721_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24721 = 1/(max(Grit_24721_H)-min(Grit_24721_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24721 = Time_24721_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24721 = Time_24721_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24721 = Time_24721_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24721 = USER_ID[24721].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24721 = np.nan_to_num(Self_control4_24721)
Self_control4_24721 = Self_control4_24721.max()

Self_control5_24721 = USER_ID[24721].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24721 = np.nan_to_num(Self_control5_24721)
Self_control5_24721 = Self_control5_24721.min()

Self_control6_24721 = USER_ID[24721].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24721 = np.nan_to_num(Self_control6_24721)
Self_control6_24721 = Self_control6_24721.sum() 
Self_control6_24721 = Self_control6_24721 / 64

Self_control7_24721 = USER_ID[24721].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24721 = np.nan_to_num(Self_control7_24721)
Self_control7_24721 = Self_control7_24721[20:40].mean()

#(3) Engagement
Engagement_24721_V = Time_24721_V    #视频观看时长
Engagement_24721_T = Time_24721_T    #文本阅读时长
Engagement_24721_H = Time_24721_H    #作业花费时长

Engagement1_24721 = USER_ID[24721].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24721 = np.nan_to_num(Engagement1_24721).sum()

Engagement2_24721 = statistics.mean(Engagement_24721_V)    #平均每次花费在视频学习的时间
Engagement3_24721 = statistics.mean(Engagement_24721_T)    #平均每次花费在文本课件的时间
Engagement4_24721 = statistics.mean(Engagement_24721_H)    #平均每次花费在作业答题的时间
Engagement5_24721 = 64    #学习次数(登入次数)
Engagement6_24721 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24721 = Time_24721_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24721 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24721 = USER_ID[24721].loc[:, '访问时长(seconds)'].values
Self_perception1_24721 = np.nan_to_num(Self_perception1_24721)

Self_perception1_24721 = 1/((Self_perception1_24721[:20].sum() 
                         - Self_perception1_24721[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24721 = 1/((statistics.mean(Grit_24721_V[:7]) 
                         - statistics.mean(Grit_24721_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24721 = 1/((statistics.mean(Grit_24721_T[:2]) 
                         - statistics.mean(Grit_24721_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24721 = 1/((statistics.mean(Grit_24721_H[:9]) 
                         - statistics.mean(Grit_24721_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24721 = USER_ID[24721].loc[:, ['高过门槛时长']].values
Motivation1_24721 = np.nan_to_num(Motivation1_24721).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24721 = USER_ID[24721].loc[c4, ['高过门槛时长']].values
Motivation2_24721 = np.nan_to_num(Motivation2_24721).sum()
#文挡高过门槛时长总和
Motivation3_24721 = USER_ID[24721].loc[c5, ['高过门槛时长']].values   
Motivation3_24721 = np.nan_to_num(Motivation3_24721).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24721 = np.array(USER_ID[24721].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24721 = np.nan_to_num(Motivation4_24721)
Motivation4_24721 = statistics.mean(Motivation4_24721 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24721 = np.array(USER_ID[24721].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24721 = np.nan_to_num(Motivation5_24721)
Motivation5_24721 = statistics.mean(Motivation5_24721 / c2)

#选修花费总时长
Motivation6_24721 = USER_ID[24721].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24721 = np.nan_to_num(Motivation6_24721).sum()

#(选修花费/页数)的平均
Motivation7_24721 = Motivation6_24721 / (11+8)
Motivation8_24721 = Motivation7_24721/Motivation5_24721    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24721 = 0.97    #完成进度*

# %%
USER_ID[24740]

# %%
USER_ID[24740].reset_index(inplace=True)
USER_ID[24740].set_index('活动名称', inplace=True)
print(USER_ID[24740].shape)
# USER_ID[24740]

Time_24740_V = USER_ID[24740].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24740_V = np.nan_to_num(Time_24740_V)

Time_24740_T = USER_ID[24740].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24740_T = np.nan_to_num(Time_24740_T)

Time_24740_H = USER_ID[24740].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24740_H = np.nan_to_num(Time_24740_H)

#(1) Grit
Grit_24740_V = Time_24740_V / c1  #视频观看时长/视频总时长
Grit_24740_T = Time_24740_T / c2   #文本阅读时长/文本页数
Grit_24740_H = Time_24740_H /c3   #作业花费时长/作业问题数

Grit1_24740 = statistics.mean(Grit_24740_V)    #(视频观看时长/视频总时长)的平均
Grit2_24740 = statistics.median(Grit_24740_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24740 = 1/statistics.stdev(Grit_24740_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24740 = 1/(max(Grit_24740_V)-min(Grit_24740_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24740 = statistics.mean(Grit_24740_T)    #(文本阅读时长/文本页数)的平均
Grit6_24740 = statistics.median(Grit_24740_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24740 = 1/statistics.stdev(Grit_24740_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24740 = 1/(max(Grit_24740_T)-min(Grit_24740_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24740 = statistics.mean(Grit_24740_H)    #(作业花费时长/作业问题数)的平均
Grit10_24740 = statistics.median(Grit_24740_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24740 = 1/statistics.stdev(Grit_24740_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24740 = 1/(max(Grit_24740_H)-min(Grit_24740_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24740 = Time_24740_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24740 = Time_24740_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24740 = Time_24740_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24740 = USER_ID[24740].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24740 = np.nan_to_num(Self_control4_24740)
Self_control4_24740 = Self_control4_24740.max()

Self_control5_24740 = USER_ID[24740].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24740 = np.nan_to_num(Self_control5_24740)
Self_control5_24740 = Self_control5_24740.min()

Self_control6_24740 = USER_ID[24740].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24740 = np.nan_to_num(Self_control6_24740)
Self_control6_24740 = Self_control6_24740.sum() 
Self_control6_24740 = Self_control6_24740 / 60

Self_control7_24740 = USER_ID[24740].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24740 = np.nan_to_num(Self_control7_24740)
Self_control7_24740 = Self_control7_24740[20:40].mean()

#(3) Engagement
Engagement_24740_V = Time_24740_V    #视频观看时长
Engagement_24740_T = Time_24740_T    #文本阅读时长
Engagement_24740_H = Time_24740_H    #作业花费时长

Engagement1_24740 = USER_ID[24740].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24740 = np.nan_to_num(Engagement1_24740).sum()

Engagement2_24740 = statistics.mean(Engagement_24740_V)    #平均每次花费在视频学习的时间
Engagement3_24740 = statistics.mean(Engagement_24740_T)    #平均每次花费在文本课件的时间
Engagement4_24740 = statistics.mean(Engagement_24740_H)    #平均每次花费在作业答题的时间
Engagement5_24740 = 60    #学习次数(登入次数)
Engagement6_24740 = 3    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24740 = Time_24740_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24740 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24740 = USER_ID[24740].loc[:, '访问时长(seconds)'].values
Self_perception1_24740 = np.nan_to_num(Self_perception1_24740)

Self_perception1_24740 = 1/((Self_perception1_24740[:20].sum() 
                         - Self_perception1_24740[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24740 = 1/((statistics.mean(Grit_24740_V[:7]) 
                         - statistics.mean(Grit_24740_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24740 = 1/((statistics.mean(Grit_24740_T[:2]) 
                         - statistics.mean(Grit_24740_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24740 = 1/((statistics.mean(Grit_24740_H[:9]) 
                         - statistics.mean(Grit_24740_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24740 = USER_ID[24740].loc[:, ['高过门槛时长']].values
Motivation1_24740 = np.nan_to_num(Motivation1_24740).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24740 = USER_ID[24740].loc[c4, ['高过门槛时长']].values
Motivation2_24740 = np.nan_to_num(Motivation2_24740).sum()
#文挡高过门槛时长总和
Motivation3_24740 = USER_ID[24740].loc[c5, ['高过门槛时长']].values   
Motivation3_24740 = np.nan_to_num(Motivation3_24740).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24740 = np.array(USER_ID[24740].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24740 = np.nan_to_num(Motivation4_24740)
Motivation4_24740 = statistics.mean(Motivation4_24740 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24740 = np.array(USER_ID[24740].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24740 = np.nan_to_num(Motivation5_24740)
Motivation5_24740 = statistics.mean(Motivation5_24740 / c2)

#选修花费总时长
Motivation6_24740 = USER_ID[24740].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24740 = np.nan_to_num(Motivation6_24740).sum()

#(选修花费/页数)的平均
Motivation7_24740 = Motivation6_24740 / (11+8)
Motivation8_24740 = Motivation7_24740/Motivation5_24740    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24740 = 0.97    #完成进度*

# %%
USER_ID[24727]

# %%
USER_ID[24727].reset_index(inplace=True)
USER_ID[24727].set_index('活动名称', inplace=True)
print(USER_ID[24727].shape) 
# USER_ID[24727]

Time_24727_V = USER_ID[24727].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24727_V = np.nan_to_num(Time_24727_V)

Time_24727_T = USER_ID[24727].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24727_T = np.nan_to_num(Time_24727_T)

Time_24727_H = USER_ID[24727].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24727_H = np.nan_to_num(Time_24727_H)

#(1) Grit
Grit_24727_V = Time_24727_V / c1  #视频观看时长/视频总时长
Grit_24727_T = Time_24727_T / c2   #文本阅读时长/文本页数
Grit_24727_H = Time_24727_H /c3   #作业花费时长/作业问题数

Grit1_24727 = statistics.mean(Grit_24727_V)    #(视频观看时长/视频总时长)的平均
Grit2_24727 = statistics.median(Grit_24727_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24727 = 1/statistics.stdev(Grit_24727_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24727 = 1/(max(Grit_24727_V)-min(Grit_24727_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24727 = statistics.mean(Grit_24727_T)    #(文本阅读时长/文本页数)的平均
Grit6_24727 = statistics.median(Grit_24727_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24727 = 1/statistics.stdev(Grit_24727_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24727 = 1/(max(Grit_24727_T)-min(Grit_24727_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24727 = statistics.mean(Grit_24727_H)    #(作业花费时长/作业问题数)的平均
Grit10_24727 = statistics.median(Grit_24727_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24727 = 1/statistics.stdev(Grit_24727_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24727 = 1/(max(Grit_24727_H)-min(Grit_24727_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24727 = Time_24727_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24727 = Time_24727_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24727 = Time_24727_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24727 = USER_ID[24727].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24727 = np.nan_to_num(Self_control4_24727)
Self_control4_24727 = Self_control4_24727.max()

Self_control5_24727 = USER_ID[24727].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24727 = np.nan_to_num(Self_control5_24727)
Self_control5_24727 = Self_control5_24727.min()

Self_control6_24727 = USER_ID[24727].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24727 = np.nan_to_num(Self_control6_24727)
Self_control6_24727 = Self_control6_24727.sum() 
Self_control6_24727 = Self_control6_24727 / 59

Self_control7_24727 = USER_ID[24727].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24727 = np.nan_to_num(Self_control7_24727)
Self_control7_24727 = Self_control7_24727[20:40].mean()

#(3) Engagement
Engagement_24727_V = Time_24727_V    #视频观看时长
Engagement_24727_T = Time_24727_T    #文本阅读时长
Engagement_24727_H = Time_24727_H    #作业花费时长

Engagement1_24727 = USER_ID[24727].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24727 = np.nan_to_num(Engagement1_24727).sum()

Engagement2_24727 = statistics.mean(Engagement_24727_V)    #平均每次花费在视频学习的时间
Engagement3_24727 = statistics.mean(Engagement_24727_T)    #平均每次花费在文本课件的时间
Engagement4_24727 = statistics.mean(Engagement_24727_H)    #平均每次花费在作业答题的时间
Engagement5_24727 = 59    #学习次数(登入次数)
Engagement6_24727 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24727 = Time_24727_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24727 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24727 = USER_ID[24727].loc[:, '访问时长(seconds)'].values
Self_perception1_24727 = np.nan_to_num(Self_perception1_24727)

Self_perception1_24727 = 1/((Self_perception1_24727[:20].sum() 
                         - Self_perception1_24727[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24727 = 1/((statistics.mean(Grit_24727_V[:7]) 
                         - statistics.mean(Grit_24727_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24727 = 1/((statistics.mean(Grit_24727_T[:2]) 
                         - statistics.mean(Grit_24727_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24727 = 1/((statistics.mean(Grit_24727_H[:9]) 
                         - statistics.mean(Grit_24727_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24727 = USER_ID[24727].loc[:, ['高过门槛时长']].values
Motivation1_24727 = np.nan_to_num(Motivation1_24727).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24727 = USER_ID[24727].loc[c4, ['高过门槛时长']].values
Motivation2_24727 = np.nan_to_num(Motivation2_24727).sum()
#文挡高过门槛时长总和
Motivation3_24727 = USER_ID[24727].loc[c5, ['高过门槛时长']].values   
Motivation3_24727 = np.nan_to_num(Motivation3_24727).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24727 = np.array(USER_ID[24727].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24727 = np.nan_to_num(Motivation4_24727)
Motivation4_24727 = statistics.mean(Motivation4_24727 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24727 = np.array(USER_ID[24727].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24727 = np.nan_to_num(Motivation5_24727)
Motivation5_24727 = statistics.mean(Motivation5_24727 / c2)

#选修花费总时长
Motivation6_24727 = USER_ID[24727].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24727 = np.nan_to_num(Motivation6_24727).sum()

#(选修花费/页数)的平均
Motivation7_24727 = Motivation6_24727 / (11+8)
Motivation8_24727 = Motivation7_24727/Motivation5_24727    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24727 = 0.97    #完成进度*

# %%
USER_ID[24730]

# %%
USER_ID[24730].reset_index(inplace=True)
USER_ID[24730].set_index('活动名称', inplace=True)
print(USER_ID[24730].shape) 
# USER_ID[24730]

Time_24730_V = USER_ID[24730].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24730_V = np.nan_to_num(Time_24730_V)

Time_24730_T = USER_ID[24730].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24730_T = np.nan_to_num(Time_24730_T)

Time_24730_H = USER_ID[24730].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24730_H = np.nan_to_num(Time_24730_H)

#(1) Grit
Grit_24730_V = Time_24730_V / c1  #视频观看时长/视频总时长
Grit_24730_T = Time_24730_T / c2   #文本阅读时长/文本页数
Grit_24730_H = Time_24730_H /c3   #作业花费时长/作业问题数

Grit1_24730 = statistics.mean(Grit_24730_V)    #(视频观看时长/视频总时长)的平均
Grit2_24730 = statistics.median(Grit_24730_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24730 = 1/statistics.stdev(Grit_24730_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24730 = 1/(max(Grit_24730_V)-min(Grit_24730_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24730 = statistics.mean(Grit_24730_T)    #(文本阅读时长/文本页数)的平均
Grit6_24730 = statistics.median(Grit_24730_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24730 = 1/statistics.stdev(Grit_24730_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24730 = 1/(max(Grit_24730_T)-min(Grit_24730_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24730 = statistics.mean(Grit_24730_H)    #(作业花费时长/作业问题数)的平均
Grit10_24730 = statistics.median(Grit_24730_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24730 = 1/statistics.stdev(Grit_24730_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24730 = 1/(max(Grit_24730_H)-min(Grit_24730_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24730 = Time_24730_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24730 = Time_24730_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24730 = Time_24730_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24730 = USER_ID[24730].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24730 = np.nan_to_num(Self_control4_24730)
Self_control4_24730 = Self_control4_24730.max()

Self_control5_24730 = USER_ID[24730].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24730 = np.nan_to_num(Self_control5_24730)
Self_control5_24730 = Self_control5_24730.min()

Self_control6_24730 = USER_ID[24730].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24730 = np.nan_to_num(Self_control6_24730)
Self_control6_24730 = Self_control6_24730.sum() 
Self_control6_24730 = Self_control6_24730 / 59

Self_control7_24730 = USER_ID[24730].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24730 = np.nan_to_num(Self_control7_24730)
Self_control7_24730 = Self_control7_24730[20:40].mean()

#(3) Engagement
Engagement_24730_V = Time_24730_V    #视频观看时长
Engagement_24730_T = Time_24730_T    #文本阅读时长
Engagement_24730_H = Time_24730_H    #作业花费时长

Engagement1_24730 = USER_ID[24730].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24730 = np.nan_to_num(Engagement1_24730).sum()

Engagement2_24730 = statistics.mean(Engagement_24730_V)    #平均每次花费在视频学习的时间
Engagement3_24730 = statistics.mean(Engagement_24730_T)    #平均每次花费在文本课件的时间
Engagement4_24730 = statistics.mean(Engagement_24730_H)    #平均每次花费在作业答题的时间
Engagement5_24730 = 59    #学习次数(登入次数)
Engagement6_24730 = 9    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24730 = Time_24730_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24730 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24730 = USER_ID[24730].loc[:, '访问时长(seconds)'].values
Self_perception1_24730 = np.nan_to_num(Self_perception1_24730)

Self_perception1_24730 = 1/((Self_perception1_24730[:20].sum() 
                         - Self_perception1_24730[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24730 = 1/((statistics.mean(Grit_24730_V[:7]) 
                         - statistics.mean(Grit_24730_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24730 = 1/((statistics.mean(Grit_24730_T[:2]) 
                         - statistics.mean(Grit_24730_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24730 = 1/((statistics.mean(Grit_24730_H[:9]) 
                         - statistics.mean(Grit_24730_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24730 = USER_ID[24730].loc[:, ['高过门槛时长']].values
Motivation1_24730 = np.nan_to_num(Motivation1_24730).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24730 = USER_ID[24730].loc[c4, ['高过门槛时长']].values
Motivation2_24730 = np.nan_to_num(Motivation2_24730).sum()
#文挡高过门槛时长总和
Motivation3_24730 = USER_ID[24730].loc[c5, ['高过门槛时长']].values   
Motivation3_24730 = np.nan_to_num(Motivation3_24730).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24730 = np.array(USER_ID[24730].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24730 = np.nan_to_num(Motivation4_24730)
Motivation4_24730 = statistics.mean(Motivation4_24730 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24730 = np.array(USER_ID[24730].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24730 = np.nan_to_num(Motivation5_24730)
Motivation5_24730 = statistics.mean(Motivation5_24730 / c2)

#选修花费总时长
Motivation6_24730 = USER_ID[24730].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24730 = np.nan_to_num(Motivation6_24730).sum()

#(选修花费/页数)的平均
Motivation7_24730 = Motivation6_24730 / (11+8)
Motivation8_24730 = Motivation7_24730/Motivation5_24730    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24730 = 0.97    #完成进度*

# %%
USER_ID[24729]

# %%
USER_ID[24729].reset_index(inplace=True)
USER_ID[24729].set_index('活动名称', inplace=True)
print(USER_ID[24729].shape)
# USER_ID[24729]

Time_24729_V = USER_ID[24729].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24729_V = np.nan_to_num(Time_24729_V)

Time_24729_T = USER_ID[24729].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24729_T = np.nan_to_num(Time_24729_T)

Time_24729_H = USER_ID[24729].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24729_H = np.nan_to_num(Time_24729_H)

#(1) Grit
Grit_24729_V = Time_24729_V / c1  #视频观看时长/视频总时长
Grit_24729_T = Time_24729_T / c2   #文本阅读时长/文本页数
Grit_24729_H = Time_24729_H /c3   #作业花费时长/作业问题数

Grit1_24729 = statistics.mean(Grit_24729_V)    #(视频观看时长/视频总时长)的平均
Grit2_24729 = statistics.median(Grit_24729_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24729 = 1/statistics.stdev(Grit_24729_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24729 = 1/(max(Grit_24729_V)-min(Grit_24729_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24729 = statistics.mean(Grit_24729_T)    #(文本阅读时长/文本页数)的平均
Grit6_24729 = statistics.median(Grit_24729_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24729 = 1/statistics.stdev(Grit_24729_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24729 = 1/(max(Grit_24729_T)-min(Grit_24729_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24729 = statistics.mean(Grit_24729_H)    #(作业花费时长/作业问题数)的平均
Grit10_24729 = statistics.median(Grit_24729_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24729 = 1/statistics.stdev(Grit_24729_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24729 = 1/(max(Grit_24729_H)-min(Grit_24729_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24729 = Time_24729_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24729 = Time_24729_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24729 = Time_24729_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24729 = USER_ID[24729].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24729 = np.nan_to_num(Self_control4_24729)
Self_control4_24729 = Self_control4_24729.max()

Self_control5_24729 = USER_ID[24729].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24729 = np.nan_to_num(Self_control5_24729)
Self_control5_24729 = Self_control5_24729.min()

Self_control6_24729 = USER_ID[24729].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24729 = np.nan_to_num(Self_control6_24729)
Self_control6_24729 = Self_control6_24729.sum() 
Self_control6_24729 = Self_control6_24729 / 57

Self_control7_24729 = USER_ID[24729].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24729 = np.nan_to_num(Self_control7_24729)
Self_control7_24729 = Self_control7_24729[20:40].mean()

#(3) Engagement
Engagement_24729_V = Time_24729_V    #视频观看时长
Engagement_24729_T = Time_24729_T    #文本阅读时长
Engagement_24729_H = Time_24729_H    #作业花费时长

Engagement1_24729 = USER_ID[24729].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24729 = np.nan_to_num(Engagement1_24729).sum()

Engagement2_24729 = statistics.mean(Engagement_24729_V)    #平均每次花费在视频学习的时间
Engagement3_24729 = statistics.mean(Engagement_24729_T)    #平均每次花费在文本课件的时间
Engagement4_24729 = statistics.mean(Engagement_24729_H)    #平均每次花费在作业答题的时间
Engagement5_24729 = 57    #学习次数(登入次数)
Engagement6_24729 = 15    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24729 = Time_24729_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24729 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24729 = USER_ID[24729].loc[:, '访问时长(seconds)'].values
Self_perception1_24729 = np.nan_to_num(Self_perception1_24729)

Self_perception1_24729 = 1/((Self_perception1_24729[:20].sum() 
                         - Self_perception1_24729[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24729 = 1/((statistics.mean(Grit_24729_V[:7]) 
                         - statistics.mean(Grit_24729_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24729 = 1/((statistics.mean(Grit_24729_T[:2]) 
                         - statistics.mean(Grit_24729_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24729 = 1/((statistics.mean(Grit_24729_H[:9]) 
                         - statistics.mean(Grit_24729_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24729 = USER_ID[24729].loc[:, ['高过门槛时长']].values
Motivation1_24729 = np.nan_to_num(Motivation1_24729).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24729 = USER_ID[24729].loc[c4, ['高过门槛时长']].values
Motivation2_24729 = np.nan_to_num(Motivation2_24729).sum()
#文挡高过门槛时长总和
Motivation3_24729 = USER_ID[24729].loc[c5, ['高过门槛时长']].values   
Motivation3_24729 = np.nan_to_num(Motivation3_24729).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24729 = np.array(USER_ID[24729].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24729 = np.nan_to_num(Motivation4_24729)
Motivation4_24729 = statistics.mean(Motivation4_24729 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24729 = np.array(USER_ID[24729].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24729 = np.nan_to_num(Motivation5_24729)
Motivation5_24729 = statistics.mean(Motivation5_24729 / c2)

#选修花费总时长
Motivation6_24729 = USER_ID[24729].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24729 = np.nan_to_num(Motivation6_24729).sum()

#(选修花费/页数)的平均
Motivation7_24729 = Motivation6_24729 / (11+8)
Motivation8_24729 = Motivation7_24729/Motivation5_24729    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24729 = 0.97    #完成进度*

# %%
USER_ID[24728]

# %%
USER_ID[24728].reset_index(inplace=True)
USER_ID[24728].set_index('活动名称', inplace=True)
print(USER_ID[24728].shape)
# USER_ID[24728]

Time_24728_V = USER_ID[24728].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24728_V = np.nan_to_num(Time_24728_V)

Time_24728_T = USER_ID[24728].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24728_T = np.nan_to_num(Time_24728_T)

Time_24728_H = USER_ID[24728].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24728_H = np.nan_to_num(Time_24728_H)

#(1) Grit
Grit_24728_V = Time_24728_V / c1  #视频观看时长/视频总时长
Grit_24728_T = Time_24728_T / c2   #文本阅读时长/文本页数
Grit_24728_H = Time_24728_H /c3   #作业花费时长/作业问题数

Grit1_24728 = statistics.mean(Grit_24728_V)    #(视频观看时长/视频总时长)的平均
Grit2_24728 = statistics.median(Grit_24728_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24728 = 1/statistics.stdev(Grit_24728_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24728 = 1/(max(Grit_24728_V)-min(Grit_24728_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24728 = statistics.mean(Grit_24728_T)    #(文本阅读时长/文本页数)的平均
Grit6_24728 = statistics.median(Grit_24728_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24728 = 1/statistics.stdev(Grit_24728_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24728 = 1/(max(Grit_24728_T)-min(Grit_24728_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24728 = statistics.mean(Grit_24728_H)    #(作业花费时长/作业问题数)的平均
Grit10_24728 = statistics.median(Grit_24728_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24728 = 1/statistics.stdev(Grit_24728_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24728 = 1/(max(Grit_24728_H)-min(Grit_24728_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24728 = Time_24728_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24728 = Time_24728_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24728 = Time_24728_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24728 = USER_ID[24728].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24728 = np.nan_to_num(Self_control4_24728)
Self_control4_24728 = Self_control4_24728.max()

Self_control5_24728 = USER_ID[24728].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24728 = np.nan_to_num(Self_control5_24728)
Self_control5_24728 = Self_control5_24728.min()

Self_control6_24728 = USER_ID[24728].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24728 = np.nan_to_num(Self_control6_24728)
Self_control6_24728 = Self_control6_24728.sum() 
Self_control6_24728 = Self_control6_24728 / 59

Self_control7_24728 = USER_ID[24728].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24728 = np.nan_to_num(Self_control7_24728)
Self_control7_24728 = Self_control7_24728[20:40].mean()

#(3) Engagement
Engagement_24728_V = Time_24728_V    #视频观看时长
Engagement_24728_T = Time_24728_T    #文本阅读时长
Engagement_24728_H = Time_24728_H    #作业花费时长

Engagement1_24728 = USER_ID[24728].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24728 = np.nan_to_num(Engagement1_24728).sum()

Engagement2_24728 = statistics.mean(Engagement_24728_V)    #平均每次花费在视频学习的时间
Engagement3_24728 = statistics.mean(Engagement_24728_T)    #平均每次花费在文本课件的时间
Engagement4_24728 = statistics.mean(Engagement_24728_H)    #平均每次花费在作业答题的时间
Engagement5_24728 = 59    #学习次数(登入次数)
Engagement6_24728 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24728 = Time_24728_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24728 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24728 = USER_ID[24728].loc[:, '访问时长(seconds)'].values
Self_perception1_24728 = np.nan_to_num(Self_perception1_24728)

Self_perception1_24728 = 1/((Self_perception1_24728[:20].sum() 
                         - Self_perception1_24728[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24728 = 1/((statistics.mean(Grit_24728_V[:7]) 
                         - statistics.mean(Grit_24728_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24728 = 1/((statistics.mean(Grit_24728_T[:2]) 
                         - statistics.mean(Grit_24728_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24728 = 1/((statistics.mean(Grit_24728_H[:9]) 
                         - statistics.mean(Grit_24728_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24728 = USER_ID[24728].loc[:, ['高过门槛时长']].values
Motivation1_24728 = np.nan_to_num(Motivation1_24728).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24728 = USER_ID[24728].loc[c4, ['高过门槛时长']].values
Motivation2_24728 = np.nan_to_num(Motivation2_24728).sum()
#文挡高过门槛时长总和
Motivation3_24728 = USER_ID[24728].loc[c5, ['高过门槛时长']].values   
Motivation3_24728 = np.nan_to_num(Motivation3_24728).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24728 = np.array(USER_ID[24728].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24728 = np.nan_to_num(Motivation4_24728)
Motivation4_24728 = statistics.mean(Motivation4_24728 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24728 = np.array(USER_ID[24728].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24728 = np.nan_to_num(Motivation5_24728)
Motivation5_24728 = statistics.mean(Motivation5_24728 / c2)

#选修花费总时长
Motivation6_24728 = USER_ID[24728].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24728 = np.nan_to_num(Motivation6_24728).sum()

#(选修花费/页数)的平均
Motivation7_24728 = Motivation6_24728 / (11+8)
Motivation8_24728 = Motivation7_24728/Motivation5_24728    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24728 = 0.97    #完成进度*

# %%
USER_ID[24732]

# %%
USER_ID[24732].reset_index(inplace=True)
USER_ID[24732].set_index('活动名称', inplace=True)
print(USER_ID[24732].shape) 
# USER_ID[24732]

Time_24732_V = USER_ID[24732].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24732_V = np.nan_to_num(Time_24732_V)

Time_24732_T = USER_ID[24732].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24732_T = np.nan_to_num(Time_24732_T)

Time_24732_H = USER_ID[24732].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24732_H = np.nan_to_num(Time_24732_H)

#(1) Grit
Grit_24732_V = Time_24732_V / c1  #视频观看时长/视频总时长
Grit_24732_T = Time_24732_T / c2   #文本阅读时长/文本页数
Grit_24732_H = Time_24732_H /c3   #作业花费时长/作业问题数

Grit1_24732 = statistics.mean(Grit_24732_V)    #(视频观看时长/视频总时长)的平均
Grit2_24732 = statistics.median(Grit_24732_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24732 = 1/statistics.stdev(Grit_24732_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24732 = 1/(max(Grit_24732_V)-min(Grit_24732_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24732 = statistics.mean(Grit_24732_T)    #(文本阅读时长/文本页数)的平均
Grit6_24732 = statistics.median(Grit_24732_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24732 = 1/statistics.stdev(Grit_24732_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24732 = 1/(max(Grit_24732_T)-min(Grit_24732_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24732 = statistics.mean(Grit_24732_H)    #(作业花费时长/作业问题数)的平均
Grit10_24732 = statistics.median(Grit_24732_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24732 = 1/statistics.stdev(Grit_24732_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24732 = 1/(max(Grit_24732_H)-min(Grit_24732_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24732 = Time_24732_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24732 = Time_24732_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24732 = Time_24732_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24732 = USER_ID[24732].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24732 = np.nan_to_num(Self_control4_24732)
Self_control4_24732 = Self_control4_24732.max()

Self_control5_24732 = USER_ID[24732].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24732 = np.nan_to_num(Self_control5_24732)
Self_control5_24732 = Self_control5_24732.min()

Self_control6_24732 = USER_ID[24732].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24732 = np.nan_to_num(Self_control6_24732)
Self_control6_24732 = Self_control6_24732.sum() 
Self_control6_24732 = Self_control6_24732 / 63

Self_control7_24732 = USER_ID[24732].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24732 = np.nan_to_num(Self_control7_24732)
Self_control7_24732 = Self_control7_24732[20:40].mean()

#(3) Engagement
Engagement_24732_V = Time_24732_V    #视频观看时长
Engagement_24732_T = Time_24732_T    #文本阅读时长
Engagement_24732_H = Time_24732_H    #作业花费时长

Engagement1_24732 = USER_ID[24732].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24732 = np.nan_to_num(Engagement1_24732).sum()

Engagement2_24732 = statistics.mean(Engagement_24732_V)    #平均每次花费在视频学习的时间
Engagement3_24732 = statistics.mean(Engagement_24732_T)    #平均每次花费在文本课件的时间
Engagement4_24732 = statistics.mean(Engagement_24732_H)    #平均每次花费在作业答题的时间
Engagement5_24732 = 63    #学习次数(登入次数)
Engagement6_24732 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24732 = Time_24732_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24732 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24732 = USER_ID[24732].loc[:, '访问时长(seconds)'].values
Self_perception1_24732 = np.nan_to_num(Self_perception1_24732)

Self_perception1_24732 = 1/((Self_perception1_24732[:20].sum() 
                         - Self_perception1_24732[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24732 = 1/((statistics.mean(Grit_24732_V[:7]) 
                         - statistics.mean(Grit_24732_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24732 = 1/((statistics.mean(Grit_24732_T[:2]) 
                         - statistics.mean(Grit_24732_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24732 = 1/((statistics.mean(Grit_24732_H[:9]) 
                         - statistics.mean(Grit_24732_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24732 = USER_ID[24732].loc[:, ['高过门槛时长']].values
Motivation1_24732 = np.nan_to_num(Motivation1_24732).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24732 = USER_ID[24732].loc[c4, ['高过门槛时长']].values
Motivation2_24732 = np.nan_to_num(Motivation2_24732).sum()
#文挡高过门槛时长总和
Motivation3_24732 = USER_ID[24732].loc[c5, ['高过门槛时长']].values   
Motivation3_24732 = np.nan_to_num(Motivation3_24732).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24732 = np.array(USER_ID[24732].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24732 = np.nan_to_num(Motivation4_24732)
Motivation4_24732 = statistics.mean(Motivation4_24732 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24732 = np.array(USER_ID[24732].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24732 = np.nan_to_num(Motivation5_24732)
Motivation5_24732 = statistics.mean(Motivation5_24732 / c2)

#选修花费总时长
Motivation6_24732 = USER_ID[24732].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24732 = np.nan_to_num(Motivation6_24732).sum()

#(选修花费/页数)的平均
Motivation7_24732 = Motivation6_24732 / (11+8)
Motivation8_24732 = Motivation7_24732/Motivation5_24732    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24732 = 0.97    #完成进度*

# %%
USER_ID[24733]

# %%
USER_ID[24733].reset_index(inplace=True)
USER_ID[24733].set_index('活动名称', inplace=True)
print(USER_ID[24733].shape) 
# USER_ID[24733]

Time_24733_V = USER_ID[24733].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24733_V = np.nan_to_num(Time_24733_V)

Time_24733_T = USER_ID[24733].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24733_T = np.nan_to_num(Time_24733_T)

Time_24733_H = USER_ID[24733].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24733_H = np.nan_to_num(Time_24733_H)

#(1) Grit
Grit_24733_V = Time_24733_V / c1  #视频观看时长/视频总时长
Grit_24733_T = Time_24733_T / c2   #文本阅读时长/文本页数
Grit_24733_H = Time_24733_H /c3   #作业花费时长/作业问题数

Grit1_24733 = statistics.mean(Grit_24733_V)    #(视频观看时长/视频总时长)的平均
Grit2_24733 = statistics.median(Grit_24733_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24733 = 1/statistics.stdev(Grit_24733_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24733 = 1/(max(Grit_24733_V)-min(Grit_24733_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24733 = statistics.mean(Grit_24733_T)    #(文本阅读时长/文本页数)的平均
Grit6_24733 = statistics.median(Grit_24733_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24733 = 1/statistics.stdev(Grit_24733_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24733 = 1/(max(Grit_24733_T)-min(Grit_24733_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24733 = statistics.mean(Grit_24733_H)    #(作业花费时长/作业问题数)的平均
Grit10_24733 = statistics.median(Grit_24733_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24733 = 1/statistics.stdev(Grit_24733_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24733 = 1/(max(Grit_24733_H)-min(Grit_24733_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24733 = Time_24733_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24733 = Time_24733_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24733 = Time_24733_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24733 = USER_ID[24733].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24733 = np.nan_to_num(Self_control4_24733)
Self_control4_24733 = Self_control4_24733.max()

Self_control5_24733 = USER_ID[24733].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24733 = np.nan_to_num(Self_control5_24733)
Self_control5_24733 = Self_control5_24733.min()

Self_control6_24733 = USER_ID[24733].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24733 = np.nan_to_num(Self_control6_24733)
Self_control6_24733 = Self_control6_24733.sum() 
Self_control6_24733 = Self_control6_24733 / 61

Self_control7_24733 = USER_ID[24733].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24733 = np.nan_to_num(Self_control7_24733)
Self_control7_24733 = Self_control7_24733[20:40].mean()

#(3) Engagement
Engagement_24733_V = Time_24733_V    #视频观看时长
Engagement_24733_T = Time_24733_T    #文本阅读时长
Engagement_24733_H = Time_24733_H    #作业花费时长

Engagement1_24733 = USER_ID[24733].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24733 = np.nan_to_num(Engagement1_24733).sum()

Engagement2_24733 = statistics.mean(Engagement_24733_V)    #平均每次花费在视频学习的时间
Engagement3_24733 = statistics.mean(Engagement_24733_T)    #平均每次花费在文本课件的时间
Engagement4_24733 = statistics.mean(Engagement_24733_H)    #平均每次花费在作业答题的时间
Engagement5_24733 = 61    #学习次数(登入次数)
Engagement6_24733 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24733 = Time_24733_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24733 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24733 = USER_ID[24733].loc[:, '访问时长(seconds)'].values
Self_perception1_24733 = np.nan_to_num(Self_perception1_24733)

Self_perception1_24733 = 1/((Self_perception1_24733[:20].sum() 
                         - Self_perception1_24733[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24733 = 1/((statistics.mean(Grit_24733_V[:7]) 
                         - statistics.mean(Grit_24733_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24733 = 1/((statistics.mean(Grit_24733_T[:2]) 
                         - statistics.mean(Grit_24733_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24733 = 1/((statistics.mean(Grit_24733_H[:9]) 
                         - statistics.mean(Grit_24733_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24733 = USER_ID[24733].loc[:, ['高过门槛时长']].values
Motivation1_24733 = np.nan_to_num(Motivation1_24733).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24733 = USER_ID[24733].loc[c4, ['高过门槛时长']].values
Motivation2_24733 = np.nan_to_num(Motivation2_24733).sum()
#文挡高过门槛时长总和
Motivation3_24733 = USER_ID[24733].loc[c5, ['高过门槛时长']].values   
Motivation3_24733 = np.nan_to_num(Motivation3_24733).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24733 = np.array(USER_ID[24733].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24733 = np.nan_to_num(Motivation4_24733)
Motivation4_24733 = statistics.mean(Motivation4_24733 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24733 = np.array(USER_ID[24733].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24733 = np.nan_to_num(Motivation5_24733)
Motivation5_24733 = statistics.mean(Motivation5_24733 / c2)

#选修花费总时长
Motivation6_24733 = USER_ID[24733].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24733 = np.nan_to_num(Motivation6_24733).sum()

#(选修花费/页数)的平均
Motivation7_24733 = Motivation6_24733 / (11+8)
Motivation8_24733 = Motivation7_24733/Motivation5_24733    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24733 = 0.97    #完成进度*

# %%
USER_ID[24725]

# %%
USER_ID[24725].reset_index(inplace=True)
USER_ID[24725].set_index('活动名称', inplace=True)
print(USER_ID[24725].shape)
# USER_ID[24725]

Time_24725_V = USER_ID[24725].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24725_V = np.nan_to_num(Time_24725_V)

Time_24725_T = USER_ID[24725].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24725_T = np.nan_to_num(Time_24725_T)

Time_24725_H = USER_ID[24725].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24725_H = np.nan_to_num(Time_24725_H)

#(1) Grit
Grit_24725_V = Time_24725_V / c1  #视频观看时长/视频总时长
Grit_24725_T = Time_24725_T / c2   #文本阅读时长/文本页数
Grit_24725_H = Time_24725_H /c3   #作业花费时长/作业问题数

Grit1_24725 = statistics.mean(Grit_24725_V)    #(视频观看时长/视频总时长)的平均
Grit2_24725 = statistics.median(Grit_24725_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24725 = 1/statistics.stdev(Grit_24725_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24725 = 1/(max(Grit_24725_V)-min(Grit_24725_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24725 = statistics.mean(Grit_24725_T)    #(文本阅读时长/文本页数)的平均
Grit6_24725 = statistics.median(Grit_24725_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24725 = 1/statistics.stdev(Grit_24725_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24725 = 1/(max(Grit_24725_T)-min(Grit_24725_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24725 = statistics.mean(Grit_24725_H)    #(作业花费时长/作业问题数)的平均
Grit10_24725 = statistics.median(Grit_24725_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24725 = 1/statistics.stdev(Grit_24725_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24725 = 1/(max(Grit_24725_H)-min(Grit_24725_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24725 = Time_24725_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24725 = Time_24725_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24725 = Time_24725_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24725 = USER_ID[24725].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24725 = np.nan_to_num(Self_control4_24725)
Self_control4_24725 = Self_control4_24725.max()

Self_control5_24725 = USER_ID[24725].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24725 = np.nan_to_num(Self_control5_24725)
Self_control5_24725 = Self_control5_24725.min()

Self_control6_24725 = USER_ID[24725].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24725 = np.nan_to_num(Self_control6_24725)
Self_control6_24725 = Self_control6_24725.sum() 
Self_control6_24725 = Self_control6_24725 / 63

Self_control7_24725 = USER_ID[24725].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24725 = np.nan_to_num(Self_control7_24725)
Self_control7_24725 = Self_control7_24725[20:40].mean()

#(3) Engagement
Engagement_24725_V = Time_24725_V    #视频观看时长
Engagement_24725_T = Time_24725_T    #文本阅读时长
Engagement_24725_H = Time_24725_H    #作业花费时长

Engagement1_24725 = USER_ID[24725].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24725 = np.nan_to_num(Engagement1_24725).sum()

Engagement2_24725 = statistics.mean(Engagement_24725_V)    #平均每次花费在视频学习的时间
Engagement3_24725 = statistics.mean(Engagement_24725_T)    #平均每次花费在文本课件的时间
Engagement4_24725 = statistics.mean(Engagement_24725_H)    #平均每次花费在作业答题的时间
Engagement5_24725 = 63    #学习次数(登入次数)
Engagement6_24725 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24725 = Time_24725_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24725 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24725 = USER_ID[24725].loc[:, '访问时长(seconds)'].values
Self_perception1_24725 = np.nan_to_num(Self_perception1_24725)

Self_perception1_24725 = 1/((Self_perception1_24725[:20].sum() 
                         - Self_perception1_24725[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24725 = 1/((statistics.mean(Grit_24725_V[:7]) 
                         - statistics.mean(Grit_24725_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24725 = 1/((statistics.mean(Grit_24725_T[:2]) 
                         - statistics.mean(Grit_24725_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24725 = 1/((statistics.mean(Grit_24725_H[:9]) 
                         - statistics.mean(Grit_24725_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24725 = USER_ID[24725].loc[:, ['高过门槛时长']].values
Motivation1_24725 = np.nan_to_num(Motivation1_24725).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24725 = USER_ID[24725].loc[c4, ['高过门槛时长']].values
Motivation2_24725 = np.nan_to_num(Motivation2_24725).sum()
#文挡高过门槛时长总和
Motivation3_24725 = USER_ID[24725].loc[c5, ['高过门槛时长']].values   
Motivation3_24725 = np.nan_to_num(Motivation3_24725).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24725 = np.array(USER_ID[24725].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24725 = np.nan_to_num(Motivation4_24725)
Motivation4_24725 = statistics.mean(Motivation4_24725 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24725 = np.array(USER_ID[24725].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24725 = np.nan_to_num(Motivation5_24725)
Motivation5_24725 = statistics.mean(Motivation5_24725 / c2)

#选修花费总时长
Motivation6_24725 = USER_ID[24725].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24725 = np.nan_to_num(Motivation6_24725).sum()

#(选修花费/页数)的平均
Motivation7_24725 = Motivation6_24725 / (11+8)
Motivation8_24725 = Motivation7_24725/Motivation5_24725    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24725 = 0.97    #完成进度*

# %%
USER_ID[24726]

# %%
USER_ID[24726].reset_index(inplace=True)
USER_ID[24726].set_index('活动名称', inplace=True)
print(USER_ID[24726].shape) 
# USER_ID[24726]

Time_24726_V = USER_ID[24726].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24726_V = np.nan_to_num(Time_24726_V)

Time_24726_T = USER_ID[24726].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24726_T = np.nan_to_num(Time_24726_T)

Time_24726_H = USER_ID[24726].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24726_H = np.nan_to_num(Time_24726_H)

#(1) Grit
Grit_24726_V = Time_24726_V / c1  #视频观看时长/视频总时长
Grit_24726_T = Time_24726_T / c2   #文本阅读时长/文本页数
Grit_24726_H = Time_24726_H /c3   #作业花费时长/作业问题数

Grit1_24726 = statistics.mean(Grit_24726_V)    #(视频观看时长/视频总时长)的平均
Grit2_24726 = statistics.median(Grit_24726_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24726 = 1/statistics.stdev(Grit_24726_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24726 = 1/(max(Grit_24726_V)-min(Grit_24726_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24726 = statistics.mean(Grit_24726_T)    #(文本阅读时长/文本页数)的平均
Grit6_24726 = statistics.median(Grit_24726_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24726 = 1/statistics.stdev(Grit_24726_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24726 = 1/(max(Grit_24726_T)-min(Grit_24726_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24726 = statistics.mean(Grit_24726_H)    #(作业花费时长/作业问题数)的平均
Grit10_24726 = statistics.median(Grit_24726_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24726 = 1/statistics.stdev(Grit_24726_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24726 = 1/(max(Grit_24726_H)-min(Grit_24726_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24726 = Time_24726_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24726 = Time_24726_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24726 = Time_24726_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24726 = USER_ID[24726].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24726 = np.nan_to_num(Self_control4_24726)
Self_control4_24726 = Self_control4_24726.max()

Self_control5_24726 = USER_ID[24726].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24726 = np.nan_to_num(Self_control5_24726)
Self_control5_24726 = Self_control5_24726.min()

Self_control6_24726 = USER_ID[24726].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24726 = np.nan_to_num(Self_control6_24726)
Self_control6_24726 = Self_control6_24726.sum() 
Self_control6_24726 = Self_control6_24726 / 58

Self_control7_24726 = USER_ID[24726].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24726 = np.nan_to_num(Self_control7_24726)
Self_control7_24726 = Self_control7_24726[20:40].mean()

#(3) Engagement
Engagement_24726_V = Time_24726_V    #视频观看时长
Engagement_24726_T = Time_24726_T    #文本阅读时长
Engagement_24726_H = Time_24726_H    #作业花费时长

Engagement1_24726 = USER_ID[24726].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24726 = np.nan_to_num(Engagement1_24726).sum()

Engagement2_24726 = statistics.mean(Engagement_24726_V)    #平均每次花费在视频学习的时间
Engagement3_24726 = statistics.mean(Engagement_24726_T)    #平均每次花费在文本课件的时间
Engagement4_24726 = statistics.mean(Engagement_24726_H)    #平均每次花费在作业答题的时间
Engagement5_24726 = 58    #学习次数(登入次数)
Engagement6_24726 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24726 = Time_24726_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24726 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24726 = USER_ID[24726].loc[:, '访问时长(seconds)'].values
Self_perception1_24726 = np.nan_to_num(Self_perception1_24726)

Self_perception1_24726 = 1/((Self_perception1_24726[:20].sum() 
                         - Self_perception1_24726[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24726 = 1/((statistics.mean(Grit_24726_V[:7]) 
                         - statistics.mean(Grit_24726_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24726 = 1/((statistics.mean(Grit_24726_T[:2]) 
                         - statistics.mean(Grit_24726_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24726 = 1/((statistics.mean(Grit_24726_H[:9]) 
                         - statistics.mean(Grit_24726_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24726 = USER_ID[24726].loc[:, ['高过门槛时长']].values
Motivation1_24726 = np.nan_to_num(Motivation1_24726).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24726 = USER_ID[24726].loc[c4, ['高过门槛时长']].values
Motivation2_24726 = np.nan_to_num(Motivation2_24726).sum()
#文挡高过门槛时长总和
Motivation3_24726 = USER_ID[24726].loc[c5, ['高过门槛时长']].values   
Motivation3_24726 = np.nan_to_num(Motivation3_24726).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24726 = np.array(USER_ID[24726].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24726 = np.nan_to_num(Motivation4_24726)
Motivation4_24726 = statistics.mean(Motivation4_24726 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24726 = np.array(USER_ID[24726].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24726 = np.nan_to_num(Motivation5_24726)
Motivation5_24726 = statistics.mean(Motivation5_24726 / c2)

#选修花费总时长
Motivation6_24726 = USER_ID[24726].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24726 = np.nan_to_num(Motivation6_24726).sum()

#(选修花费/页数)的平均
Motivation7_24726 = Motivation6_24726 / (11+8)
Motivation8_24726 = Motivation7_24726/Motivation5_24726    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24726 = 0.97    #完成进度*

# %%
USER_ID[24723]

# %%
USER_ID[24723].reset_index(inplace=True)
USER_ID[24723].set_index('活动名称', inplace=True)
print(USER_ID[24723].shape) 
# USER_ID[24723]

Time_24723_V = USER_ID[24723].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24723_V = np.nan_to_num(Time_24723_V)

Time_24723_T = USER_ID[24723].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24723_T = np.nan_to_num(Time_24723_T)

Time_24723_H = USER_ID[24723].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24723_H = np.nan_to_num(Time_24723_H)

#(1) Grit
Grit_24723_V = Time_24723_V / c1  #视频观看时长/视频总时长
Grit_24723_T = Time_24723_T / c2   #文本阅读时长/文本页数
Grit_24723_H = Time_24723_H /c3   #作业花费时长/作业问题数

Grit1_24723 = statistics.mean(Grit_24723_V)    #(视频观看时长/视频总时长)的平均
Grit2_24723 = statistics.median(Grit_24723_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24723 = 1/statistics.stdev(Grit_24723_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24723 = 1/(max(Grit_24723_V)-min(Grit_24723_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24723 = statistics.mean(Grit_24723_T)    #(文本阅读时长/文本页数)的平均
Grit6_24723 = statistics.median(Grit_24723_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24723 = 1/statistics.stdev(Grit_24723_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24723 = 1/(max(Grit_24723_T)-min(Grit_24723_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24723 = statistics.mean(Grit_24723_H)    #(作业花费时长/作业问题数)的平均
Grit10_24723 = statistics.median(Grit_24723_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24723 = 1/statistics.stdev(Grit_24723_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24723 = 1/(max(Grit_24723_H)-min(Grit_24723_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24723 = Time_24723_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24723 = Time_24723_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24723 = Time_24723_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24723 = USER_ID[24723].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24723 = np.nan_to_num(Self_control4_24723)
Self_control4_24723 = Self_control4_24723.max()

Self_control5_24723 = USER_ID[24723].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24723 = np.nan_to_num(Self_control5_24723)
Self_control5_24723 = Self_control5_24723.min()

Self_control6_24723 = USER_ID[24723].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24723 = np.nan_to_num(Self_control6_24723)
Self_control6_24723 = Self_control6_24723.sum() 
Self_control6_24723 = Self_control6_24723 / 57

Self_control7_24723 = USER_ID[24723].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24723 = np.nan_to_num(Self_control7_24723)
Self_control7_24723 = Self_control7_24723[20:40].mean()

#(3) Engagement
Engagement_24723_V = Time_24723_V    #视频观看时长
Engagement_24723_T = Time_24723_T    #文本阅读时长
Engagement_24723_H = Time_24723_H    #作业花费时长

Engagement1_24723 = USER_ID[24723].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24723 = np.nan_to_num(Engagement1_24723).sum()

Engagement2_24723 = statistics.mean(Engagement_24723_V)    #平均每次花费在视频学习的时间
Engagement3_24723 = statistics.mean(Engagement_24723_T)    #平均每次花费在文本课件的时间
Engagement4_24723 = statistics.mean(Engagement_24723_H)    #平均每次花费在作业答题的时间
Engagement5_24723 = 57    #学习次数(登入次数)
Engagement6_24723 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24723 = Time_24723_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24723 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24723 = USER_ID[24723].loc[:, '访问时长(seconds)'].values
Self_perception1_24723 = np.nan_to_num(Self_perception1_24723)

Self_perception1_24723 = 1/((Self_perception1_24723[:20].sum() 
                         - Self_perception1_24723[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24723 = 1/((statistics.mean(Grit_24723_V[:7]) 
                         - statistics.mean(Grit_24723_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24723 = 1/((statistics.mean(Grit_24723_T[:2]) 
                         - statistics.mean(Grit_24723_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24723 = 1/((statistics.mean(Grit_24723_H[:9]) 
                         - statistics.mean(Grit_24723_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24723 = USER_ID[24723].loc[:, ['高过门槛时长']].values
Motivation1_24723 = np.nan_to_num(Motivation1_24723).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24723 = USER_ID[24723].loc[c4, ['高过门槛时长']].values
Motivation2_24723 = np.nan_to_num(Motivation2_24723).sum()
#文挡高过门槛时长总和
Motivation3_24723 = USER_ID[24723].loc[c5, ['高过门槛时长']].values   
Motivation3_24723 = np.nan_to_num(Motivation3_24723).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24723 = np.array(USER_ID[24723].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24723 = np.nan_to_num(Motivation4_24723)
Motivation4_24723 = statistics.mean(Motivation4_24723 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24723 = np.array(USER_ID[24723].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24723 = np.nan_to_num(Motivation5_24723)
Motivation5_24723 = statistics.mean(Motivation5_24723 / c2)

#选修花费总时长
Motivation6_24723 = USER_ID[24723].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24723 = np.nan_to_num(Motivation6_24723).sum()

#(选修花费/页数)的平均
Motivation7_24723 = Motivation6_24723 / (11+8)
Motivation8_24723 = Motivation7_24723/Motivation5_24723    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24723 = 0.97    #完成进度*

# %%
USER_ID[24724]

# %%
USER_ID[24724].reset_index(inplace=True)
USER_ID[24724].set_index('活动名称', inplace=True)
print(USER_ID[24724].shape)
# USER_ID[24724]

Time_24724_V = USER_ID[24724].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24724_V = np.nan_to_num(Time_24724_V)

Time_24724_T = USER_ID[24724].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24724_T = np.nan_to_num(Time_24724_T)

Time_24724_H = USER_ID[24724].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24724_H = np.nan_to_num(Time_24724_H)

#(1) Grit
Grit_24724_V = Time_24724_V / c1  #视频观看时长/视频总时长
Grit_24724_T = Time_24724_T / c2   #文本阅读时长/文本页数
Grit_24724_H = Time_24724_H /c3   #作业花费时长/作业问题数

Grit1_24724 = statistics.mean(Grit_24724_V)    #(视频观看时长/视频总时长)的平均
Grit2_24724 = statistics.median(Grit_24724_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24724 = 1/statistics.stdev(Grit_24724_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24724 = 1/(max(Grit_24724_V)-min(Grit_24724_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24724 = statistics.mean(Grit_24724_T)    #(文本阅读时长/文本页数)的平均
Grit6_24724 = statistics.median(Grit_24724_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24724 = 1/statistics.stdev(Grit_24724_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24724 = 1/(max(Grit_24724_T)-min(Grit_24724_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24724 = statistics.mean(Grit_24724_H)    #(作业花费时长/作业问题数)的平均
Grit10_24724 = statistics.median(Grit_24724_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24724 = 1/statistics.stdev(Grit_24724_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24724 = 1/(max(Grit_24724_H)-min(Grit_24724_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24724 = Time_24724_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24724 = Time_24724_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24724 = Time_24724_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24724 = USER_ID[24724].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24724 = np.nan_to_num(Self_control4_24724)
Self_control4_24724 = Self_control4_24724.max()

Self_control5_24724 = USER_ID[24724].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24724 = np.nan_to_num(Self_control5_24724)
Self_control5_24724 = Self_control5_24724.min()

Self_control6_24724 = USER_ID[24724].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24724 = np.nan_to_num(Self_control6_24724)
Self_control6_24724 = Self_control6_24724.sum() 
Self_control6_24724 = Self_control6_24724 / 64

Self_control7_24724 = USER_ID[24724].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24724 = np.nan_to_num(Self_control7_24724)
Self_control7_24724 = Self_control7_24724[20:40].mean()

#(3) Engagement
Engagement_24724_V = Time_24724_V    #视频观看时长
Engagement_24724_T = Time_24724_T    #文本阅读时长
Engagement_24724_H = Time_24724_H    #作业花费时长

Engagement1_24724 = USER_ID[24724].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24724 = np.nan_to_num(Engagement1_24724).sum()

Engagement2_24724 = statistics.mean(Engagement_24724_V)    #平均每次花费在视频学习的时间
Engagement3_24724 = statistics.mean(Engagement_24724_T)    #平均每次花费在文本课件的时间
Engagement4_24724 = statistics.mean(Engagement_24724_H)    #平均每次花费在作业答题的时间
Engagement5_24724 = 64    #学习次数(登入次数)
Engagement6_24724 = 9    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24724 = Time_24724_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24724 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24724 = USER_ID[24724].loc[:, '访问时长(seconds)'].values
Self_perception1_24724 = np.nan_to_num(Self_perception1_24724)

Self_perception1_24724 = 1/((Self_perception1_24724[:20].sum() 
                         - Self_perception1_24724[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24724 = 1/((statistics.mean(Grit_24724_V[:7]) 
                         - statistics.mean(Grit_24724_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24724 = 1/((statistics.mean(Grit_24724_T[:2]) 
                         - statistics.mean(Grit_24724_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24724 = 1/((statistics.mean(Grit_24724_H[:9]) 
                         - statistics.mean(Grit_24724_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24724 = USER_ID[24724].loc[:, ['高过门槛时长']].values
Motivation1_24724 = np.nan_to_num(Motivation1_24724).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24724 = USER_ID[24724].loc[c4, ['高过门槛时长']].values
Motivation2_24724 = np.nan_to_num(Motivation2_24724).sum()
#文挡高过门槛时长总和
Motivation3_24724 = USER_ID[24724].loc[c5, ['高过门槛时长']].values   
Motivation3_24724 = np.nan_to_num(Motivation3_24724).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24724 = np.array(USER_ID[24724].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24724 = np.nan_to_num(Motivation4_24724)
Motivation4_24724 = statistics.mean(Motivation4_24724 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24724 = np.array(USER_ID[24724].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24724 = np.nan_to_num(Motivation5_24724)
Motivation5_24724 = statistics.mean(Motivation5_24724 / c2)

#选修花费总时长
Motivation6_24724 = USER_ID[24724].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24724 = np.nan_to_num(Motivation6_24724).sum()

#(选修花费/页数)的平均
Motivation7_24724 = Motivation6_24724 / (11+8)
Motivation8_24724 = Motivation7_24724/Motivation5_24724    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24724 = 0.97    #完成进度*

# %%
USER_ID[24747]

# %%
USER_ID[24747].reset_index(inplace=True)
USER_ID[24747].set_index('活动名称', inplace=True)
print(USER_ID[24747].shape)
# USER_ID[24747]

Time_24747_V = USER_ID[24747].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24747_V = np.nan_to_num(Time_24747_V)

Time_24747_T = USER_ID[24747].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24747_T = np.nan_to_num(Time_24747_T)

Time_24747_H = USER_ID[24747].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24747_H = np.nan_to_num(Time_24747_H)

#(1) Grit
Grit_24747_V = Time_24747_V / c1  #视频观看时长/视频总时长
Grit_24747_T = Time_24747_T / c2   #文本阅读时长/文本页数
Grit_24747_H = Time_24747_H /c3   #作业花费时长/作业问题数

Grit1_24747 = statistics.mean(Grit_24747_V)    #(视频观看时长/视频总时长)的平均
Grit2_24747 = statistics.median(Grit_24747_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24747 = 1/statistics.stdev(Grit_24747_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24747 = 1/(max(Grit_24747_V)-min(Grit_24747_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24747 = statistics.mean(Grit_24747_T)    #(文本阅读时长/文本页数)的平均
Grit6_24747 = statistics.median(Grit_24747_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24747 = 1/statistics.stdev(Grit_24747_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24747 = 1/(max(Grit_24747_T)-min(Grit_24747_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24747 = statistics.mean(Grit_24747_H)    #(作业花费时长/作业问题数)的平均
Grit10_24747 = statistics.median(Grit_24747_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24747 = 1/statistics.stdev(Grit_24747_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24747 = 1/(max(Grit_24747_H)-min(Grit_24747_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24747 = Time_24747_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24747 = Time_24747_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24747 = Time_24747_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24747 = USER_ID[24747].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24747 = np.nan_to_num(Self_control4_24747)
Self_control4_24747 = Self_control4_24747.max()

Self_control5_24747 = USER_ID[24747].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24747 = np.nan_to_num(Self_control5_24747)
Self_control5_24747 = Self_control5_24747.min()

Self_control6_24747 = USER_ID[24747].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24747 = np.nan_to_num(Self_control6_24747)
Self_control6_24747 = Self_control6_24747.sum() 
Self_control6_24747 = Self_control6_24747 / 45

Self_control7_24747 = USER_ID[24747].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24747 = np.nan_to_num(Self_control7_24747)
Self_control7_24747 = Self_control7_24747[20:40].mean()

#(3) Engagement
Engagement_24747_V = Time_24747_V    #视频观看时长
Engagement_24747_T = Time_24747_T    #文本阅读时长
Engagement_24747_H = Time_24747_H    #作业花费时长

Engagement1_24747 = USER_ID[24747].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24747 = np.nan_to_num(Engagement1_24747).sum()

Engagement2_24747 = statistics.mean(Engagement_24747_V)    #平均每次花费在视频学习的时间
Engagement3_24747 = statistics.mean(Engagement_24747_T)    #平均每次花费在文本课件的时间
Engagement4_24747 = statistics.mean(Engagement_24747_H)    #平均每次花费在作业答题的时间
Engagement5_24747 = 45    #学习次数(登入次数)
Engagement6_24747 = 0    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24747 = Time_24747_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24747 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24747 = USER_ID[24747].loc[:, '访问时长(seconds)'].values
Self_perception1_24747 = np.nan_to_num(Self_perception1_24747)

Self_perception1_24747 = 1/((Self_perception1_24747[:20].sum() 
                         - Self_perception1_24747[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24747 = 1/((statistics.mean(Grit_24747_V[:7]) 
                         - statistics.mean(Grit_24747_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24747 = 1/((statistics.mean(Grit_24747_T[:2]) 
                         - statistics.mean(Grit_24747_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24747 = 1/((statistics.mean(Grit_24747_H[:9]) 
                         - statistics.mean(Grit_24747_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24747 = USER_ID[24747].loc[:, ['高过门槛时长']].values
Motivation1_24747 = np.nan_to_num(Motivation1_24747).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24747 = USER_ID[24747].loc[c4, ['高过门槛时长']].values
Motivation2_24747 = np.nan_to_num(Motivation2_24747).sum()
#文挡高过门槛时长总和
Motivation3_24747 = USER_ID[24747].loc[c5, ['高过门槛时长']].values   
Motivation3_24747 = np.nan_to_num(Motivation3_24747).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24747 = np.array(USER_ID[24747].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24747 = np.nan_to_num(Motivation4_24747)
Motivation4_24747 = statistics.mean(Motivation4_24747 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24747 = np.array(USER_ID[24747].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24747 = np.nan_to_num(Motivation5_24747)
Motivation5_24747 = statistics.mean(Motivation5_24747 / c2)

#选修花费总时长
Motivation6_24747 = USER_ID[24747].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24747 = np.nan_to_num(Motivation6_24747).sum()

#(选修花费/页数)的平均
Motivation7_24747 = Motivation6_24747 / (11+8)
Motivation8_24747 = Motivation7_24747/Motivation5_24747    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24747 = 0.65    #完成进度*

# %%
USER_ID[24757]

# %%
USER_ID[24757].reset_index(inplace=True)
USER_ID[24757].set_index('活动名称', inplace=True)
print(USER_ID[24757].shape)
# USER_ID[24757]

Time_24757_V = USER_ID[24757].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24757_V = np.nan_to_num(Time_24757_V)

Time_24757_T = USER_ID[24757].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24757_T = np.nan_to_num(Time_24757_T)

Time_24757_H = USER_ID[24757].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24757_H = np.nan_to_num(Time_24757_H)

#(1) Grit
Grit_24757_V = Time_24757_V / c1  #视频观看时长/视频总时长
Grit_24757_T = Time_24757_T / c2   #文本阅读时长/文本页数
Grit_24757_H = Time_24757_H /c3   #作业花费时长/作业问题数

Grit1_24757 = statistics.mean(Grit_24757_V)    #(视频观看时长/视频总时长)的平均
Grit2_24757 = statistics.median(Grit_24757_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24757 = 1/statistics.stdev(Grit_24757_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24757 = 1/(max(Grit_24757_V)-min(Grit_24757_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24757 = statistics.mean(Grit_24757_T)    #(文本阅读时长/文本页数)的平均
Grit6_24757 = statistics.median(Grit_24757_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24757 = 1/statistics.stdev(Grit_24757_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24757 = 1/(max(Grit_24757_T)-min(Grit_24757_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24757 = statistics.mean(Grit_24757_H)    #(作业花费时长/作业问题数)的平均
Grit10_24757 = statistics.median(Grit_24757_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24757 = 1/statistics.stdev(Grit_24757_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24757 = 1/(max(Grit_24757_H)-min(Grit_24757_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24757 = Time_24757_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24757 = Time_24757_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24757 = Time_24757_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24757 = USER_ID[24757].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24757 = np.nan_to_num(Self_control4_24757)
Self_control4_24757 = Self_control4_24757.max()

Self_control5_24757 = USER_ID[24757].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24757 = np.nan_to_num(Self_control5_24757)
Self_control5_24757 = Self_control5_24757.min()

Self_control6_24757 = USER_ID[24757].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24757 = np.nan_to_num(Self_control6_24757)
Self_control6_24757 = Self_control6_24757.sum() 
Self_control6_24757 = Self_control6_24757 / 63

Self_control7_24757 = USER_ID[24757].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24757 = np.nan_to_num(Self_control7_24757)
Self_control7_24757 = Self_control7_24757[20:40].mean()

#(3) Engagement
Engagement_24757_V = Time_24757_V    #视频观看时长
Engagement_24757_T = Time_24757_T    #文本阅读时长
Engagement_24757_H = Time_24757_H    #作业花费时长

Engagement1_24757 = USER_ID[24757].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24757 = np.nan_to_num(Engagement1_24757).sum()

Engagement2_24757 = statistics.mean(Engagement_24757_V)    #平均每次花费在视频学习的时间
Engagement3_24757 = statistics.mean(Engagement_24757_T)    #平均每次花费在文本课件的时间
Engagement4_24757 = statistics.mean(Engagement_24757_H)    #平均每次花费在作业答题的时间
Engagement5_24757 = 63    #学习次数(登入次数)
Engagement6_24757 = 15    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24757 = Time_24757_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24757 = 1    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24757 = USER_ID[24757].loc[:, '访问时长(seconds)'].values
Self_perception1_24757 = np.nan_to_num(Self_perception1_24757)

Self_perception1_24757 = 1/((Self_perception1_24757[:20].sum() 
                         - Self_perception1_24757[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24757 = 1/((statistics.mean(Grit_24757_V[:7]) 
                         - statistics.mean(Grit_24757_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24757 = 1/((statistics.mean(Grit_24757_T[:2]) 
                         - statistics.mean(Grit_24757_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24757 = 1/((statistics.mean(Grit_24757_H[:9]) 
                         - statistics.mean(Grit_24757_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24757 = USER_ID[24757].loc[:, ['高过门槛时长']].values
Motivation1_24757 = np.nan_to_num(Motivation1_24757).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24757 = USER_ID[24757].loc[c4, ['高过门槛时长']].values
Motivation2_24757 = np.nan_to_num(Motivation2_24757).sum()
#文挡高过门槛时长总和
Motivation3_24757 = USER_ID[24757].loc[c5, ['高过门槛时长']].values   
Motivation3_24757 = np.nan_to_num(Motivation3_24757).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24757 = np.array(USER_ID[24757].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24757 = np.nan_to_num(Motivation4_24757)
Motivation4_24757 = statistics.mean(Motivation4_24757 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24757 = np.array(USER_ID[24757].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24757 = np.nan_to_num(Motivation5_24757)
Motivation5_24757 = statistics.mean(Motivation5_24757 / c2)

#选修花费总时长
Motivation6_24757 = USER_ID[24757].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24757 = np.nan_to_num(Motivation6_24757).sum()

#(选修花费/页数)的平均
Motivation7_24757 = Motivation6_24757 / (11+8)
Motivation8_24757 = Motivation7_24757/Motivation5_24757    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24757 = 1    #完成进度*

# %%
USER_ID[24760]

# %%
USER_ID[24760].reset_index(inplace=True)
USER_ID[24760].set_index('活动名称', inplace=True)
print(USER_ID[24760].shape)
# USER_ID[24760]

Time_24760_V = USER_ID[24760].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24760_V = np.nan_to_num(Time_24760_V)

Time_24760_T = USER_ID[24760].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24760_T = np.nan_to_num(Time_24760_T)

Time_24760_H = USER_ID[24760].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24760_H = np.nan_to_num(Time_24760_H)

#(1) Grit
Grit_24760_V = Time_24760_V / c1  #视频观看时长/视频总时长
Grit_24760_T = Time_24760_T / c2   #文本阅读时长/文本页数
Grit_24760_H = Time_24760_H /c3   #作业花费时长/作业问题数

Grit1_24760 = statistics.mean(Grit_24760_V)    #(视频观看时长/视频总时长)的平均
Grit2_24760 = statistics.median(Grit_24760_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24760 = 1/statistics.stdev(Grit_24760_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24760 = 1/(max(Grit_24760_V)-min(Grit_24760_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24760 = statistics.mean(Grit_24760_T)    #(文本阅读时长/文本页数)的平均
Grit6_24760 = statistics.median(Grit_24760_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24760 = 1/statistics.stdev(Grit_24760_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24760 = 1/(max(Grit_24760_T)-min(Grit_24760_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24760 = statistics.mean(Grit_24760_H)    #(作业花费时长/作业问题数)的平均
Grit10_24760 = statistics.median(Grit_24760_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24760 = 1/statistics.stdev(Grit_24760_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24760 = 1/(max(Grit_24760_H)-min(Grit_24760_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24760 = Time_24760_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24760 = Time_24760_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24760 = Time_24760_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24760 = USER_ID[24760].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24760 = np.nan_to_num(Self_control4_24760)
Self_control4_24760 = Self_control4_24760.max()

Self_control5_24760 = USER_ID[24760].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24760 = np.nan_to_num(Self_control5_24760)
Self_control5_24760 = Self_control5_24760.min()

Self_control6_24760 = USER_ID[24760].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24760 = np.nan_to_num(Self_control6_24760)
Self_control6_24760 = Self_control6_24760.sum() 
Self_control6_24760 = Self_control6_24760 / 58

Self_control7_24760 = USER_ID[24760].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24760 = np.nan_to_num(Self_control7_24760)
Self_control7_24760 = Self_control7_24760[20:40].mean()

#(3) Engagement
Engagement_24760_V = Time_24760_V    #视频观看时长
Engagement_24760_T = Time_24760_T    #文本阅读时长
Engagement_24760_H = Time_24760_H    #作业花费时长

Engagement1_24760 = USER_ID[24760].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24760 = np.nan_to_num(Engagement1_24760).sum()

Engagement2_24760 = statistics.mean(Engagement_24760_V)    #平均每次花费在视频学习的时间
Engagement3_24760 = statistics.mean(Engagement_24760_T)    #平均每次花费在文本课件的时间
Engagement4_24760 = statistics.mean(Engagement_24760_H)    #平均每次花费在作业答题的时间
Engagement5_24760 = 58    #学习次数(登入次数)
Engagement6_24760 = 27    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24760 = Time_24760_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24760 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24760 = USER_ID[24760].loc[:, '访问时长(seconds)'].values
Self_perception1_24760 = np.nan_to_num(Self_perception1_24760)

Self_perception1_24760 = 1/((Self_perception1_24760[:20].sum() 
                         - Self_perception1_24760[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24760 = 1/((statistics.mean(Grit_24760_V[:7]) 
                         - statistics.mean(Grit_24760_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24760 = 1/((statistics.mean(Grit_24760_T[:2]) 
                         - statistics.mean(Grit_24760_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24760 = 1/((statistics.mean(Grit_24760_H[:9]) 
                         - statistics.mean(Grit_24760_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24760 = USER_ID[24760].loc[:, ['高过门槛时长']].values
Motivation1_24760 = np.nan_to_num(Motivation1_24760).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24760 = USER_ID[24760].loc[c4, ['高过门槛时长']].values
Motivation2_24760 = np.nan_to_num(Motivation2_24760).sum()
#文挡高过门槛时长总和
Motivation3_24760 = USER_ID[24760].loc[c5, ['高过门槛时长']].values   
Motivation3_24760 = np.nan_to_num(Motivation3_24760).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24760 = np.array(USER_ID[24760].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24760 = np.nan_to_num(Motivation4_24760)
Motivation4_24760 = statistics.mean(Motivation4_24760 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24760 = np.array(USER_ID[24760].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24760 = np.nan_to_num(Motivation5_24760)
Motivation5_24760 = statistics.mean(Motivation5_24760 / c2)

#选修花费总时长
Motivation6_24760 = USER_ID[24760].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24760 = np.nan_to_num(Motivation6_24760).sum()

#(选修花费/页数)的平均
Motivation7_24760 = Motivation6_24760 / (11+8)
Motivation8_24760 = Motivation7_24760/Motivation5_24760    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24760 = 1    #完成进度*

# %%
USER_ID[24761]

# %%
USER_ID[24761].reset_index(inplace=True)
USER_ID[24761].set_index('活动名称', inplace=True)
print(USER_ID[24761].shape) 
# USER_ID[24761]

Time_24761_V = USER_ID[24761].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24761_V = np.nan_to_num(Time_24761_V)

Time_24761_T = USER_ID[24761].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24761_T = np.nan_to_num(Time_24761_T)

Time_24761_H = USER_ID[24761].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24761_H = np.nan_to_num(Time_24761_H)

#(1) Grit
Grit_24761_V = Time_24761_V / c1  #视频观看时长/视频总时长
Grit_24761_T = Time_24761_T / c2   #文本阅读时长/文本页数
Grit_24761_H = Time_24761_H /c3   #作业花费时长/作业问题数

Grit1_24761 = statistics.mean(Grit_24761_V)    #(视频观看时长/视频总时长)的平均
Grit2_24761 = statistics.median(Grit_24761_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24761 = 1/statistics.stdev(Grit_24761_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24761 = 1/(max(Grit_24761_V)-min(Grit_24761_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24761 = statistics.mean(Grit_24761_T)    #(文本阅读时长/文本页数)的平均
Grit6_24761 = statistics.median(Grit_24761_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24761 = 1/statistics.stdev(Grit_24761_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24761 = 1/(max(Grit_24761_T)-min(Grit_24761_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24761 = statistics.mean(Grit_24761_H)    #(作业花费时长/作业问题数)的平均
Grit10_24761 = statistics.median(Grit_24761_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24761 = 1/statistics.stdev(Grit_24761_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24761 = 1/(max(Grit_24761_H)-min(Grit_24761_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24761 = Time_24761_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24761 = Time_24761_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24761 = Time_24761_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24761 = USER_ID[24761].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24761 = np.nan_to_num(Self_control4_24761)
Self_control4_24761 = Self_control4_24761.max()

Self_control5_24761 = USER_ID[24761].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24761 = np.nan_to_num(Self_control5_24761)
Self_control5_24761 = Self_control5_24761.min()

Self_control6_24761 = USER_ID[24761].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24761 = np.nan_to_num(Self_control6_24761)
Self_control6_24761 = Self_control6_24761.sum() 
Self_control6_24761 = Self_control6_24761 / 46

Self_control7_24761 = USER_ID[24761].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24761 = np.nan_to_num(Self_control7_24761)
Self_control7_24761 = Self_control7_24761[20:40].mean()

#(3) Engagement
Engagement_24761_V = Time_24761_V    #视频观看时长
Engagement_24761_T = Time_24761_T    #文本阅读时长
Engagement_24761_H = Time_24761_H    #作业花费时长

Engagement1_24761 = USER_ID[24761].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24761 = np.nan_to_num(Engagement1_24761).sum()

Engagement2_24761 = statistics.mean(Engagement_24761_V)    #平均每次花费在视频学习的时间
Engagement3_24761 = statistics.mean(Engagement_24761_T)    #平均每次花费在文本课件的时间
Engagement4_24761 = statistics.mean(Engagement_24761_H)    #平均每次花费在作业答题的时间
Engagement5_24761 = 46    #学习次数(登入次数)
Engagement6_24761 = 18    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24761 = Time_24761_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24761 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24761 = USER_ID[24761].loc[:, '访问时长(seconds)'].values
Self_perception1_24761 = np.nan_to_num(Self_perception1_24761)

Self_perception1_24761 = 1/((Self_perception1_24761[:20].sum() 
                         - Self_perception1_24761[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24761 = 1/((statistics.mean(Grit_24761_V[:7]) 
                         - statistics.mean(Grit_24761_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24761 = 1/((statistics.mean(Grit_24761_T[:2]) 
                         - statistics.mean(Grit_24761_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24761 = 1/((statistics.mean(Grit_24761_H[:9]) 
                         - statistics.mean(Grit_24761_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24761 = USER_ID[24761].loc[:, ['高过门槛时长']].values
Motivation1_24761 = np.nan_to_num(Motivation1_24761).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24761 = USER_ID[24761].loc[c4, ['高过门槛时长']].values
Motivation2_24761 = np.nan_to_num(Motivation2_24761).sum()
#文挡高过门槛时长总和
Motivation3_24761 = USER_ID[24761].loc[c5, ['高过门槛时长']].values   
Motivation3_24761 = np.nan_to_num(Motivation3_24761).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24761 = np.array(USER_ID[24761].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24761 = np.nan_to_num(Motivation4_24761)
Motivation4_24761 = statistics.mean(Motivation4_24761 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24761 = np.array(USER_ID[24761].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24761 = np.nan_to_num(Motivation5_24761)
Motivation5_24761 = statistics.mean(Motivation5_24761 / c2)

#选修花费总时长
Motivation6_24761 = USER_ID[24761].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24761 = np.nan_to_num(Motivation6_24761).sum()

#(选修花费/页数)的平均
Motivation7_24761 = Motivation6_24761 / (11+8)
Motivation8_24761 = Motivation7_24761/Motivation5_24761    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24761 = 1    #完成进度*

# %%
USER_ID[24770]

# %%
USER_ID[24770].reset_index(inplace=True)
USER_ID[24770].set_index('活动名称', inplace=True)
print(USER_ID[24770].shape)
# USER_ID[24770]

Time_24770_V = USER_ID[24770].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24770_V = np.nan_to_num(Time_24770_V)

Time_24770_T = USER_ID[24770].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24770_T = np.nan_to_num(Time_24770_T)

Time_24770_H = USER_ID[24770].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24770_H = np.nan_to_num(Time_24770_H)

#(1) Grit
Grit_24770_V = Time_24770_V / c1  #视频观看时长/视频总时长
Grit_24770_T = Time_24770_T / c2   #文本阅读时长/文本页数
Grit_24770_H = Time_24770_H /c3   #作业花费时长/作业问题数

Grit1_24770 = statistics.mean(Grit_24770_V)    #(视频观看时长/视频总时长)的平均
Grit2_24770 = statistics.median(Grit_24770_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24770 = 1/statistics.stdev(Grit_24770_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24770 = 1/(max(Grit_24770_V)-min(Grit_24770_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24770 = statistics.mean(Grit_24770_T)    #(文本阅读时长/文本页数)的平均
Grit6_24770 = statistics.median(Grit_24770_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24770 = 1/statistics.stdev(Grit_24770_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24770 = 1/(max(Grit_24770_T)-min(Grit_24770_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24770 = statistics.mean(Grit_24770_H)    #(作业花费时长/作业问题数)的平均
Grit10_24770 = statistics.median(Grit_24770_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24770 = 1/statistics.stdev(Grit_24770_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24770 = 1/(max(Grit_24770_H)-min(Grit_24770_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24770 = Time_24770_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24770 = Time_24770_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24770 = Time_24770_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24770 = USER_ID[24770].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24770 = np.nan_to_num(Self_control4_24770)
Self_control4_24770 = Self_control4_24770.max()

Self_control5_24770 = USER_ID[24770].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24770 = np.nan_to_num(Self_control5_24770)
Self_control5_24770 = Self_control5_24770.min()

Self_control6_24770 = USER_ID[24770].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24770 = np.nan_to_num(Self_control6_24770)
Self_control6_24770 = Self_control6_24770.sum() 
Self_control6_24770 = Self_control6_24770 / 73

Self_control7_24770 = USER_ID[24770].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24770 = np.nan_to_num(Self_control7_24770)
Self_control7_24770 = Self_control7_24770[20:40].mean()

#(3) Engagement
Engagement_24770_V = Time_24770_V    #视频观看时长
Engagement_24770_T = Time_24770_T    #文本阅读时长
Engagement_24770_H = Time_24770_H    #作业花费时长

Engagement1_24770 = USER_ID[24770].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24770 = np.nan_to_num(Engagement1_24770).sum()

Engagement2_24770 = statistics.mean(Engagement_24770_V)    #平均每次花费在视频学习的时间
Engagement3_24770 = statistics.mean(Engagement_24770_T)    #平均每次花费在文本课件的时间
Engagement4_24770 = statistics.mean(Engagement_24770_H)    #平均每次花费在作业答题的时间
Engagement5_24770 = 73    #学习次数(登入次数)
Engagement6_24770 = 30    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24770 = Time_24770_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24770 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24770 = USER_ID[24770].loc[:, '访问时长(seconds)'].values
Self_perception1_24770 = np.nan_to_num(Self_perception1_24770)

Self_perception1_24770 = 1/((Self_perception1_24770[:20].sum() 
                         - Self_perception1_24770[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24770 = 1/((statistics.mean(Grit_24770_V[:7]) 
                         - statistics.mean(Grit_24770_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24770 = 1/((statistics.mean(Grit_24770_T[:2]) 
                         - statistics.mean(Grit_24770_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24770 = 1/((statistics.mean(Grit_24770_H[:9]) 
                         - statistics.mean(Grit_24770_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24770 = USER_ID[24770].loc[:, ['高过门槛时长']].values
Motivation1_24770 = np.nan_to_num(Motivation1_24770).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24770 = USER_ID[24770].loc[c4, ['高过门槛时长']].values
Motivation2_24770 = np.nan_to_num(Motivation2_24770).sum()
#文挡高过门槛时长总和
Motivation3_24770 = USER_ID[24770].loc[c5, ['高过门槛时长']].values   
Motivation3_24770 = np.nan_to_num(Motivation3_24770).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24770 = np.array(USER_ID[24770].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24770 = np.nan_to_num(Motivation4_24770)
Motivation4_24770 = statistics.mean(Motivation4_24770 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24770 = np.array(USER_ID[24770].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24770 = np.nan_to_num(Motivation5_24770)
Motivation5_24770 = statistics.mean(Motivation5_24770 / c2)

#选修花费总时长
Motivation6_24770 = USER_ID[24770].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24770 = np.nan_to_num(Motivation6_24770).sum()

#(选修花费/页数)的平均
Motivation7_24770 = Motivation6_24770 / (11+8)
Motivation8_24770 = Motivation7_24770/Motivation5_24770    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24770 = 1    #完成进度*

# %%
USER_ID[24778]

# %%
USER_ID[24778].reset_index(inplace=True)
USER_ID[24778].set_index('活动名称', inplace=True)
print(USER_ID[24778].shape)
# USER_ID[24778]

Time_24778_V = USER_ID[24778].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24778_V = np.nan_to_num(Time_24778_V)

Time_24778_T = USER_ID[24778].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24778_T = np.nan_to_num(Time_24778_T)

Time_24778_H = USER_ID[24778].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24778_H = np.nan_to_num(Time_24778_H)

#(1) Grit
Grit_24778_V = Time_24778_V / c1  #视频观看时长/视频总时长
Grit_24778_T = Time_24778_T / c2   #文本阅读时长/文本页数
Grit_24778_H = Time_24778_H /c3   #作业花费时长/作业问题数

Grit1_24778 = statistics.mean(Grit_24778_V)    #(视频观看时长/视频总时长)的平均
Grit2_24778 = statistics.median(Grit_24778_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24778 = 1/statistics.stdev(Grit_24778_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24778 = 1/(max(Grit_24778_V)-min(Grit_24778_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24778 = statistics.mean(Grit_24778_T)    #(文本阅读时长/文本页数)的平均
Grit6_24778 = statistics.median(Grit_24778_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24778 = 1/statistics.stdev(Grit_24778_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24778 = 1/(max(Grit_24778_T)-min(Grit_24778_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24778 = statistics.mean(Grit_24778_H)    #(作业花费时长/作业问题数)的平均
Grit10_24778 = statistics.median(Grit_24778_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24778 = 1/statistics.stdev(Grit_24778_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24778 = 1/(max(Grit_24778_H)-min(Grit_24778_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24778 = Time_24778_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24778 = Time_24778_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24778 = Time_24778_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24778 = USER_ID[24778].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24778 = np.nan_to_num(Self_control4_24778)
Self_control4_24778 = Self_control4_24778.max()

Self_control5_24778 = USER_ID[24778].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24778 = np.nan_to_num(Self_control5_24778)
Self_control5_24778 = Self_control5_24778.min()

Self_control6_24778 = USER_ID[24778].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24778 = np.nan_to_num(Self_control6_24778)
Self_control6_24778 = Self_control6_24778.sum() 
Self_control6_24778 = Self_control6_24778 / 61

Self_control7_24778 = USER_ID[24778].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24778 = np.nan_to_num(Self_control7_24778)
Self_control7_24778 = Self_control7_24778[20:40].mean()

#(3) Engagement
Engagement_24778_V = Time_24778_V    #视频观看时长
Engagement_24778_T = Time_24778_T    #文本阅读时长
Engagement_24778_H = Time_24778_H    #作业花费时长

Engagement1_24778 = USER_ID[24778].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24778 = np.nan_to_num(Engagement1_24778).sum()

Engagement2_24778 = statistics.mean(Engagement_24778_V)    #平均每次花费在视频学习的时间
Engagement3_24778 = statistics.mean(Engagement_24778_T)    #平均每次花费在文本课件的时间
Engagement4_24778 = statistics.mean(Engagement_24778_H)    #平均每次花费在作业答题的时间
Engagement5_24778 = 61    #学习次数(登入次数)
Engagement6_24778 = 15    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24778 = Time_24778_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24778 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24778 = USER_ID[24778].loc[:, '访问时长(seconds)'].values
Self_perception1_24778 = np.nan_to_num(Self_perception1_24778)

Self_perception1_24778 = 1/((Self_perception1_24778[:20].sum() 
                         - Self_perception1_24778[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24778 = 1/((statistics.mean(Grit_24778_V[:7]) 
                         - statistics.mean(Grit_24778_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24778 = 1/((statistics.mean(Grit_24778_T[:2]) 
                         - statistics.mean(Grit_24778_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24778 = 1/((statistics.mean(Grit_24778_H[:9]) 
                         - statistics.mean(Grit_24778_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24778 = USER_ID[24778].loc[:, ['高过门槛时长']].values
Motivation1_24778 = np.nan_to_num(Motivation1_24778).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24778 = USER_ID[24778].loc[c4, ['高过门槛时长']].values
Motivation2_24778 = np.nan_to_num(Motivation2_24778).sum()
#文挡高过门槛时长总和
Motivation3_24778 = USER_ID[24778].loc[c5, ['高过门槛时长']].values   
Motivation3_24778 = np.nan_to_num(Motivation3_24778).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24778 = np.array(USER_ID[24778].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24778 = np.nan_to_num(Motivation4_24778)
Motivation4_24778 = statistics.mean(Motivation4_24778 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24778 = np.array(USER_ID[24778].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24778 = np.nan_to_num(Motivation5_24778)
Motivation5_24778 = statistics.mean(Motivation5_24778 / c2)

#选修花费总时长
Motivation6_24778 = USER_ID[24778].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24778 = np.nan_to_num(Motivation6_24778).sum()

#(选修花费/页数)的平均
Motivation7_24778 = Motivation6_24778 / (11+8)
Motivation8_24778 = Motivation7_24778/Motivation5_24778    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24778 = 1    #完成进度*

# %%
USER_ID[24779]

# %%
USER_ID[24779].reset_index(inplace=True)
USER_ID[24779].set_index('活动名称', inplace=True)
print(USER_ID[24779].shape)
# USER_ID[24779]

Time_24779_V = USER_ID[24779].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24779_V = np.nan_to_num(Time_24779_V)

Time_24779_T = USER_ID[24779].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24779_T = np.nan_to_num(Time_24779_T)

Time_24779_H = USER_ID[24779].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24779_H = np.nan_to_num(Time_24779_H)

#(1) Grit
Grit_24779_V = Time_24779_V / c1  #视频观看时长/视频总时长
Grit_24779_T = Time_24779_T / c2   #文本阅读时长/文本页数
Grit_24779_H = Time_24779_H /c3   #作业花费时长/作业问题数

Grit1_24779 = statistics.mean(Grit_24779_V)    #(视频观看时长/视频总时长)的平均
Grit2_24779 = statistics.median(Grit_24779_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24779 = 1/statistics.stdev(Grit_24779_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24779 = 1/(max(Grit_24779_V)-min(Grit_24779_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24779 = statistics.mean(Grit_24779_T)    #(文本阅读时长/文本页数)的平均
Grit6_24779 = statistics.median(Grit_24779_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24779 = 1/statistics.stdev(Grit_24779_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24779 = 1/(max(Grit_24779_T)-min(Grit_24779_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24779 = statistics.mean(Grit_24779_H)    #(作业花费时长/作业问题数)的平均
Grit10_24779 = statistics.median(Grit_24779_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24779 = 1/statistics.stdev(Grit_24779_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24779 = 1/(max(Grit_24779_H)-min(Grit_24779_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24779 = Time_24779_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24779 = Time_24779_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24779 = Time_24779_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24779 = USER_ID[24779].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24779 = np.nan_to_num(Self_control4_24779)
Self_control4_24779 = Self_control4_24779.max()

Self_control5_24779 = USER_ID[24779].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24779 = np.nan_to_num(Self_control5_24779)
Self_control5_24779 = Self_control5_24779.min()

Self_control6_24779 = USER_ID[24779].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24779 = np.nan_to_num(Self_control6_24779)
Self_control6_24779 = Self_control6_24779.sum() 
Self_control6_24779 = Self_control6_24779 / 60

Self_control7_24779 = USER_ID[24779].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24779 = np.nan_to_num(Self_control7_24779)
Self_control7_24779 = Self_control7_24779[20:40].mean()

#(3) Engagement
Engagement_24779_V = Time_24779_V    #视频观看时长
Engagement_24779_T = Time_24779_T    #文本阅读时长
Engagement_24779_H = Time_24779_H    #作业花费时长

Engagement1_24779 = USER_ID[24779].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24779 = np.nan_to_num(Engagement1_24779).sum()

Engagement2_24779 = statistics.mean(Engagement_24779_V)    #平均每次花费在视频学习的时间
Engagement3_24779 = statistics.mean(Engagement_24779_T)    #平均每次花费在文本课件的时间
Engagement4_24779 = statistics.mean(Engagement_24779_H)    #平均每次花费在作业答题的时间
Engagement5_24779 = 60    #学习次数(登入次数)
Engagement6_24779 = 9    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24779 = Time_24779_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24779 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24779 = USER_ID[24779].loc[:, '访问时长(seconds)'].values
Self_perception1_24779 = np.nan_to_num(Self_perception1_24779)

Self_perception1_24779 = 1/((Self_perception1_24779[:20].sum() 
                         - Self_perception1_24779[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24779 = 1/((statistics.mean(Grit_24779_V[:7]) 
                         - statistics.mean(Grit_24779_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24779 = 1/((statistics.mean(Grit_24779_T[:2]) 
                         - statistics.mean(Grit_24779_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24779 = 1/((statistics.mean(Grit_24779_H[:9]) 
                         - statistics.mean(Grit_24779_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24779 = USER_ID[24779].loc[:, ['高过门槛时长']].values
Motivation1_24779 = np.nan_to_num(Motivation1_24779).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24779 = USER_ID[24779].loc[c4, ['高过门槛时长']].values
Motivation2_24779 = np.nan_to_num(Motivation2_24779).sum()
#文挡高过门槛时长总和
Motivation3_24779 = USER_ID[24779].loc[c5, ['高过门槛时长']].values   
Motivation3_24779 = np.nan_to_num(Motivation3_24779).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24779 = np.array(USER_ID[24779].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24779 = np.nan_to_num(Motivation4_24779)
Motivation4_24779 = statistics.mean(Motivation4_24779 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24779 = np.array(USER_ID[24779].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24779 = np.nan_to_num(Motivation5_24779)
Motivation5_24779 = statistics.mean(Motivation5_24779 / c2)

#选修花费总时长
Motivation6_24779 = USER_ID[24779].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24779 = np.nan_to_num(Motivation6_24779).sum()

#(选修花费/页数)的平均
Motivation7_24779 = Motivation6_24779 / (11+8)
Motivation8_24779 = Motivation7_24779/Motivation5_24779    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24779 = 1    #完成进度*

# %%
USER_ID[24775]

# %%
USER_ID[24775].reset_index(inplace=True)
USER_ID[24775].set_index('活动名称', inplace=True)
print(USER_ID[24775].shape)
# USER_ID[24775]

Time_24775_V = USER_ID[24775].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24775_V = np.nan_to_num(Time_24775_V)

Time_24775_T = USER_ID[24775].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24775_T = np.nan_to_num(Time_24775_T)

Time_24775_H = USER_ID[24775].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24775_H = np.nan_to_num(Time_24775_H)

#(1) Grit
Grit_24775_V = Time_24775_V / c1  #视频观看时长/视频总时长
Grit_24775_T = Time_24775_T / c2   #文本阅读时长/文本页数
Grit_24775_H = Time_24775_H /c3   #作业花费时长/作业问题数

Grit1_24775 = statistics.mean(Grit_24775_V)    #(视频观看时长/视频总时长)的平均
Grit2_24775 = statistics.median(Grit_24775_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24775 = 1/statistics.stdev(Grit_24775_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24775 = 1/(max(Grit_24775_V)-min(Grit_24775_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24775 = statistics.mean(Grit_24775_T)    #(文本阅读时长/文本页数)的平均
Grit6_24775 = statistics.median(Grit_24775_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24775 = 1/statistics.stdev(Grit_24775_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24775 = 1/(max(Grit_24775_T)-min(Grit_24775_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24775 = statistics.mean(Grit_24775_H)    #(作业花费时长/作业问题数)的平均
Grit10_24775 = statistics.median(Grit_24775_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24775 = 1/statistics.stdev(Grit_24775_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24775 = 1/(max(Grit_24775_H)-min(Grit_24775_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24775 = Time_24775_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24775 = Time_24775_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24775 = Time_24775_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24775 = USER_ID[24775].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24775 = np.nan_to_num(Self_control4_24775)
Self_control4_24775 = Self_control4_24775.max()

Self_control5_24775 = USER_ID[24775].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24775 = np.nan_to_num(Self_control5_24775)
Self_control5_24775 = Self_control5_24775.min()

Self_control6_24775 = USER_ID[24775].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24775 = np.nan_to_num(Self_control6_24775)
Self_control6_24775 = Self_control6_24775.sum() 
Self_control6_24775 = Self_control6_24775 / 59

Self_control7_24775 = USER_ID[24775].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24775 = np.nan_to_num(Self_control7_24775)
Self_control7_24775 = Self_control7_24775[20:40].mean()

#(3) Engagement
Engagement_24775_V = Time_24775_V    #视频观看时长
Engagement_24775_T = Time_24775_T    #文本阅读时长
Engagement_24775_H = Time_24775_H    #作业花费时长

Engagement1_24775 = USER_ID[24775].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24775 = np.nan_to_num(Engagement1_24775).sum()

Engagement2_24775 = statistics.mean(Engagement_24775_V)    #平均每次花费在视频学习的时间
Engagement3_24775 = statistics.mean(Engagement_24775_T)    #平均每次花费在文本课件的时间
Engagement4_24775 = statistics.mean(Engagement_24775_H)    #平均每次花费在作业答题的时间
Engagement5_24775 = 59    #学习次数(登入次数)
Engagement6_24775 = 21    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24775 = Time_24775_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24775 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24775 = USER_ID[24775].loc[:, '访问时长(seconds)'].values
Self_perception1_24775 = np.nan_to_num(Self_perception1_24775)

Self_perception1_24775 = 1/((Self_perception1_24775[:20].sum() 
                         - Self_perception1_24775[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24775 = 1/((statistics.mean(Grit_24775_V[:7]) 
                         - statistics.mean(Grit_24775_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24775 = 1/((statistics.mean(Grit_24775_T[:2]) 
                         - statistics.mean(Grit_24775_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24775 = 1/((statistics.mean(Grit_24775_H[:9]) 
                         - statistics.mean(Grit_24775_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24775 = USER_ID[24775].loc[:, ['高过门槛时长']].values
Motivation1_24775 = np.nan_to_num(Motivation1_24775).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24775 = USER_ID[24775].loc[c4, ['高过门槛时长']].values
Motivation2_24775 = np.nan_to_num(Motivation2_24775).sum()
#文挡高过门槛时长总和
Motivation3_24775 = USER_ID[24775].loc[c5, ['高过门槛时长']].values   
Motivation3_24775 = np.nan_to_num(Motivation3_24775).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24775 = np.array(USER_ID[24775].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24775 = np.nan_to_num(Motivation4_24775)
Motivation4_24775 = statistics.mean(Motivation4_24775 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24775 = np.array(USER_ID[24775].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24775 = np.nan_to_num(Motivation5_24775)
Motivation5_24775 = statistics.mean(Motivation5_24775 / c2)

#选修花费总时长
Motivation6_24775 = USER_ID[24775].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24775 = np.nan_to_num(Motivation6_24775).sum()

#(选修花费/页数)的平均
Motivation7_24775 = Motivation6_24775 / (11+8)
Motivation8_24775 = Motivation7_24775/Motivation5_24775    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24775 = 1    #完成进度*

# %%
USER_ID[24777]

# %%
USER_ID[24777].reset_index(inplace=True)
USER_ID[24777].set_index('活动名称', inplace=True)
print(USER_ID[24777].shape)
# USER_ID[24777]

Time_24777_V = USER_ID[24777].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24777_V = np.nan_to_num(Time_24777_V)

Time_24777_T = USER_ID[24777].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24777_T = np.nan_to_num(Time_24777_T)

Time_24777_H = USER_ID[24777].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24777_H = np.nan_to_num(Time_24777_H)

#(1) Grit
Grit_24777_V = Time_24777_V / c1  #视频观看时长/视频总时长
Grit_24777_T = Time_24777_T / c2   #文本阅读时长/文本页数
Grit_24777_H = Time_24777_H /c3   #作业花费时长/作业问题数

Grit1_24777 = statistics.mean(Grit_24777_V)    #(视频观看时长/视频总时长)的平均
Grit2_24777 = statistics.median(Grit_24777_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24777 = 1/statistics.stdev(Grit_24777_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24777 = 1/(max(Grit_24777_V)-min(Grit_24777_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24777 = statistics.mean(Grit_24777_T)    #(文本阅读时长/文本页数)的平均
Grit6_24777 = statistics.median(Grit_24777_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24777 = 1/statistics.stdev(Grit_24777_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24777 = 1/(max(Grit_24777_T)-min(Grit_24777_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24777 = statistics.mean(Grit_24777_H)    #(作业花费时长/作业问题数)的平均
Grit10_24777 = statistics.median(Grit_24777_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24777 = 1/statistics.stdev(Grit_24777_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24777 = 1/(max(Grit_24777_H)-min(Grit_24777_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24777 = Time_24777_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24777 = Time_24777_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24777 = Time_24777_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24777 = USER_ID[24777].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24777 = np.nan_to_num(Self_control4_24777)
Self_control4_24777 = Self_control4_24777.max()

Self_control5_24777 = USER_ID[24777].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24777 = np.nan_to_num(Self_control5_24777)
Self_control5_24777 = Self_control5_24777.min()

Self_control6_24777 = USER_ID[24777].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24777 = np.nan_to_num(Self_control6_24777)
Self_control6_24777 = Self_control6_24777.sum() 
Self_control6_24777 = Self_control6_24777 / 61

Self_control7_24777 = USER_ID[24777].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24777 = np.nan_to_num(Self_control7_24777)
Self_control7_24777 = Self_control7_24777[20:40].mean()

#(3) Engagement
Engagement_24777_V = Time_24777_V    #视频观看时长
Engagement_24777_T = Time_24777_T    #文本阅读时长
Engagement_24777_H = Time_24777_H    #作业花费时长

Engagement1_24777 = USER_ID[24777].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24777 = np.nan_to_num(Engagement1_24777).sum()

Engagement2_24777 = statistics.mean(Engagement_24777_V)    #平均每次花费在视频学习的时间
Engagement3_24777 = statistics.mean(Engagement_24777_T)    #平均每次花费在文本课件的时间
Engagement4_24777 = statistics.mean(Engagement_24777_H)    #平均每次花费在作业答题的时间
Engagement5_24777 = 61    #学习次数(登入次数)
Engagement6_24777 = 6    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24777 = Time_24777_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24777 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24777 = USER_ID[24777].loc[:, '访问时长(seconds)'].values
Self_perception1_24777 = np.nan_to_num(Self_perception1_24777)

Self_perception1_24777 = 1/((Self_perception1_24777[:20].sum() 
                         - Self_perception1_24777[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24777 = 1/((statistics.mean(Grit_24777_V[:7]) 
                         - statistics.mean(Grit_24777_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24777 = 1/((statistics.mean(Grit_24777_T[:2]) 
                         - statistics.mean(Grit_24777_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24777 = 1/((statistics.mean(Grit_24777_H[:9]) 
                         - statistics.mean(Grit_24777_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24777 = USER_ID[24777].loc[:, ['高过门槛时长']].values
Motivation1_24777 = np.nan_to_num(Motivation1_24777).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24777 = USER_ID[24777].loc[c4, ['高过门槛时长']].values
Motivation2_24777 = np.nan_to_num(Motivation2_24777).sum()
#文挡高过门槛时长总和
Motivation3_24777 = USER_ID[24777].loc[c5, ['高过门槛时长']].values   
Motivation3_24777 = np.nan_to_num(Motivation3_24777).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24777 = np.array(USER_ID[24777].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24777 = np.nan_to_num(Motivation4_24777)
Motivation4_24777 = statistics.mean(Motivation4_24777 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24777 = np.array(USER_ID[24777].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24777 = np.nan_to_num(Motivation5_24777)
Motivation5_24777 = statistics.mean(Motivation5_24777 / c2)

#选修花费总时长
Motivation6_24777 = USER_ID[24777].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24777 = np.nan_to_num(Motivation6_24777).sum()

#(选修花费/页数)的平均
Motivation7_24777 = Motivation6_24777 / (11+8)
Motivation8_24777 = Motivation7_24777/Motivation5_24777    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24777 = 1    #完成进度*

# %%
USER_ID[24776]

# %%
USER_ID[24776].reset_index(inplace=True)
USER_ID[24776].set_index('活动名称', inplace=True)
print(USER_ID[24776].shape) 
# USER_ID[24776]

Time_24776_V = USER_ID[24776].loc[c4, '访问时长(seconds)'].values    #视频观看时长
Time_24776_V = np.nan_to_num(Time_24776_V)

Time_24776_T = USER_ID[24776].loc[c5, '访问时长(seconds)'].values    #文本阅读时长
Time_24776_T = np.nan_to_num(Time_24776_T)

Time_24776_H = USER_ID[24776].loc[c6, '访问时长(seconds)'].values    #作业花费时长
Time_24776_H = np.nan_to_num(Time_24776_H)

#(1) Grit
Grit_24776_V = Time_24776_V / c1  #视频观看时长/视频总时长
Grit_24776_T = Time_24776_T / c2   #文本阅读时长/文本页数
Grit_24776_H = Time_24776_H /c3   #作业花费时长/作业问题数

Grit1_24776 = statistics.mean(Grit_24776_V)    #(视频观看时长/视频总时长)的平均
Grit2_24776 = statistics.median(Grit_24776_V)    #(视频观看时长/视频总时长)的中位数
Grit3_24776 = 1/statistics.stdev(Grit_24776_V)    #(视频观看时长/视频总时长)的标准差的倒数
Grit4_24776 = 1/(max(Grit_24776_V)-min(Grit_24776_V))    #(视频观看时长/视频总时长)最大差距的倒数
Grit5_24776 = statistics.mean(Grit_24776_T)    #(文本阅读时长/文本页数)的平均
Grit6_24776 = statistics.median(Grit_24776_T)    #(文本阅读时长/文本页数)的中位数
Grit7_24776 = 1/statistics.stdev(Grit_24776_T)    #(文本阅读时长/文本页数)的标准差的倒数
Grit8_24776 = 1/(max(Grit_24776_T)-min(Grit_24776_T))    #(文本阅读时长/文本页数)最大差距的倒数
Grit9_24776 = statistics.mean(Grit_24776_H)    #(作业花费时长/作业问题数)的平均
Grit10_24776 = statistics.median(Grit_24776_H)    #(作业花费时长/作业问题数)的中位数
Grit11_24776 = 1/statistics.stdev(Grit_24776_H)    #(作业花费时长/作业问题数)的标准差的倒数
Grit12_24776 = 1/(max(Grit_24776_H)-min(Grit_24776_H))    #(作业花费时长/作业问题数)最大差距的倒数

#(2) Self-control
Self_control1_24776 = Time_24776_V[9] / 1027    #("最长视频"观看时长/视频总时长)
Self_control2_24776 = Time_24776_T[4] / 42    #("最多页文本"阅读时长/文本页数)
Self_control3_24776 = Time_24776_H[0] / 53    #("最多题作业"花费时长/作业问题数)

Self_control4_24776 = USER_ID[24776].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最长时长
Self_control4_24776 = np.nan_to_num(Self_control4_24776)
Self_control4_24776 = Self_control4_24776.max()

Self_control5_24776 = USER_ID[24776].loc[:, '访问时长(seconds)'].values    #单一课件一次学习最短时长 
Self_control5_24776 = np.nan_to_num(Self_control5_24776)
Self_control5_24776 = Self_control5_24776.min()

Self_control6_24776 = USER_ID[24776].loc[:, '访问时长(seconds)'].values    #平均登入時長
Self_control6_24776 = np.nan_to_num(Self_control6_24776)
Self_control6_24776 = Self_control6_24776.sum() 
Self_control6_24776 = Self_control6_24776 / 61

Self_control7_24776 = USER_ID[24776].loc[:, '访问时长(seconds)'].values    #课程后半段学习时间
Self_control7_24776 = np.nan_to_num(Self_control7_24776)
Self_control7_24776 = Self_control7_24776[20:40].mean()

#(3) Engagement
Engagement_24776_V = Time_24776_V    #视频观看时长
Engagement_24776_T = Time_24776_T    #文本阅读时长
Engagement_24776_H = Time_24776_H    #作业花费时长

Engagement1_24776 = USER_ID[24776].loc[:, '访问时长(seconds)']    #学习总时长
Engagement1_24776 = np.nan_to_num(Engagement1_24776).sum()

Engagement2_24776 = statistics.mean(Engagement_24776_V)    #平均每次花费在视频学习的时间
Engagement3_24776 = statistics.mean(Engagement_24776_T)    #平均每次花费在文本课件的时间
Engagement4_24776 = statistics.mean(Engagement_24776_H)    #平均每次花费在作业答题的时间
Engagement5_24776 = 61    #学习次数(登入次数)
Engagement6_24776 = 9    #结业考试成绩(30%)*

#(4) Metacognitive_Self-regulation
Metacognitive_Self_regulation1_24776 = Time_24776_T[4]    #"课程回顾"花费时间
Metacognitive_Self_regulation2_24776 = 0    #是否重复阅读与观看 or 是否按照课程结构

#(5) Self-perception
Self_perception1_24776 = USER_ID[24776].loc[:, '访问时长(seconds)'].values
Self_perception1_24776 = np.nan_to_num(Self_perception1_24776)

Self_perception1_24776 = 1/((Self_perception1_24776[:20].sum() 
                         - Self_perception1_24776[20:40].sum())**2)    #(学习历程前半段时长-学习历程后半段时长)的平方的倒数
Self_perception2_24776 = 1/((statistics.mean(Grit_24776_V[:7]) 
                         - statistics.mean(Grit_24776_V[7:14]))**2)    #((视频观看时长/视频时长)前半段平均-(视频观看时长/视频时长)后半段平均)的平方的倒数
Self_perception3_24776 = 1/((statistics.mean(Grit_24776_T[:2]) 
                         - statistics.mean(Grit_24776_T[2:]))**2)    #((文本阅读时长/页数)前半段平均-(文本阅读时长/页数)后半段平均)的平方的倒数    
Self_perception4_24776 = 1/((statistics.mean(Grit_24776_H[:9]) 
                         - statistics.mean(Grit_24776_H[9:]))**2)    #((作业花费时长/页数)前半段平均-(作业花费时长/页数)后半段平均)的平方的倒数 

#(6) Motivation
Motivation1_24776 = USER_ID[24776].loc[:, ['高过门槛时长']].values
Motivation1_24776 = np.nan_to_num(Motivation1_24776).sum()    #高过门槛时长总和

#视频高过门槛时长总和
Motivation2_24776 = USER_ID[24776].loc[c4, ['高过门槛时长']].values
Motivation2_24776 = np.nan_to_num(Motivation2_24776).sum()
#文挡高过门槛时长总和
Motivation3_24776 = USER_ID[24776].loc[c5, ['高过门槛时长']].values   
Motivation3_24776 = np.nan_to_num(Motivation3_24776).sum()
                                       
#(视频高过门槛时长/视频时长)的平均
Motivation4_24776 = np.array(USER_ID[24776].loc[c4, ['高过门槛时长']].values).flatten()
Motivation4_24776 = np.nan_to_num(Motivation4_24776)
Motivation4_24776 = statistics.mean(Motivation4_24776 / c1)

#(文挡高过门槛时长/页数)的平均
Motivation5_24776 = np.array(USER_ID[24776].loc[c5, ['高过门槛时长']].values).flatten()
Motivation5_24776 = np.nan_to_num(Motivation5_24776)
Motivation5_24776 = statistics.mean(Motivation5_24776 / c2)

#选修花费总时长
Motivation6_24776 = USER_ID[24776].loc[['延伸阅读：人工智能的历史现状与未来（选修）', '延伸阅读：我思故我在？（选修）'], '访问时长(seconds)'].values
Motivation6_24776 = np.nan_to_num(Motivation6_24776).sum()

#(选修花费/页数)的平均
Motivation7_24776 = Motivation6_24776 / (11+8)
Motivation8_24776 = Motivation7_24776/Motivation5_24776    #(选修花费/页数)的平均 / (文挡高过门槛时长/页数)的平均
Motivation9_24776 = 1    #完成进度*

# %%
user

# %%
Data_Point = {}
for i in user:
     Data_Point[i] = [eval("Grit1_"+str(i)), 
                     eval("Grit2_"+str(i)),
                     eval("Grit3_"+str(i)),
                     eval("Grit4_"+str(i)),
                     eval("Grit5_"+str(i)),
                     eval("Grit6_"+str(i)),
                     eval("Grit7_"+str(i)),
                     eval("Grit8_"+str(i)),
                     eval("Grit9_"+str(i)),
                     eval("Grit10_"+str(i)),
                     eval("Grit11_"+str(i)),
                     eval("Grit12_"+str(i)),
                     eval("Self_control1_"+str(i)),
                     eval("Self_control2_"+str(i)),
                     eval("Self_control3_"+str(i)),
                     eval("Self_control4_"+str(i)),
                     eval("Self_control5_"+str(i)),
                     eval("Self_control6_"+str(i)),
                     eval("Self_control7_"+str(i)),
                     eval("Engagement1_"+str(i)),
                     eval("Engagement2_"+str(i)),
                     eval("Engagement3_"+str(i)),
                     eval("Engagement4_"+str(i)),
                     eval("Engagement5_"+str(i)),
                     eval("Engagement6_"+str(i)),
                     eval("Metacognitive_Self_regulation1_"+str(i)),
                     eval("Metacognitive_Self_regulation2_"+str(i)),
                     eval("Self_perception1_"+str(i)),
                     eval("Self_perception2_"+str(i)),
                     eval("Self_perception3_"+str(i)),
                     eval("Self_perception4_"+str(i)),
                     eval("Motivation1_"+str(i)),
                     eval("Motivation2_"+str(i)),
                     eval("Motivation3_"+str(i)),
                     eval("Motivation4_"+str(i)),
                     eval("Motivation5_"+str(i)),
                     eval("Motivation6_"+str(i)),
                     eval("Motivation7_"+str(i)),
                     eval("Motivation8_"+str(i)),
                     eval("Motivation9_"+str(i))]

# %%
Data_Point

# %%
Data_Point.items()

# %%
df_Data_Point = pd.DataFrame([
    { 'USER_ID': ID, 
    'G1': G1, 'G2': G2, 'G3': G3, 'G4': G4, 'G5': G5, 'G6': G6, 'G7': G7, 'G8': G8, 'G9': G9, 'G10': G10, 'G11': G11, 'G12': G12, 
    'SC1': SC1, 'SC2': SC2, 'SC3': SC3, 'SC4': SC4, 'SC5': SC5, 'SC6': SC6, 'SC7': SC7, 
    'E1': E1, 'E2': E2, 'E3': E3, 'E4': E4, 'E5': E5, 'E6': E6, 
    'MSR1': MSR1, 'MSR2': MSR2, 
    'SP1': SP1, 'SP2': SP2, 'SP3': SP3, 'SP4': SP4, 
    'M1': M1, 'M2': M2, 'M3': M3, 'M4': M4, 'M5': M5, 'M6': M6, 'M7': M7, 'M8': M8, 'M9': M9} for ID, (G1, 
                                                                                                               G2, 
                                                                                                               G3, 
                                                                                                               G4, 
                                                                                                               G5, 
                                                                                                               G6, 
                                                                                                               G7, 
                                                                                                               G8, 
                                                                                                               G9, 
                                                                                                               G10, 
                                                                                                               G11, 
                                                                                                               G12, 
                                                                                                               SC1, 
                                                                                                               SC2, 
                                                                                                               SC3, 
                                                                                                               SC4, 
                                                                                                               SC5, 
                                                                                                               SC6, 
                                                                                                               SC7, 
                                                                                                               E1, 
                                                                                                               E2, 
                                                                                                               E3, 
                                                                                                               E4, 
                                                                                                               E5, 
                                                                                                               E6, 
                                                                                                               MSR1, 
                                                                                                               MSR2, 
                                                                                                               SP1, 
                                                                                                               SP2, 
                                                                                                               SP3, 
                                                                                                               SP4, 
                                                                                                               M1, 
                                                                                                               M2, 
                                                                                                               M3, 
                                                                                                               M4, 
                                                                                                               M5,
                                                                                                               M6, 
                                                                                                               M7, 
                                                                                                               M8, 
                                                                                                               M9) in Data_Point.items()])

# %%
df_Data_Point

# %%
cols = ['USER_ID', 'G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 
                                                    'SC1', 'SC2', 'SC3', 'SC4', 'SC5', 'SC6', 'SC7', 
                                                    'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 
                                                    'MSR1', 'MSR2', 
                                                    'SP1', 'SP2', 'SP3', 'SP4', 
                                                    'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9']


df_Data_Point = df_Data_Point.reindex(columns=cols)

df_Data_Point.set_index('USER_ID', inplace=True)
df_Data_Point

# %%
# Normalization of Features
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
df_Data_Point_scaled = scaler.fit_transform(df_Data_Point) # it becomes an array
df_Data_Point_scaled_noNaN = np.nan_to_num(df_Data_Point_scaled)

# make it a dataframe
df_Data_Point_scaled_noNaN = pd.DataFrame(df_Data_Point_scaled_noNaN, index = df_Data_Point.index, columns = df_Data_Point.columns)

# %%
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt

# %%
import seaborn as sns

plt.figure(figsize=(20,10))
e = df_Data_Point_scaled_noNaN.corr()
sns.heatmap(e)

# %%
# Factor Analysis
fa = FactorAnalyzer()
fa.fit(df_Data_Point_scaled_noNaN) # Get Eigen values and plot them
ev, v = fa.get_eigenvalues()
ev
plt.plot(range(1, df_Data_Point_scaled_noNaN.shape[1]+1), ev)

# %%
fa = FactorAnalyzer(6, rotation='varimax')  # Choose 6 factors which are also the number we assumed
fa.fit(df_Data_Point_scaled_noNaN)
loads = fa.loadings_
loads

# %%
import sys
import numpy
numpy.set_printoptions(linewidth=1000)
loads

# %%
fa.get_factor_variance()

# %%
fa.get_communalities()

# %%
loadings = pd.DataFrame(loads, columns=['G', 'SC', 'E', 'MSR', 'SP', 'M'], 
                        index=df_Data_Point_scaled_noNaN.columns)
print('Factor Loadings \n%s' %loadings)

# %%
#re-order

arrange_loadings = loadings.reindex(['G1', 'G2', 'G3', 'G4', 'G6', 'G7', 'G8', 'SC1', 'SC4', 'SC6', 'SC7', 'E1', 'E2', 'SP1', 'M1', 'M2', 'M4', 
                 'SC2', 'SC5', 'MSR1', 'M9', 
                 'G5', 'G11', 'E3', 'SP4', 'M3', 'M5', 
                 'G10', 'SC3', 'E4', 'MSR2', 'SP2', 'M8', 
                 'E5', 'E6', 'M6', 'M7', 
                 'G9', 'G12', 'SP3'])

arrange_loadings

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Do the PCA.

n=5
pca = PCA(n_components=n)
pct = pca.fit_transform(df_Data_Point_scaled_noNaN)

# Append the principle components for each entry to the dataframe
for i in range(n):
    df_Data_Point_scaled_noNaN['PC' + str(i + 1)] = pct[:, i]

display(df_Data_Point_scaled_noNaN.head())

# %%
# Do a scree plot
ind = np.arange(n)
(fig, ax) = plt.subplots(figsize=(8, 6))
sns.pointplot(x=ind, y=pca.explained_variance_ratio_)
ax.set_title('Scree plot')
ax.set_xlabel('Component Number')
ax.set_ylabel('Explained Variance')
plt.show()

# %%
g = sns.lmplot('PC1',
               'PC2',
               data=df_Data_Point_scaled_noNaN,
               fit_reg=False,
               scatter=True,
               size=7)

plt.show()

# %%
df_Data_Point_scaled_noNaN = df_Data_Point_scaled_noNaN.drop(columns =['PC3', 'PC4', 'PC5'])

# %%
df_Data_Point_scaled_noNaN_0 = df_Data_Point_scaled_noNaN.drop(columns =['PC1', 'PC2'], inplace = False) 
df_Data_Point_scaled_noNaN_0.head()
df_Data_Point_scaled_noNaN.head()

# %%
# Plot a variable factor map for the first two dimensions.
(fig, ax) = plt.subplots(figsize=(12, 12))
for i in range(0, len(df_Data_Point_scaled_noNaN_0.columns)):          # Each PCA's number of features
    ax.arrow(0,
             0,  # Start the arrow at the origin
             pca.components_[0, i],  #0 for PC1
             pca.components_[1, i],  #1 for PC2
             head_width=0.01,
             head_length=0.01)
    plt.text(pca.components_[0, i] + 0.001,
             pca.components_[1, i] + 0.001,
             df_Data_Point_scaled_noNaN_0.columns[i])                   

# Name of columns = Name of features

an = np.linspace(0, 2 * np.pi, 100)
plt.plot(0.5 * np.cos(an), 0.5 * np.sin(an))  # Add a unit circle for scale
plt.axis('equal')
ax.set_title('Variable factor map')

ax.spines['left'].set_position('zero')  # 将左边框置于数据坐标原点
ax.spines['bottom'].set_position('zero')  # 将底边框置于数据坐标原点

plt.axvline(0)  #從原點畫個垂直線
plt.axhline(0)  #從原點畫個平行線


plt.show()

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(df_Data_Point_scaled_noNaN_0)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
df_Data_Point_scaled_noNaN_2 = df_Data_Point_scaled_noNaN[['PC1','PC2']]

kmeans = KMeans(n_clusters=4)
kmeans.fit(df_Data_Point_scaled_noNaN_2)
y_kmeans = kmeans.predict(df_Data_Point_scaled_noNaN_2)

x = df_Data_Point_scaled_noNaN_2['PC1'].astype('float32')
y = df_Data_Point_scaled_noNaN_2['PC2'].astype('float32')
c = y_kmeans.astype('float32')

plt.scatter(x, y, c=c, s=50, cmap='viridis')

# %%
plt.scatter(x, y, c=c, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()

# %%
# Plot a variable factor map for the first two dimensions.
(fig, ax) = plt.subplots(figsize=(18, 18))
for i in range(0, len(df_Data_Point_scaled_noNaN_0.columns)):          # Each PCA's number of features
    ax.arrow(0,
             0,  # Start the arrow at the origin
             pca.components_[0, i] * 3,  #0 for PC1
             pca.components_[1, i] * 3,  #1 for PC2
             head_width=0.01,
             head_length=0.01)
    plt.text(pca.components_[0, i] * 3 + 0.001,
             pca.components_[1, i] * 3 + 0.001,
             df_Data_Point_scaled_noNaN_0.columns[i])                   

# Name of columns = Name of features

ax.spines['left'].set_position('zero')  # 将左边框置于数据坐标原点
ax.spines['bottom'].set_position('zero')  # 将底边框置于数据坐标原点

plt.axvline(0)  #從原點畫個垂直線
plt.axhline(0)  #從原點畫個平行線


plt.scatter(x, y, c=c, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)


plt.show()

# %%
df_Data_Point_scaled_noNaN['cluster'] = y_kmeans
df_Data_Point_scaled_noNaN.head()

# %%
cluster_1 = df_Data_Point_scaled_noNaN.loc[df_Data_Point_scaled_noNaN['cluster'] == 0]
cluster_2 = df_Data_Point_scaled_noNaN.loc[df_Data_Point_scaled_noNaN['cluster'] == 1]
cluster_3 = df_Data_Point_scaled_noNaN.loc[df_Data_Point_scaled_noNaN['cluster'] == 2]
cluster_4 = df_Data_Point_scaled_noNaN.loc[df_Data_Point_scaled_noNaN['cluster'] == 3]

# %%
mean_cluster_1 = cluster_1.mean() 
mean_cluster_2 = cluster_2.mean() 
mean_cluster_3 = cluster_3.mean() 
mean_cluster_4 = cluster_4.mean()

# %%
list_mean_cluster_1 = mean_cluster_1.tolist() 
list_mean_cluster_2 = mean_cluster_2.tolist() 
list_mean_cluster_3 = mean_cluster_3.tolist()
list_mean_cluster_4 = mean_cluster_4.tolist()

G = []
SC = []
E = []
MSR = []
SP = []
M = []

for i in range(4):
    XYZ1 = eval('list_mean_cluster_'+str(i+1))
    XYZ1 = XYZ1[:12]
    G.append(statistics.mean(XYZ1))
    XYZ2 = eval('list_mean_cluster_'+str(i+1))
    XYZ2 = XYZ2[12:19]
    SC.append(statistics.mean(XYZ2))
    XYZ3 = eval('list_mean_cluster_'+str(i+1))
    XYZ3 = XYZ3[19:25]
    E.append(statistics.mean(XYZ3))
    XYZ4 = eval('list_mean_cluster_'+str(i+1))
    XYZ4 = XYZ4[25:27]
    MSR.append(statistics.mean(XYZ4))
    XYZ5 = eval('list_mean_cluster_'+str(i+1))
    XYZ5 = XYZ5[27:31]
    SP.append(statistics.mean(XYZ5))
    XYZ6 = eval('list_mean_cluster_'+str(i+1))
    XYZ6 = XYZ6[31:40]
    M.append(statistics.mean(XYZ6))

# %%
print(G)
print(SC)
print(E)
print(MSR)
print(SP)
print(M)

# %%
Learners = {}
for i in range(4):
    Learners['Persona'+str(i+1)] = [G[i], SC[i], E[i], MSR[i], SP[i], M[i]]

Learners

# %%
from math import pi

categories = ['Grit', 'Self-Control', 'Engagement', 'Meta-cognitive Self-Regulation', 'Self-Perception', 'Motivation']
N = len(categories)

angles0 = [n / float(N)*2*pi for n in range(N)]


Learners['Persona1'] += Learners['Persona1'][:1]
angles0 += angles0[:1]

plt.polar(angles0, Learners['Persona1'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles0, Learners['Persona1'], alpha=0.3)
plt.xticks(angles0, categories)
axes = plt.gca()
axes.set_ylim(0,0.5)
axes.set_yticks(np.arange(0,0.5,0.1))


plt.show()

# %%
Learners['Persona2'] += Learners['Persona2'][:1]

plt.polar(angles0, Learners['Persona2'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles0, Learners['Persona2'], alpha=0.3)
plt.xticks(angles0, categories)
axes = plt.gca()
axes.set_ylim(0,0.5)
axes.set_yticks(np.arange(0,0.5,0.1))

plt.show()

# %%
Learners['Persona3'] += Learners['Persona3'][:1]

plt.polar(angles0, Learners['Persona3'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles0, Learners['Persona3'], alpha=0.3)
plt.xticks(angles0, categories)
axes = plt.gca()
axes.set_ylim(0,0.5)
axes.set_yticks(np.arange(0,0.5,0.1))

plt.show()

# %%
Learners['Persona4'] += Learners['Persona4'][:1]

plt.polar(angles0, Learners['Persona4'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles0, Learners['Persona4'], alpha=0.3)
plt.xticks(angles0, categories)
axes = plt.gca()
axes.set_ylim(0,0.5)
axes.set_yticks(np.arange(0,0.5,0.1))

plt.show()

# %%
# Rearrange the columns' order according to factor analyisi

columnsTitles = ['PC1', 'PC2', 'cluster',
                 'G1', 'G2', 'G3', 'G4', 'G6', 'G7', 'G8', 'SC1', 'SC4', 'SC6', 'SC7', 'E1', 'E2', 'SP1', 'M1', 'M2', 'M4', 
                 'SC2', 'SC5', 'MSR1', 'M9', 
                 'G5', 'G11', 'E3', 'SP4', 'M3', 'M5', 
                 'G10', 'SC3', 'E4', 'MSR2', 'SP2', 'M8', 
                 'E5', 'E6', 'M6', 'M7', 
                 'G9', 'G12', 'SP3']

arrange_df_Data_Point_scaled_noNaN = df_Data_Point_scaled_noNaN.reindex(columns=columnsTitles)

# %%
arrange_cluster_1 = arrange_df_Data_Point_scaled_noNaN.loc[arrange_df_Data_Point_scaled_noNaN['cluster'] == 0]
arrange_cluster_2 = arrange_df_Data_Point_scaled_noNaN.loc[arrange_df_Data_Point_scaled_noNaN['cluster'] == 1]
arrange_cluster_3 = arrange_df_Data_Point_scaled_noNaN.loc[arrange_df_Data_Point_scaled_noNaN['cluster'] == 2]
arrange_cluster_4 = arrange_df_Data_Point_scaled_noNaN.loc[arrange_df_Data_Point_scaled_noNaN['cluster'] == 3]

# %%
mean_arrange_cluster_1 = arrange_cluster_1.mean() 
mean_arrange_cluster_2 = arrange_cluster_2.mean() 
mean_arrange_cluster_3 = arrange_cluster_3.mean() 
mean_arrange_cluster_4 = arrange_cluster_4.mean() 

list_mean_arrange_cluster_1 = mean_arrange_cluster_1.tolist() 
list_mean_arrange_cluster_2 = mean_arrange_cluster_2.tolist() 
list_mean_arrange_cluster_3 = mean_arrange_cluster_3.tolist()
list_mean_arrange_cluster_4 = mean_arrange_cluster_4.tolist()

G_arrange = []
SC_arrange = []
E_arrange = []
MSR_arrange = []
SP_arrange = []
M_arrange = []

for i in range(4):
    ABC1 = eval('list_mean_arrange_cluster_'+str(i+1))
    ABC1 = ABC1[3:20]
    G_arrange.append(statistics.mean(ABC1))
    ABC2 = eval('list_mean_arrange_cluster_'+str(i+1))
    ABC2 = ABC2[20:24]
    SC_arrange.append(statistics.mean(ABC2))
    ABC3 = eval('list_mean_arrange_cluster_'+str(i+1))
    ABC3 = ABC3[24:30]
    E_arrange.append(statistics.mean(ABC3))
    ABC4 = eval('list_mean_arrange_cluster_'+str(i+1))
    ABC4 = ABC4[30:36]
    MSR_arrange.append(statistics.mean(ABC4))
    ABC5 = eval('list_mean_arrange_cluster_'+str(i+1))
    ABC5 = ABC5[36:40]
    SP_arrange.append(statistics.mean(ABC5))
    ABC6 = eval('list_mean_arrange_cluster_'+str(i+1))
    ABC6 = ABC6[40:]
    M_arrange.append(statistics.mean(ABC6))

print(G_arrange)
print(SC_arrange)
print(E_arrange)
print(MSR_arrange)
print(SP_arrange)
print(M_arrange)

# %%
Learners_arrange = {}
for i in range(4):
    Learners_arrange['Persona_arrange'+str(i+1)] = [G_arrange[i], SC_arrange[i], E_arrange[i], MSR_arrange[i], SP_arrange[i], M_arrange[i]]

Learners_arrange

# %%
from math import pi

categories = ['Grit', 'Self-Control', 'Engagement', 'Meta-cognitive Self-Regulation', 'Self-Perception', 'Motivation']
N = len(categories)

angles1 = [n / float(N)*2*pi for n in range(N)]


Learners_arrange['Persona_arrange1'] += Learners_arrange['Persona_arrange1'][:1]
angles1 += angles1[:1]

plt.polar(angles1, Learners_arrange['Persona_arrange1'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles1, Learners_arrange['Persona_arrange1'], alpha=0.3)
plt.xticks(angles1, categories)
axes = plt.gca()
axes.set_ylim(0,0.6)
axes.set_yticks(np.arange(0,0.6,0.1))


plt.show()

# %%
Learners_arrange['Persona_arrange2'] += Learners_arrange['Persona_arrange2'][:1]

plt.polar(angles1, Learners_arrange['Persona_arrange2'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles1, Learners_arrange['Persona_arrange2'], alpha=0.3)
plt.xticks(angles1, categories)
axes = plt.gca()
axes.set_ylim(0,0.6)
axes.set_yticks(np.arange(0,0.6,0.1))


plt.show()

# %%
Learners_arrange['Persona_arrange3'] += Learners_arrange['Persona_arrange3'][:1]

plt.polar(angles1, Learners_arrange['Persona_arrange3'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles1, Learners_arrange['Persona_arrange3'], alpha=0.3)
plt.xticks(angles1, categories)
axes = plt.gca()
axes.set_ylim(0,0.6)
axes.set_yticks(np.arange(0,0.6,0.1))


plt.show()

# %%
Learners_arrange['Persona_arrange4'] += Learners_arrange['Persona_arrange4'][:1]

plt.polar(angles1, Learners_arrange['Persona_arrange4'])
# color the area inside
plt.tick_params(labelsize=8)
plt.fill(angles1, Learners_arrange['Persona_arrange4'], alpha=0.3)
plt.xticks(angles1, categories)
axes = plt.gca()
axes.set_ylim(0,0.6)
axes.set_yticks(np.arange(0,0.6,0.1))


plt.show()

# %%
df_Data_Point_scaled_noNaN.shape

# %%
len(user)

# %%
df_survey = pd.read_excel("C1 - t3.xlsx")
df_survey.shape

# %%
df_survey.set_index('USER ID', inplace=True)

# %%
type(user)

# %%
df_survey = df_survey.loc[user, :]
df_survey.shape

# %%
#Grit = 题4 - 题13
#Self-control = 题14 - 题25
#Engagement = 题26 - 题32
#Metacognitive Self-regulation = 题33 - 题43
#Self-perception = 题44 - 题49
#Motivation = 题50 - 题56
df_non_cog = df_survey.iloc[:, :56]

# %%
df_non_cog_no24539 = df_survey.drop([24539])
df_non_cog_no24539.iloc[:, :56].head(10)

# %%
df_non_cog_no24539.iloc[:, :56].describe()

# %%
#Grit = 题4 - 题13
df_non_cog_no24539['Grit'] = df_non_cog_no24539.iloc[:, 3:13].sum(1) / len(df_non_cog_no24539.iloc[0, 3:13])

#Self-control = 题14 - 题25
df_non_cog_no24539['Self-control'] = df_non_cog_no24539.iloc[:, 13:25].sum(1) / len(df_non_cog_no24539.iloc[0, 13:25])

#Engagement = 题26 - 题32
df_non_cog_no24539['Engagement'] = df_non_cog_no24539.iloc[:, 25:32].sum(1) / len(df_non_cog_no24539.iloc[0, 25:32])

#Metacognitive Self-regulation = 题33 - 题43
df_non_cog_no24539['Metacognitive Self-regulation'] = df_non_cog_no24539.iloc[:, 32:43].sum(1) / len(df_non_cog_no24539.iloc[0, 32:43])

#Self-perception = 题44 - 题49
df_non_cog_no24539['Self-perception'] = df_non_cog_no24539.iloc[:, 43:49].sum(1) / len(df_non_cog_no24539.iloc[0, 43:49])

#Motivation = 题50 - 题56
df_non_cog_no24539['Motivation'] = df_non_cog_no24539.iloc[:, 49:56].sum(1) / len(df_non_cog_no24539.iloc[0, 49:56])

# %%
df_non_cog_no24539.head()

# %%
six_df_non_cog_no24539 = df_non_cog_no24539.iloc[:, 110:]

# %%
six_df_non_cog_no24539.head()

# %%
six_df_non_cog_no24539.describe()

# %%
df_Data_Point_scaled_noNaN_no24539 = df_Data_Point_scaled_noNaN.drop([24539])

# %%
df_Data_Point_scaled_noNaN_no24539.head()

# %%
df_Data_Point_scaled_noNaN_no24539.shape

# %%
merge_non_cog = df_Data_Point_scaled_noNaN_no24539.merge(six_df_non_cog_no24539, 
                                                         left_index=True, right_index=True, how='left')
merge_non_cog

# %%
merge_non_cog.head()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso



#Expert Engineering版
X_Grit_EE = merge_non_cog.loc[:, ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 
                                  'G12']]
Y_Grit = merge_non_cog.loc[:, 'Grit']

X_Self_control_EE = merge_non_cog.loc[:, ['SC1', 'SC2', 'SC3', 'SC4', 'SC5', 'SC6', 'SC7']]
Y_Self_control = merge_non_cog.loc[:, 'Self-control']

X_Engagement_EE = merge_non_cog.loc[:, ['E1', 'E2', 'E3', 'E4', 'E5', 'E6']]
Y_Engagement = merge_non_cog.loc[:, 'Engagement']

X_Metacognitive_EE = merge_non_cog.loc[:, ['MSR1', 'MSR2']]
Y_Metacognitive = merge_non_cog.loc[:, 'Metacognitive Self-regulation']

X_Self_perception_EE = merge_non_cog.loc[:, ['SP1', 'SP2', 'SP3', 'SP4']]
Y_Self_perception = merge_non_cog.loc[:, 'Self-perception']

X_Motivation_EE = merge_non_cog.loc[:, ['M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9']]
Y_Motivation = merge_non_cog.loc[:, 'Motivation']

# %%
#Exploratory Factor Analysis版
X_Grit_EFA = merge_non_cog.loc[:, ['G1', 'G2', 'G3', 'G4', 'G6', 'G7', 'G8', 'SC1', 'SC4', 'SC6', 
                                   'SC7', 'E1', 'E2', 'SP1', 'M1', 'M2', 'M4']]
X_Self_control_EFA = merge_non_cog.loc[:, ['SC2', 'SC5', 'MSR1', 'M9']]
X_Engagement_EFA = merge_non_cog.loc[:, ['G5', 'G11', 'E3', 'SP4', 'M3', 'M5']]
X_Metacognitive_EFA = merge_non_cog.loc[:, ['G10', 'SC3', 'E4', 'MSR2', 'SP2', 'M8']]
X_Self_perception_EFA = merge_non_cog.loc[:, ['E5', 'E6', 'M6', 'M7']]
X_Motivation_EFA = merge_non_cog.loc[:, ['G9', 'G12', 'SP3']]

# %%
#Grit: Linear Regression of EE
lin_reg_EE_G = LinearRegression()
MSEs = cross_val_score(lin_reg_EE_G, X_Grit_EE, Y_Grit, scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EE_G.fit(X_Grit_EE, Y_Grit)

print(lin_reg_EE_G.intercept_)
print(lin_reg_EE_G.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Grit: Linear Regression of EFA
lin_reg_EFA_G = LinearRegression()
MSEs = cross_val_score(lin_reg_EFA_G, X_Grit_EFA, Y_Grit, scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EFA_G.fit(X_Grit_EFA, Y_Grit)

print(lin_reg_EFA_G.intercept_)
print(lin_reg_EFA_G.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Self-control: Linear Regression of EE
lin_reg_EE_SC = LinearRegression()
MSEs = cross_val_score(lin_reg_EE_SC, X_Self_control_EE, Y_Self_control, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EE_SC.fit(X_Self_control_EE, Y_Self_control)

print(lin_reg_EE_SC.intercept_)
print(lin_reg_EE_SC.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Self-control: Linear Regression of EFA
lin_reg_EFA_SC = LinearRegression()
MSEs = cross_val_score(lin_reg_EFA_SC, X_Self_control_EFA, Y_Self_control, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EFA_SC.fit(X_Self_control_EFA, Y_Self_control)

print(lin_reg_EFA_SC.intercept_)
print(lin_reg_EFA_SC.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Engagement: Linear Regression of EE
lin_reg_EE_E = LinearRegression()
MSEs = cross_val_score(lin_reg_EE_E, X_Engagement_EE, Y_Engagement, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EE_E.fit(X_Engagement_EE, Y_Engagement)

print(lin_reg_EE_E.intercept_)
print(lin_reg_EE_E.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Engagement: Linear Regression of EFA
lin_reg_EFA_E = LinearRegression()
MSEs = cross_val_score(lin_reg_EFA_E, X_Engagement_EFA, Y_Engagement, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EFA_E.fit(X_Engagement_EFA, Y_Engagement)

print(lin_reg_EFA_E.intercept_)
print(lin_reg_EFA_E.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Metacognitive Self-regulation: Linear Regression of EE
lin_reg_EE_MSR = LinearRegression()
MSEs = cross_val_score(lin_reg_EE_MSR, X_Metacognitive_EE, Y_Metacognitive, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EE_MSR.fit(X_Metacognitive_EE, Y_Metacognitive)

print(lin_reg_EE_MSR.intercept_)
print(lin_reg_EE_MSR.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Metacognitive Self-regulation: Linear Regression of EFA
lin_reg_EFA_MSR = LinearRegression()
MSEs = cross_val_score(lin_reg_EFA_MSR, X_Metacognitive_EFA, Y_Metacognitive, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EFA_MSR.fit(X_Metacognitive_EFA, Y_Metacognitive)

print(lin_reg_EFA_MSR.intercept_)
print(lin_reg_EFA_MSR.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Self-perception: Linear Regression of EE
lin_reg_EE_SP = LinearRegression()
MSEs = cross_val_score(lin_reg_EE_SP, X_Self_perception_EE, Y_Self_perception, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EE_SP.fit(X_Self_perception_EE, Y_Self_perception)

print(lin_reg_EE_SP.intercept_)
print(lin_reg_EE_SP.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Self-perception: Linear Regression of EFA
lin_reg_EFA_SP = LinearRegression()
MSEs = cross_val_score(lin_reg_EFA_SP, X_Self_perception_EFA, Y_Self_perception, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EFA_SP.fit(X_Self_perception_EFA, Y_Self_perception)

print(lin_reg_EFA_SP.intercept_)
print(lin_reg_EFA_SP.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Motivation: Linear Regression of EE
lin_reg_EE_M = LinearRegression()
MSEs = cross_val_score(lin_reg_EE_M, X_Motivation_EE, Y_Motivation, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EE_M.fit(X_Motivation_EE, Y_Motivation)

print(lin_reg_EE_M.intercept_)
print(lin_reg_EE_M.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Motivation: Linear Regression of EFA
lin_reg_EFA_M = LinearRegression()
MSEs = cross_val_score(lin_reg_EFA_M, X_Motivation_EFA, Y_Motivation, 
                       scoring='neg_mean_squared_error', cv=5)
mean_MSE = np.mean(MSEs)
lin_reg_EFA_M.fit(X_Motivation_EFA, Y_Motivation)

print(lin_reg_EFA_M.intercept_)
print(lin_reg_EFA_M.coef_)
print(MSEs)
print(mean_MSE)

# %%
#Grit: Lasso Regression of EE
lasso_EE_G = Lasso(alpha=0.005)
lasso_EE_G.fit(X_Grit_EE, Y_Grit)
list(lasso_EE_G.coef_)

# %%
#Grit: Lasso Regression of EFA
lasso_EFA_G = Lasso(alpha=0.005)
lasso_EFA_G.fit(X_Grit_EFA, Y_Grit)
list(lasso_EFA_G.coef_)

# %%
#Self-control: Lasso Regression of EE
lasso_EE_SC = Lasso(alpha=0.005)
lasso_EE_SC.fit(X_Self_control_EE, Y_Self_control)
list(lasso_EE_SC.coef_)

# %%
#Self-control: Lasso Regression of EFA
lasso_EFA_SC = Lasso(alpha=0.005)
lasso_EFA_SC.fit(X_Self_control_EFA, Y_Self_control)
list(lasso_EFA_SC.coef_)

# %%
#Engagement: Lasso Regression of EE
lasso_EE_E = Lasso(alpha=0.005)
lasso_EE_E.fit(X_Engagement_EE, Y_Engagement)
list(lasso_EE_E.coef_)

# %%
#Engagement: Lasso Regression of EFA
lasso_EFA_E = Lasso(alpha=0.005)
lasso_EFA_E.fit(X_Engagement_EFA, Y_Engagement)
list(lasso_EFA_E.coef_)

# %%
#Metacognitive Self-regulation: Lasso Regression of EE
lasso_EE_MSR = Lasso(alpha=0.005)
lasso_EE_MSR.fit(X_Metacognitive_EE, Y_Metacognitive)
list(lasso_EE_MSR.coef_)

# %%
#Metacognitive Self-regulation: Lasso Regression of EFA
lasso_EFA_MSR = Lasso(alpha=0.005)
lasso_EFA_MSR.fit(X_Metacognitive_EFA, Y_Metacognitive)
list(lasso_EFA_MSR.coef_)

# %%
#Self-perception: Lasso Regression of EE
lasso_EE_SP = Lasso(alpha=0.005)
lasso_EE_SP.fit(X_Self_perception_EE, Y_Self_perception)
list(lasso_EE_SP.coef_)

# %%
#Self-perception: Lasso Regression of EFA
lasso_EFA_SP = Lasso(alpha=0.005)
lasso_EFA_SP.fit(X_Self_perception_EFA, Y_Self_perception)
list(lasso_EFA_SP.coef_)

# %%
#Motivation: Lasso Regression of EE
lasso_EE_M = Lasso(alpha=0.005)
lasso_EE_M.fit(X_Motivation_EE, Y_Motivation)
list(lasso_EE_M.coef_)

# %%
#Motivation: Lasso Regression of EE
lasso_EFA_M = Lasso(alpha=0.005)
lasso_EFA_M.fit(X_Motivation_EFA, Y_Motivation)
list(lasso_EFA_M.coef_)

# %%
listEE_G = lin_reg_EE_G.coef_.tolist()
listEE_SC = lin_reg_EE_SC.coef_.tolist()
listEE_E = lin_reg_EE_E.coef_.tolist()
listEE_MSR = lin_reg_EE_MSR.coef_.tolist()
listEE_SP = lin_reg_EE_SP.coef_.tolist()
listEE_M = lin_reg_EE_M.coef_.tolist()

coef_list_reg_EE = listEE_G + listEE_SC + listEE_E + listEE_MSR + listEE_SP + listEE_M

# %%
listEE_G2 = lasso_EE_G.coef_.tolist()
listEE_SC2 = lasso_EE_SC.coef_.tolist()
listEE_E2 = lasso_EE_E.coef_.tolist()
listEE_MSR2 = lasso_EE_MSR.coef_.tolist()
listEE_SP2 = lasso_EE_SP.coef_.tolist()
listEE_M2 = lasso_EE_M.coef_.tolist()

coef_list_lasso_EE = listEE_G2 + listEE_SC2 + listEE_E2 + listEE_MSR2 + listEE_SP2 + listEE_M2

# %%
listEFA_G = lin_reg_EFA_G.coef_.tolist()
listEFA_SC = lin_reg_EFA_SC.coef_.tolist()
listEFA_E = lin_reg_EFA_E.coef_.tolist()
listEFA_MSR = lin_reg_EFA_MSR.coef_.tolist()
listEFA_SP = lin_reg_EFA_SP.coef_.tolist()
listEFA_M = lin_reg_EFA_M.coef_.tolist()

coef_list_reg_EFA = listEFA_G + listEFA_SC + listEFA_E + listEFA_MSR + listEFA_SP + listEFA_M

# %%
listEFA_G2 = lasso_EFA_G.coef_.tolist()
listEFA_SC2 = lasso_EFA_SC.coef_.tolist()
listEFA_E2 = lasso_EFA_E.coef_.tolist()
listEFA_MSR2 = lasso_EFA_MSR.coef_.tolist()
listEFA_SP2 = lasso_EFA_SP.coef_.tolist()
listEFA_M2 = lasso_EFA_M.coef_.tolist()

coef_list_lasso_EFA = listEFA_G2 + listEFA_SC2 + listEFA_E2 + listEFA_MSR2 + listEFA_SP2 + listEFA_M2

# %%
EE_coef_table = pd.DataFrame(columns = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 
                                        'SC1', 'SC2', 'SC3', 'SC4', 'SC5', 'SC6', 'SC7', 
                                        'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 
                                        'MSR1', 'MSR2', 
                                        'SP1', 'SP2', 'SP3', 'SP4', 
                                        'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9'], index = ['Linear', 'LASSO', ])
EE_coef_table.loc['Linear'] = coef_list_reg_EE
EE_coef_table.loc['LASSO'] = coef_list_lasso_EE

# %%
EE_coef_table

# %%
EFA_coef_table = pd.DataFrame(columns = ['G1', 'G2', 'G3', 'G4', 'G6', 'G7', 'G8', 'SC1', 'SC4', 'SC6', 
                                          'SC7', 'E1', 'E2', 'SP1', 'M1', 'M2', 'M4',
                                          'SC2', 'SC5', 'MSR1', 'M9', 
                                          'G5', 'G11', 'E3', 'SP4', 'M3', 'M5', 
                                          'G10', 'SC3', 'E4', 'MSR2', 'SP2', 'M8', 
                                          'E5', 'E6', 'M6', 'M7', 
                                          'G9', 'G12', 'SP3'], index = ['Linear', 'LASSO'])
EFA_coef_table.loc['Linear'] = coef_list_reg_EFA
EFA_coef_table.loc['LASSO'] = coef_list_lasso_EFA

# %%
EFA_coef_table

# %%
Logic_merge_non_cog = merge_non_cog

# %%
Logic_merge_non_cog.describe()

# %%
threshold = 3.5 + 0.1 

Logic_merge_non_cog['Grit_Logic'] = Logic_merge_non_cog['Grit'].gt(threshold).astype(int)
Logic_merge_non_cog['Self-control_Logic'] = Logic_merge_non_cog['Self-control'].gt(threshold).astype(int)
Logic_merge_non_cog['Engagement_Logic'] = Logic_merge_non_cog['Engagement'].gt(threshold).astype(int)
Logic_merge_non_cog['Metacognitive Self-regulation_Logic'] 
= Logic_merge_non_cog['Metacognitive Self-regulation'].gt(threshold).astype(int)
Logic_merge_non_cog['Self-perception_Logic'] 
= Logic_merge_non_cog['Self-perception'].gt(threshold).astype(int)
Logic_merge_non_cog['Motivation_Logic'] = Logic_merge_non_cog['Motivation'].gt(threshold).astype(int)
Logic_merge_non_cog

# %%
Y_Grit_L = Logic_merge_non_cog.loc[:, 'Grit_Logic']
Y_Self_control_L = Logic_merge_non_cog.loc[:, 'Self-control_Logic']
Y_Engagement_L = Logic_merge_non_cog.loc[:, 'Engagement_Logic']
Y_Metacognitive_L = Logic_merge_non_cog.loc[:, 'Metacognitive Self-regulation_Logic']
Y_Self_perception_L = Logic_merge_non_cog.loc[:, 'Self-perception_Logic']
Y_Motivation_L = Logic_merge_non_cog.loc[:, 'Motivation_Logic']

# %%
from sklearn.linear_model import LogisticRegression

L1_EE_G = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EE_SC = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EE_E = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EE_MSR = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EE_SP = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EE_M = LogisticRegression(penalty='l1', C = 10, solver='liblinear')

#Grit: Lasso "Logistic" Regression of EE
L1_EE_G.fit(X_Grit_EE, Y_Grit_L)
#Self-control: Lasso "Logistic" Regression of EE
L1_EE_SC.fit(X_Self_control_EE, Y_Self_control_L)
#Engagement: Lasso "Logistic" Regression of EE
L1_EE_E.fit(X_Engagement_EE, Y_Engagement_L)
#Meatcognitive Self-regulation: Lasso "Logistic" Regression of EE
L1_EE_MSR.fit(X_Metacognitive_EE, Y_Metacognitive_L)
#Self-perception: Lasso "Logistic" Regression of EE
L1_EE_SP.fit(X_Self_perception_EE, Y_Self_perception_L)
#Motivation: Lasso "Logistic" Regression of EE
L1_EE_M.fit(X_Motivation_EE, Y_Motivation_L)

# %%
listEE_G3 = L1_EE_G.coef_.tolist()
listEE_SC3 = L1_EE_SC.coef_.tolist()
listEE_E3 = L1_EE_E.coef_.tolist()
listEE_MSR3 = L1_EE_MSR.coef_.tolist()
listEE_SP3 = L1_EE_SP.coef_.tolist()
listEE_M3 = L1_EE_M.coef_.tolist()

# %%
coef_list_L1_EE = listEE_G3[0] + listEE_SC3[0] + listEE_E3[0] + 
listEE_MSR3[0] + listEE_SP3[0] + listEE_M3[0]

# %%
EE_coef_table2 = pd.DataFrame(columns = ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 
                                         'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 
                                        'SC1', 'SC2', 'SC3', 'SC4', 'SC5', 'SC6', 'SC7', 
                                        'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 
                                        'MSR1', 'MSR2', 
                                        'SP1', 'SP2', 'SP3', 'SP4', 
                                        'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 
                                         'M7', 'M8', 'M9'], 
                              index = ['Linear', 'LASSO', 'LASSO_logistic'])
EE_coef_table2.loc['Linear'] = coef_list_reg_EE
EE_coef_table2.loc['LASSO'] = coef_list_lasso_EE
EE_coef_table2.loc['LASSO_logistic'] = coef_list_L1_EE
EE_coef_table2

# %%
L1_EFA_G = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EFA_SC = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EFA_E = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EFA_MSR = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EFA_SP = LogisticRegression(penalty='l1', C = 10, solver='liblinear')
L1_EFA_M = LogisticRegression(penalty='l1', C = 10, solver='liblinear')

#Grit: Lasso "Logistic" Regression of EFA
L1_EFA_G.fit(X_Grit_EFA, Y_Grit_L)
#Self-control: Lasso "Logistic" Regression of EFA
L1_EFA_SC.fit(X_Self_control_EFA, Y_Self_control_L)
#Engagement: Lasso "Logistic" Regression of EFA
L1_EFA_E.fit(X_Engagement_EFA, Y_Engagement_L)
#Meatcognitive Self-regulation: Lasso "Logistic" Regression of EFA
L1_EFA_MSR.fit(X_Metacognitive_EFA, Y_Metacognitive_L)
#Self-perception: Lasso "Logistic" Regression of EFA
L1_EFA_SP.fit(X_Self_perception_EFA, Y_Self_perception_L)
#Motivation: Lasso "Logistic" Regression of EFA
L1_EFA_M.fit(X_Motivation_EFA, Y_Motivation_L)

listEFA_G3 = L1_EFA_G.coef_.tolist()
listEFA_SC3 = L1_EFA_SC.coef_.tolist()
listEFA_E3 = L1_EFA_E.coef_.tolist()
listEFA_MSR3 = L1_EFA_MSR.coef_.tolist()
listEFA_SP3 = L1_EFA_SP.coef_.tolist()
listEFA_M3 = L1_EFA_M.coef_.tolist()

# %%
coef_list_L1_EFA = listEFA_G3[0] + listEFA_SC3[0] + listEFA_E3[0] + 
listEFA_MSR3[0] + listEFA_SP3[0] + listEFA_M3[0]

# %%
EFA_coef_table2 = pd.DataFrame(columns = ['G1', 'G2', 'G3', 'G4', 'G6', 'G7', 'G8', 'SC1', 'SC4', 'SC6', 
                                          'SC7', 'E1', 'E2', 'SP1', 'M1', 'M2', 'M4',
                                          'SC2', 'SC5', 'MSR1', 'M9', 
                                          'G5', 'G11', 'E3', 'SP4', 'M3', 'M5', 
                                          'G10', 'SC3', 'E4', 'MSR2', 'SP2', 'M8', 
                                          'E5', 'E6', 'M6', 'M7', 
                                          'G9', 'G12', 'SP3'], 
                               index = ['Linear', 'LASSO', 'LASSO_logistic'])
X_Grit_EFA = merge_non_cog.loc[:, []]
X_Self_control_EFA = merge_non_cog.loc[:, []]
X_Engagement_EFA = merge_non_cog.loc[:, []]
X_Metacognitive_EFA = merge_non_cog.loc[:, []]
X_Self_perception_EFA = merge_non_cog.loc[:, []]
X_Motivation_EFA = merge_non_cog.loc[:, []]

EFA_coef_table2.loc['Linear'] = coef_list_reg_EFA
EFA_coef_table2.loc['LASSO'] = coef_list_lasso_EFA
EFA_coef_table2.loc['LASSO_logistic'] = coef_list_L1_EFA
EFA_coef_table2
